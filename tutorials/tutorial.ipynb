# %% [markdown]
# # **Mutated-gene Genome-Wide Association Study (MugGWAS)**

# %% [markdown]
# MugGWAS offers an non-model-organism-friendly pipeline to infer gene-trait association. It tackles common challenges faced by non-model organism research—such as lack of readily available annotation databases and small sample sizes—by integrating a simple annotation pipeline with mutation-centric GWAS analysis. Users can identify putative gene mutations that drive phenotypic change without the large statistical power required to perform genome-wide tests on a per nucleotide basis.

# %% [markdown]
# ## **Motivation**
#
# Understanding the genetic basis of a trait is central to many biological research that help gain mechanismtic insight into complex biological phenomena. For instance, the discovery of genetic loci that contribute to antibiotic resistance could better our knowledge for how important pathogens evolve to escape medicinal application.
#
# Most association tools classify raw genetic variants (like single nucleotide polymorphisms or structural variants) into reference or alternative genotypes, then perform statistical tests to infer associations between particular variants and phenotypes. However, genome-wide analyses typically require large sample sizes for statistical power—a major challenge for organisms that are difficult to culture or traits that are challenging to measure. Alternative approaches test associations between phenotypes and gene presence/absence, but these methods don't capture finer details like important mutations that potentially disrupt gene function.
#
# Mutated-gene Genome-Wide Association Study (MugGWAS) addresses these limitations by offering a non-model-organism-friendly pipeline to infer gene-trait associations. By annotating disruptive mutation types (nonsense, missense, stopgain, or nonstop), MugGWAS identifies putative gene dysfunctions associated with phenotypic changes. This approach conserves statistical power by avoiding tests on variants that either (1) don't affect function at the gene level or (2) result in disruption of the same gene, allowing users to identify putative gene mutations driving phenotypic changes without the large statistical power required for per-nucleotide genome-wide tests.

# %% [markdown]
# ## **Prerquisites**
# MugGWAS uses the external tool-**ANNOVAR** to annotate variants. Please follow the [instructions](http://annovar.openbioinformatics.org/en/latest/) to download **ANNOVAR** (_registration is required_), and specify the path to ANNOVAR scripts for MugGWAS. More instructions are provided below.
#
# This package uses the fixed effect model in [**pyseer**](https://pyseer.readthedocs.io/en/master/index.html) for association analysis. Users don't need to download **Pyseer** and the [prerequisites](https://pyseer.readthedocs.io/en/master/installation.html#prerequisites) themselves. They will be included in the conda environments following the instructions below.

# %% [markdown]
# ## **Installation Guide**
#
# The easiest way to install MugGWAS and fulfill the prerequites is through this path:
#
# #### **Build Conda Environment**
#
# Download the [environmental.yaml](https://github.com/lyuchengmarvin/MugGWAS/blob/main/envs/environment.yaml) file for setting up your conda environement. You can download it using this command in your terminal.
#
# ```{command line}
# wget https://github.com/lyuchengmarvin/MugGWAS/blob/main/envs/environment.yaml
# ```
#
# Build the environment to satisfy software prerequisites and ensure applicability.
#
# ```{command line}
# conda env create --name muggwas --file envs/environment.yaml
# ```
#
# Activate envrionment before use each time:
#
# ```{command line}
# conda activate muggwas
# ```
#
# Deactivate after use:
#
# ```{command line}
# conda deactivate
# ```
#
# #### **Install MugGWAS**
#
# Install MugGWAS in your environment and make sure that all prerequisites are fulfilled.
#
# ```{command line}
# pip install -i https://test.pypi.org/simple/ MugGWAS
# ```
# You might need to restart the kernal to run this tutorial in Jupyter Notebook.

# %% [markdown]
# ## **Tutaorial**
#
# ### **Download the Tutorial Dataset**
# Type this command in your terminal to download the [dataset](https://github.com/lyuchengmarvin/MugGWAS/tree/main/tutorials/data/pyseer_dataset). Remeber to place this under the same directory of this tutorial file.
# ```{comand line}
# wget https://github.com/lyuchengmarvin/MugGWAS/tree/main/tutorials/data/pyseer_dataset
# ```
#
# ### **Overview:**
# 1. Annotate variants
# 2. Build gene mutation table
# 3. Estimate population structure
# 4. GWAS with pyseer
#
# ![MugGWAS Workflow](MugGWAS_workflow.png)

# %% [markdown]
# ### **Step 1: Annotate variants with ANNOVAR**
#
# We will use the external tool ANNOVAR and annotate the variants from vcf files. Although one vcf file should contain the variant information for multiple samples, ANNOVAR annotates samples iteratively and create an annotation file per sample.
#
# This tool also assumed that users will build their customized database for their none-model organisms, so a genome annotation **<ref_prefix>.gff3** and a genome fasta file **<ref_prefix>.fna** are required and placed in the directory **<ref_prefix>/**. The database will utilize the tool `gff3ToGenePred` to build the database, which was also built when users created their conda environments.
#
#
# **Annotation workflow**
#
# 1. **Make input files**:
#     - Input: a VCF file `vcf_prefix.vcf` (with multiple samples)
#     - Convert VCF to ANNOVAR input format `vcf_prefix.<sample_name>.avinput`
#     - Store in `/path_to_vcf/annovar_files/`
# 2. **Build database**:
#     - Input: `ref_prefix.gff3` and `ref_prefix.fna` in `db_dir/`
#     - Build customized database: `ref_prefix_refGene.txt` and `ref_prefix_refGeneMrna.fa`
# 3. **Annotate variants with ANNOVAR**:
#     - Output1: `vcf_prefix.<sample_name>.avinput.variant_function` infer mutation position on a gene.
#     - Output2: `vcf_prefix.<sample_name>.avinput.exonic_variant_function` infer mutation effects on translation, namely synonymous, nonsynonymous, stop codon gain, or stop codon loss.

# %%
from muggwas import run_annovar

## User inputs
# the path to the ANNOVAR installation
annovar_dir = '../annovar/'
# the directory where the reference files are located
db_dir = 'pyseer_dataset/Spn23F/' #ref is susceptible to penicillin
# path to the vcf file
input_dir = 'pyseer_dataset/snps.snp.subset.filtered.vcf.gz'
# output prefix or the converted annovar input file
vcf_prefix = 'snps'
# output prefix for the annovar database
ref_prefix = 'Spn23F' #ref is susceptible to penicillin

## Run ANNOVAR
run_annovar(
    annovar_dir=annovar_dir,
    db_dir=db_dir,
    input_dir=input_dir,
    vcf_prefix=vcf_prefix,
    ref_prefix=ref_prefix
)
# Out:
# Converting VCF file to annovar input format...
# NOTICE: output files will be written to data/pyseer_dataset/annovar_files/snps.<samplename>.avinput
# NOTICE: Finished reading 91729 lines from VCF file
# NOTICE: A total of 91717 locus in VCF file passed QC threshold, representing 91717 SNPs (69023 transitions and 22694 transversions) and 0 indels/substitutions
# NOTICE: Finished writing 3154524 SNP genotypes (2386705 transitions and 767819 transversions) and 0 indels/substitutions for 300 samples
# The VCF file has been converted and saved to data/pyseer_dataset/annovar_files/.
# NOTICE: Reading region file data/pyseer_dataset/Spn23F/Spn23F_refGene.txt ... Done with 2271 regions from 1 chromosomes
# NOTICE: Finished reading 1 sequences from data/pyseer_dataset/Spn23F/Spn23F.fna
# NOTICE: Finished writting FASTA for 2271 genomic regions to data/pyseer_dataset/Spn23F/Spn23F_refGeneMrna.fa
# WARNING: 3 regions occur more than once with discordant sequence length (for example, cds-WP_000997239.1, cds-WP_010963246.1, cds-WP_087671856.1)
# WARNING: 111 gene regions do not have complete ORF (for example, cds-SPN23F_RS13720NC_011900.1:137325, cds-SPN23F_RS11710NC_011900.1:22714, cds-SPN23F_RS14010NC_011900.1:2040012, cds-SPN23F_RS03165NC_011900.1:613877, cds-SPN23F_RS13675NC_011900.1:37582)
# 2025-04-15 21:02:56,444 - INFO - Starting parallel annotation of avinput files.
# Database has been built and saved to data/pyseer_dataset/Spn23F/.
#
# Annotating avinput files...
# NOTICE: Output files are written to data/pyseer_dataset/annovar_files/snps.6925_2#84.avinput.variant_function, data/pyseer_dataset/annovar_files/snps.6925_2#84.avinput.exonic_variant_function
# NOTICE: Reading gene annotation from data/pyseer_dataset/Spn23F/Spn23F_refGene.txt ... NOTICE: Output files are written to data/pyseer_dataset/annovar_files/snps.7622_4#14.avinput.variant_function, data/pyseer_dataset/annovar_files/snps.7622_4#14.avinput.exonic_variant_function
# NOTICE: Reading gene annotation from data/pyseer_dataset/Spn23F/Spn23F_refGene.txt ... NOTICE: Output files are written to data/pyseer_dataset/annovar_files/snps.7622_3#89.avinput.variant_function, data/pyseer_dataset/annovar_files/snps.7622_3#89.avinput.exonic_variant_function
# NOTICE: Reading gene annotation from data/pyseer_dataset/Spn23F/Spn23F_refGene.txt ... NOTICE: Output files are written to data/pyseer_dataset/annovar_files/snps.7622_5#84.avinput.variant_function, data/pyseer_dataset/annovar_files/snps.7622_5#84.avinput.exonic_variant_function
# NOTICE: Reading gene annotation from data/pyseer_dataset/Spn23F/Spn23F_refGene.txt ... NOTICE: Output files are written to data/pyseer_dataset/annovar_files/snps.6999_2#16.avinput.variant_function, data/pyseer_dataset/annovar_files/snps.6999_2#16.avinput.exonic_variant_function
# NOTICE: Output files are written to data/pyseer_dataset/annovar_files/snps.7622_5#94.avinput.variant_function, data/pyseer_dataset/annovar_files/snps.7622_5#94.avinput.exonic_variant_function
# NOTICE: Reading gene annotation from data/pyseer_dataset/Spn23F/Spn23F_refGene.txt ... NOTICE: Reading gene annotation from data/pyseer_dataset/Spn23F/Spn23F_refGene.txt ... NOTICE: Output files are written to data/pyseer_dataset/annovar_files/snps.6925_2#94.avinput.variant_function, data/pyseer_dataset/annovar_files/snps.6925_2#94.avinput.exonic_variant_function
# NOTICE: Reading gene annotation from data/pyseer_dataset/Spn23F/Spn23F_refGene.txt ... NOTICE: Output files are written to data/pyseer_dataset/annovar_files/snps.7622_3#52.avinput.variant_function, data/pyseer_dataset/annovar_files/snps.7622_3#52.avinput.exonic_variant_function
# NOTICE: Reading gene annotation from data/pyseer_dataset/Spn23F/Spn23F_refGene.txt ... Done with 2271 transcripts (including 70 without coding sequence annotation) for 2268 unique genes
# Done with 2271 transcripts (including 70 without coding sequence annotation) for 2268 unique genes
# Done with 2271 transcripts (including 70 without coding sequence annotation) for 2268 unique genes
# Done with 2271 transcripts (including 70 without coding sequence annotation) for 2268 unique genes
# Done with 2271 transcripts (including 70 without coding sequence annotation) for 2268 unique genes
# Done with 2271 transcripts (including 70 without coding sequence annotation) for 2268 unique genes
# Done with 2271 transcripts (including 70 without coding sequence annotation) for 2268 unique genes
# Done with 2271 transcripts (including 70 without coding sequence annotation) for 2268 unique genes
# NOTICE: Processing next batch with 9531 unique variants in 9531 input lines
# NOTICE: Processing next batch with 11800 unique variants in 11800 input lines
# NOTICE: Processing next batch with 10727 unique variants in 10727 input lines
# NOTICE: Processing next batch with 10514 unique variants in 10514 input lines
# NOTICE: Processing next batch with 10349 unique variants in 10349 input lines
# NOTICE: Processing next batch with 10447 unique variants in 10447 input lines
# NOTICE: Processing next batch with 10157 unique variants in 10157 input lines
# NOTICE: Processing next batch with 10185 unique variants in 10185 input lines
# NOTICE: Reading FASTA sequences from data/pyseer_dataset/Spn23F/Spn23F_refGeneMrna.fa ... Done with 1441 sequences
# WARNING: A total of 111 sequences will be ignored due to lack of correct ORF annotation
# NOTICE: Reading FASTA sequences from data/pyseer_dataset/Spn23F/Spn23F_refGeneMrna.fa ... Done with 1489 sequences
# WARNING: A total of 111 sequences will be ignored due to lack of correct ORF annotation
# NOTICE: Reading FASTA sequences from data/pyseer_dataset/Spn23F/Spn23F_refGeneMrna.fa ... Done with 1467 sequences
# WARNING: A total of 111 sequences will be ignored due to lack of correct ORF annotation
# NOTICE: Reading FASTA sequences from data/pyseer_dataset/Spn23F/Spn23F_refGeneMrna.fa ...
# ---------------------------------------------------------------------------------------
# WARNING: 2023 exonic SNPs have WRONG reference alleles specified in your input file!
# WARNING: An example input line is <NC_011900.1	48794	48794	C	T	hom	.	.>
# WARNING: ANNOVAR can still annotate exonic_variant_function for the mutation correctly!
# WARNING: you may have used wrong -buildver, or specified incorrect reference allele, or used outdated mRNA FASTA file!
# ---------------------------------------------------------------------------------------
#
# Done with 1456 sequences
# WARNING: A total of 111 sequences will be ignored due to lack of correct ORF annotation
# 2025-04-15 21:02:59,406 - INFO - Successfully annotated data/pyseer_dataset/annovar_files/snps.6925_2#94.avinput
# NOTICE: Reading FASTA sequences from data/pyseer_dataset/Spn23F/Spn23F_refGeneMrna.fa ... Done with 1468 sequences
# WARNING: A total of 111 sequences will be ignored due to lack of correct ORF annotation
#
# ---------------------------------------------------------------------------------------
# WARNING: 2023 exonic SNPs have WRONG reference alleles specified in your input file!
# WARNING: An example input line is <NC_011900.1	2059021	2059021	A	G	hom	.	.>
# WARNING: ANNOVAR can still annotate exonic_variant_function for the mutation correctly!
# WARNING: you may have used wrong -buildver, or specified incorrect reference allele, or used outdated mRNA FASTA file!
# ---------------------------------------------------------------------------------------
#
# NOTICE: Reading FASTA sequences from data/pyseer_dataset/Spn23F/Spn23F_refGeneMrna.fa ... Done with 1437 sequences
# WARNING: A total of 111 sequences will be ignored due to lack of correct ORF annotation
# 2025-04-15 21:02:59,508 - INFO - Successfully annotated data/pyseer_dataset/annovar_files/snps.7622_3#89.avinput
# NOTICE: Reading FASTA sequences from data/pyseer_dataset/Spn23F/Spn23F_refGeneMrna.fa ...
# ---------------------------------------------------------------------------------------
# WARNING: 1826 exonic SNPs have WRONG reference alleles specified in your input file!
# WARNING: An example input line is <NC_011900.1	1951223	1951223	A	T	hom	.	.>
# WARNING: ANNOVAR can still annotate exonic_variant_function for the mutation correctly!
# WARNING: you may have used wrong -buildver, or specified incorrect reference allele, or used outdated mRNA FASTA file!
# ---------------------------------------------------------------------------------------
#
# Done with 1433 sequences
# WARNING: A total of 111 sequences will be ignored due to lack of correct ORF annotation
#
# ---------------------------------------------------------------------------------------
# WARNING: 2197 exonic SNPs have WRONG reference alleles specified in your input file!
# WARNING: An example input line is <NC_011900.1	1104518	1104518	G	A	hom	.	.>
# WARNING: ANNOVAR can still annotate exonic_variant_function for the mutation correctly!
# WARNING: you may have used wrong -buildver, or specified incorrect reference allele, or used outdated mRNA FASTA file!
# ---------------------------------------------------------------------------------------
#
# NOTICE: Output files are written to data/pyseer_dataset/annovar_files/snps.7622_4#7.avinput.variant_function, data/pyseer_dataset/annovar_files/snps.7622_4#7.avinput.exonic_variant_function
# NOTICE: Reading gene annotation from data/pyseer_dataset/Spn23F/Spn23F_refGene.txt ... 2025-04-15 21:02:59,549 - INFO - Successfully annotated data/pyseer_dataset/annovar_files/snps.7622_5#84.avinput
# 2025-04-15 21:02:59,554 - INFO - Successfully annotated data/pyseer_dataset/annovar_files/snps.6999_2#16.avinput
# Done with 2271 transcripts (including 70 without coding sequence annotation) for 2268 unique genes
# NOTICE: Output files are written to data/pyseer_dataset/annovar_files/snps.6925_1#53.avinput.variant_function, data/pyseer_dataset/annovar_files/snps.6925_1#53.avinput.exonic_variant_function
# NOTICE: Reading gene annotation from data/pyseer_dataset/Spn23F/Spn23F_refGene.txt ...
# ---------------------------------------------------------------------------------------
# WARNING: 2131 exonic SNPs have WRONG reference alleles specified in your input file!
# WARNING: An example input line is <NC_011900.1	882406	882406	G	A	hom	.	.>
# WARNING: ANNOVAR can still annotate exonic_variant_function for the mutation correctly!
# WARNING: you may have used wrong -buildver, or specified incorrect reference allele, or used outdated mRNA FASTA file!
# ---------------------------------------------------------------------------------------
#
# NOTICE: Processing next batch with 10117 unique variants in 10117 input lines
# NOTICE: Output files are written to data/pyseer_dataset/annovar_files/snps.6952_7#5.avinput.variant_function, data/pyseer_dataset/annovar_files/snps.6952_7#5.avinput.exonic_variant_function
# NOTICE: Reading gene annotation from data/pyseer_dataset/Spn23F/Spn23F_refGene.txt ... NOTICE: Output files are written to data/pyseer_dataset/annovar_files/snps.7622_5#70.avinput.variant_function, data/pyseer_dataset/annovar_files/snps.7622_5#70.avinput.exonic_variant_function
# NOTICE: Reading gene annotation from data/pyseer_dataset/Spn23F/Spn23F_refGene.txt ... 2025-04-15 21:02:59,667 - INFO - Successfully annotated data/pyseer_dataset/annovar_files/snps.6925_2#84.avinput
# Done with 2271 transcripts (including 70 without coding sequence annotation) for 2268 unique genes
#
# ---------------------------------------------------------------------------------------
# WARNING: 2033 exonic SNPs have WRONG reference alleles specified in your input file!
# WARNING: An example input line is <NC_011900.1	1116003	1116003	C	T	hom	.	.>
# WARNING: ANNOVAR can still annotate exonic_variant_function for the mutation correctly!
# WARNING: you may have used wrong -buildver, or specified incorrect reference allele, or used outdated mRNA FASTA file!
# ---------------------------------------------------------------------------------------
#
# Done with 2271 transcripts (including 70 without coding sequence annotation) for 2268 unique genes
# Done with 2271 transcripts (including 70 without coding sequence annotation) for 2268 unique genes
#
# ---------------------------------------------------------------------------------------
# WARNING: 2228 exonic SNPs have WRONG reference alleles specified in your input file!
# WARNING: An example input line is <NC_011900.1	784518	784518	A	T	hom	.	.>
# WARNING: ANNOVAR can still annotate exonic_variant_function for the mutation correctly!
# WARNING: you may have used wrong -buildver, or specified incorrect reference allele, or used outdated mRNA FASTA file!
# ---------------------------------------------------------------------------------------
#
# 2025-04-15 21:02:59,717 - INFO - Successfully annotated data/pyseer_dataset/annovar_files/snps.7622_3#52.avinput
# NOTICE: Processing next batch with 7643 unique variants in 7643 input lines
# 2025-04-15 21:02:59,727 - INFO - Successfully annotated data/pyseer_dataset/annovar_files/snps.7622_4#14.avinput
# NOTICE: Processing next batch with 7552 unique variants in 7552 input lines
# NOTICE: Processing next batch with 10010 unique variants in 10010 input lines
# NOTICE: Reading FASTA sequences from data/pyseer_dataset/Spn23F/Spn23F_refGeneMrna.fa ... Done with 1459 sequences
# WARNING: A total of 111 sequences will be ignored due to lack of correct ORF annotation
# NOTICE: Output files are written to data/pyseer_dataset/annovar_files/snps.7622_2#36.avinput.variant_function, data/pyseer_dataset/annovar_files/snps.7622_2#36.avinput.exonic_variant_function
# NOTICE: Reading gene annotation from data/pyseer_dataset/Spn23F/Spn23F_refGene.txt ... Done with 2271 transcripts (including 70 without coding sequence annotation) for 2268 unique genes
# NOTICE: Output files are written to data/pyseer_dataset/annovar_files/snps.7622_5#60.avinput.variant_function, data/pyseer_dataset/annovar_files/snps.7622_5#60.avinput.exonic_variant_function
# NOTICE: Reading gene annotation from data/pyseer_dataset/Spn23F/Spn23F_refGene.txt ... NOTICE: Output files are written to data/pyseer_dataset/annovar_files/snps.6999_1#3.avinput.variant_function, data/pyseer_dataset/annovar_files/snps.6999_1#3.avinput.exonic_variant_function
# NOTICE: Reading gene annotation from data/pyseer_dataset/Spn23F/Spn23F_refGene.txt ... Done with 2271 transcripts (including 70 without coding sequence annotation) for 2268 unique genes
# Done with 2271 transcripts (including 70 without coding sequence annotation) for 2268 unique genes
# NOTICE: Processing next batch with 11226 unique variants in 11226 input lines
#
# ---------------------------------------------------------------------------------------
# WARNING: 1898 exonic SNPs have WRONG reference alleles specified in your input file!
# WARNING: An example input line is <NC_011900.1	1312322	1312322	A	G	hom	.	.>
# WARNING: ANNOVAR can still annotate exonic_variant_function for the mutation correctly!
# WARNING: you may have used wrong -buildver, or specified incorrect reference allele, or used outdated mRNA FASTA file!
# ---------------------------------------------------------------------------------------
#
# 2025-04-15 21:02:59,952 - INFO - Successfully annotated data/pyseer_dataset/annovar_files/snps.7622_5#94.avinput
# NOTICE: Processing next batch with 11030 unique variants in 11030 input lines
# NOTICE: Processing next batch with 11002 unique variants in 11002 input lines
# NOTICE: Output files are written to data/pyseer_dataset/annovar_files/snps.7622_2#44.avinput.variant_function, data/pyseer_dataset/annovar_files/snps.7622_2#44.avinput.exonic_variant_function
# NOTICE: Reading gene annotation from data/pyseer_dataset/Spn23F/Spn23F_refGene.txt ... Done with 2271 transcripts (including 70 without coding sequence annotation) for 2268 unique genes
# NOTICE: Processing next batch with 10121 unique variants in 10121 input lines
# NOTICE: Reading FASTA sequences from data/pyseer_dataset/Spn23F/Spn23F_refGeneMrna.fa ... Done with 1351 sequences
# WARNING: A total of 111 sequences will be ignored due to lack of correct ORF annotation
# NOTICE: Reading FASTA sequences from data/pyseer_dataset/Spn23F/Spn23F_refGeneMrna.fa ... Done with 1350 sequences
# WARNING: A total of 111 sequences will be ignored due to lack of correct ORF annotation
#
# ---------------------------------------------------------------------------------------
# WARNING: 2707 exonic SNPs have WRONG reference alleles specified in your input file!
# WARNING: An example input line is <NC_011900.1	490424	490424	T	A	hom	.	.>
# WARNING: ANNOVAR can still annotate exonic_variant_function for the mutation correctly!
# WARNING: you may have used wrong -buildver, or specified incorrect reference allele, or used outdated mRNA FASTA file!
# ---------------------------------------------------------------------------------------
#
# 2025-04-15 21:03:01,333 - INFO - Successfully annotated data/pyseer_dataset/annovar_files/snps.7622_5#70.avinput
#
# ---------------------------------------------------------------------------------------
# WARNING: 2905 exonic SNPs have WRONG reference alleles specified in your input file!
# WARNING: An example input line is <NC_011900.1	1075944	1075944	T	C	hom	.	.>
# WARNING: ANNOVAR can still annotate exonic_variant_function for the mutation correctly!
# WARNING: you may have used wrong -buildver, or specified incorrect reference allele, or used outdated mRNA FASTA file!
# ---------------------------------------------------------------------------------------
#
# 2025-04-15 21:03:01,350 - INFO - Successfully annotated data/pyseer_dataset/annovar_files/snps.6925_1#53.avinput
# NOTICE: Output files are written to data/pyseer_dataset/annovar_files/snps.6952_4#1.avinput.variant_function, data/pyseer_dataset/annovar_files/snps.6952_4#1.avinput.exonic_variant_function
# NOTICE: Reading gene annotation from data/pyseer_dataset/Spn23F/Spn23F_refGene.txt ... Done with 2271 transcripts (including 70 without coding sequence annotation) for 2268 unique genes
# NOTICE: Output files are written to data/pyseer_dataset/annovar_files/snps.6930_8#10.avinput.variant_function, data/pyseer_dataset/annovar_files/snps.6930_8#10.avinput.exonic_variant_function
# NOTICE: Reading gene annotation from data/pyseer_dataset/Spn23F/Spn23F_refGene.txt ... NOTICE: Reading FASTA sequences from data/pyseer_dataset/Spn23F/Spn23F_refGeneMrna.fa ... Done with 2271 transcripts (including 70 without coding sequence annotation) for 2268 unique genes
# Done with 1452 sequences
# WARNING: A total of 111 sequences will be ignored due to lack of correct ORF annotation
# NOTICE: Processing next batch with 11785 unique variants in 11785 input lines
# NOTICE: Processing next batch with 11867 unique variants in 11867 input lines
#
# ---------------------------------------------------------------------------------------
# WARNING: 1948 exonic SNPs have WRONG reference alleles specified in your input file!
# WARNING: An example input line is <NC_011900.1	35499	35499	C	T	hom	.	.>
# WARNING: ANNOVAR can still annotate exonic_variant_function for the mutation correctly!
# WARNING: you may have used wrong -buildver, or specified incorrect reference allele, or used outdated mRNA FASTA file!
# ---------------------------------------------------------------------------------------
#
# NOTICE: Reading FASTA sequences from data/pyseer_dataset/Spn23F/Spn23F_refGeneMrna.fa ... Done with 1459 sequences
# WARNING: A total of 111 sequences will be ignored due to lack of correct ORF annotation
# 2025-04-15 21:03:01,678 - INFO - Successfully annotated data/pyseer_dataset/annovar_files/snps.7622_4#7.avinput
# NOTICE: Output files are written to data/pyseer_dataset/annovar_files/snps.6952_4#21.avinput.variant_function, data/pyseer_dataset/annovar_files/snps.6952_4#21.avinput.exonic_variant_function
# NOTICE: Reading gene annotation from data/pyseer_dataset/Spn23F/Spn23F_refGene.txt ...
# ---------------------------------------------------------------------------------------
# WARNING: 2187 exonic SNPs have WRONG reference alleles specified in your input file!
# WARNING: An example input line is <NC_011900.1	1515627	1515627	C	T	hom	.	.>
# WARNING: ANNOVAR can still annotate exonic_variant_function for the mutation correctly!
# WARNING: you may have used wrong -buildver, or specified incorrect reference allele, or used outdated mRNA FASTA file!
# ---------------------------------------------------------------------------------------
#
# 2025-04-15 21:03:01,845 - INFO - Successfully annotated data/pyseer_dataset/annovar_files/snps.6952_7#5.avinput
# Done with 2271 transcripts (including 70 without coding sequence annotation) for 2268 unique genes
# NOTICE: Processing next batch with 12194 unique variants in 12194 input lines
# NOTICE: Reading FASTA sequences from data/pyseer_dataset/Spn23F/Spn23F_refGeneMrna.fa ... Done with 1491 sequences
# WARNING: A total of 111 sequences will be ignored due to lack of correct ORF annotation
# NOTICE: Output files are written to data/pyseer_dataset/annovar_files/snps.6952_4#17.avinput.variant_function, data/pyseer_dataset/annovar_files/snps.6952_4#17.avinput.exonic_variant_function
# NOTICE: Reading gene annotation from data/pyseer_dataset/Spn23F/Spn23F_refGene.txt ... Done with 2271 transcripts (including 70 without coding sequence annotation) for 2268 unique genes
# NOTICE: Reading FASTA sequences from data/pyseer_dataset/Spn23F/Spn23F_refGeneMrna.fa ... NOTICE: Processing next batch with 10937 unique variants in 10937 input lines
# Done with 1480 sequences
# WARNING: A total of 111 sequences will be ignored due to lack of correct ORF annotation
# NOTICE: Reading FASTA sequences from data/pyseer_dataset/Spn23F/Spn23F_refGeneMrna.fa ... Done with 1440 sequences
# WARNING: A total of 111 sequences will be ignored due to lack of correct ORF annotation
# NOTICE: Reading FASTA sequences from data/pyseer_dataset/Spn23F/Spn23F_refGeneMrna.fa ... Done with 1538 sequences
# WARNING: A total of 111 sequences will be ignored due to lack of correct ORF annotation
#
# ---------------------------------------------------------------------------------------
# WARNING: 1949 exonic SNPs have WRONG reference alleles specified in your input file!
# WARNING: An example input line is <NC_011900.1	884355	884355	A	G	hom	.	.>
# WARNING: ANNOVAR can still annotate exonic_variant_function for the mutation correctly!
# WARNING: you may have used wrong -buildver, or specified incorrect reference allele, or used outdated mRNA FASTA file!
# ---------------------------------------------------------------------------------------
#
# 2025-04-15 21:03:02,168 - INFO - Successfully annotated data/pyseer_dataset/annovar_files/snps.6999_1#3.avinput
#
# ---------------------------------------------------------------------------------------
# WARNING: 2137 exonic SNPs have WRONG reference alleles specified in your input file!
# WARNING: An example input line is <NC_011900.1	1398249	1398249	G	A	hom	.	.>
# WARNING: ANNOVAR can still annotate exonic_variant_function for the mutation correctly!
# WARNING: you may have used wrong -buildver, or specified incorrect reference allele, or used outdated mRNA FASTA file!
# ---------------------------------------------------------------------------------------
#
#
# ---------------------------------------------------------------------------------------
# WARNING: 1928 exonic SNPs have WRONG reference alleles specified in your input file!
# WARNING: An example input line is <NC_011900.1	1336171	1336171	C	T	hom	.	.>
# WARNING: ANNOVAR can still annotate exonic_variant_function for the mutation correctly!
# WARNING: you may have used wrong -buildver, or specified incorrect reference allele, or used outdated mRNA FASTA file!
# ---------------------------------------------------------------------------------------
#
# 2025-04-15 21:03:02,278 - INFO - Successfully annotated data/pyseer_dataset/annovar_files/snps.7622_2#36.avinput
#
# ---------------------------------------------------------------------------------------
# WARNING: 1958 exonic SNPs have WRONG reference alleles specified in your input file!
# WARNING: An example input line is <NC_011900.1	1445360	1445360	G	A	hom	.	.>
# WARNING: ANNOVAR can still annotate exonic_variant_function for the mutation correctly!
# WARNING: you may have used wrong -buildver, or specified incorrect reference allele, or used outdated mRNA FASTA file!
# ---------------------------------------------------------------------------------------
#
# 2025-04-15 21:03:02,291 - INFO - Successfully annotated data/pyseer_dataset/annovar_files/snps.7622_2#44.avinput
# 2025-04-15 21:03:02,312 - INFO - Successfully annotated data/pyseer_dataset/annovar_files/snps.7622_5#60.avinput
# NOTICE: Output files are written to data/pyseer_dataset/annovar_files/snps.6999_1#13.avinput.variant_function, data/pyseer_dataset/annovar_files/snps.6999_1#13.avinput.exonic_variant_function
# NOTICE: Reading gene annotation from data/pyseer_dataset/Spn23F/Spn23F_refGene.txt ... Done with 2271 transcripts (including 70 without coding sequence annotation) for 2268 unique genes
# NOTICE: Output files are written to data/pyseer_dataset/annovar_files/snps.7622_3#80.avinput.variant_function, data/pyseer_dataset/annovar_files/snps.7622_3#80.avinput.exonic_variant_function
# NOTICE: Reading gene annotation from data/pyseer_dataset/Spn23F/Spn23F_refGene.txt ... NOTICE: Output files are written to data/pyseer_dataset/annovar_files/snps.7622_5#56.avinput.variant_function, data/pyseer_dataset/annovar_files/snps.7622_5#56.avinput.exonic_variant_function
# NOTICE: Reading gene annotation from data/pyseer_dataset/Spn23F/Spn23F_refGene.txt ... NOTICE: Processing next batch with 10021 unique variants in 10021 input lines
# Done with 2271 transcripts (including 70 without coding sequence annotation) for 2268 unique genes
# Done with 2271 transcripts (including 70 without coding sequence annotation) for 2268 unique genes
# NOTICE: Output files are written to data/pyseer_dataset/annovar_files/snps.7622_3#74.avinput.variant_function, data/pyseer_dataset/annovar_files/snps.7622_3#74.avinput.exonic_variant_function
# NOTICE: Reading gene annotation from data/pyseer_dataset/Spn23F/Spn23F_refGene.txt ... Done with 2271 transcripts (including 70 without coding sequence annotation) for 2268 unique genes
# NOTICE: Processing next batch with 12335 unique variants in 12335 input lines
# NOTICE: Processing next batch with 11163 unique variants in 11163 input lines
# NOTICE: Processing next batch with 10449 unique variants in 10449 input lines
# NOTICE: Reading FASTA sequences from data/pyseer_dataset/Spn23F/Spn23F_refGeneMrna.fa ... Done with 1533 sequences
# WARNING: A total of 111 sequences will be ignored due to lack of correct ORF annotation
# NOTICE: Reading FASTA sequences from data/pyseer_dataset/Spn23F/Spn23F_refGeneMrna.fa ... Done with 1506 sequences
# WARNING: A total of 111 sequences will be ignored due to lack of correct ORF annotation
#
# ---------------------------------------------------------------------------------------
# WARNING: 2728 exonic SNPs have WRONG reference alleles specified in your input file!
# WARNING: An example input line is <NC_011900.1	92692	92692	C	T	hom	.	.>
# WARNING: ANNOVAR can still annotate exonic_variant_function for the mutation correctly!
# WARNING: you may have used wrong -buildver, or specified incorrect reference allele, or used outdated mRNA FASTA file!
# ---------------------------------------------------------------------------------------
#
# 2025-04-15 21:03:03,997 - INFO - Successfully annotated data/pyseer_dataset/annovar_files/snps.6952_4#1.avinput
#
# ---------------------------------------------------------------------------------------
# WARNING: 3545 exonic SNPs have WRONG reference alleles specified in your input file!
# WARNING: An example input line is <NC_011900.1	2146764	2146764	C	T	hom	.	.>
# WARNING: ANNOVAR can still annotate exonic_variant_function for the mutation correctly!
# WARNING: you may have used wrong -buildver, or specified incorrect reference allele, or used outdated mRNA FASTA file!
# ---------------------------------------------------------------------------------------
#
# 2025-04-15 21:03:04,071 - INFO - Successfully annotated data/pyseer_dataset/annovar_files/snps.6930_8#10.avinput
# NOTICE: Output files are written to data/pyseer_dataset/annovar_files/snps.7622_4#32.avinput.variant_function, data/pyseer_dataset/annovar_files/snps.7622_4#32.avinput.exonic_variant_function
# NOTICE: Reading gene annotation from data/pyseer_dataset/Spn23F/Spn23F_refGene.txt ... Done with 2271 transcripts (including 70 without coding sequence annotation) for 2268 unique genes
# NOTICE: Reading FASTA sequences from data/pyseer_dataset/Spn23F/Spn23F_refGeneMrna.fa ... Done with 1486 sequences
# WARNING: A total of 111 sequences will be ignored due to lack of correct ORF annotation
# NOTICE: Processing next batch with 10904 unique variants in 10904 input lines
# NOTICE: Output files are written to data/pyseer_dataset/annovar_files/snps.7622_4#22.avinput.variant_function, data/pyseer_dataset/annovar_files/snps.7622_4#22.avinput.exonic_variant_function
# NOTICE: Reading gene annotation from data/pyseer_dataset/Spn23F/Spn23F_refGene.txt ... Done with 2271 transcripts (including 70 without coding sequence annotation) for 2268 unique genes
#
# ---------------------------------------------------------------------------------------
# WARNING: 1899 exonic SNPs have WRONG reference alleles specified in your input file!
# WARNING: An example input line is <NC_011900.1	1802748	1802748	A	G	hom	.	.>
# WARNING: ANNOVAR can still annotate exonic_variant_function for the mutation correctly!
# WARNING: you may have used wrong -buildver, or specified incorrect reference allele, or used outdated mRNA FASTA file!
# ---------------------------------------------------------------------------------------
#
# NOTICE: Processing next batch with 7884 unique variants in 7884 input lines
# NOTICE: Reading FASTA sequences from data/pyseer_dataset/Spn23F/Spn23F_refGeneMrna.fa ... Done with 1487 sequences
# WARNING: A total of 111 sequences will be ignored due to lack of correct ORF annotation
# 2025-04-15 21:03:04,348 - INFO - Successfully annotated data/pyseer_dataset/annovar_files/snps.6952_4#17.avinput
# NOTICE: Reading FASTA sequences from data/pyseer_dataset/Spn23F/Spn23F_refGeneMrna.fa ... Done with 1428 sequences
# WARNING: A total of 111 sequences will be ignored due to lack of correct ORF annotation
# NOTICE: Output files are written to data/pyseer_dataset/annovar_files/snps.7622_3#64.avinput.variant_function, data/pyseer_dataset/annovar_files/snps.7622_3#64.avinput.exonic_variant_function
# NOTICE: Reading gene annotation from data/pyseer_dataset/Spn23F/Spn23F_refGene.txt ...
# ---------------------------------------------------------------------------------------
# WARNING: 2623 exonic SNPs have WRONG reference alleles specified in your input file!
# WARNING: An example input line is <NC_011900.1	870067	870067	C	G	hom	.	.>
# WARNING: ANNOVAR can still annotate exonic_variant_function for the mutation correctly!
# WARNING: you may have used wrong -buildver, or specified incorrect reference allele, or used outdated mRNA FASTA file!
# ---------------------------------------------------------------------------------------
#
# Done with 2271 transcripts (including 70 without coding sequence annotation) for 2268 unique genes
# 2025-04-15 21:03:04,521 - INFO - Successfully annotated data/pyseer_dataset/annovar_files/snps.6999_1#13.avinput
#
# ---------------------------------------------------------------------------------------
# WARNING: 3647 exonic SNPs have WRONG reference alleles specified in your input file!
# WARNING: An example input line is <NC_011900.1	966182	966182	G	T	hom	.	.>
# WARNING: ANNOVAR can still annotate exonic_variant_function for the mutation correctly!
# WARNING: you may have used wrong -buildver, or specified incorrect reference allele, or used outdated mRNA FASTA file!
# ---------------------------------------------------------------------------------------
#
# 2025-04-15 21:03:04,560 - INFO - Successfully annotated data/pyseer_dataset/annovar_files/snps.6952_4#21.avinput
# NOTICE: Reading FASTA sequences from data/pyseer_dataset/Spn23F/Spn23F_refGeneMrna.fa ... Done with 1434 sequences
# WARNING: A total of 111 sequences will be ignored due to lack of correct ORF annotation
# NOTICE: Processing next batch with 10419 unique variants in 10419 input lines
# NOTICE: Reading FASTA sequences from data/pyseer_dataset/Spn23F/Spn23F_refGeneMrna.fa ... Done with 1481 sequences
# WARNING: A total of 111 sequences will be ignored due to lack of correct ORF annotation
# NOTICE: Output files are written to data/pyseer_dataset/annovar_files/snps.6925_1#65.avinput.variant_function, data/pyseer_dataset/annovar_files/snps.6925_1#65.avinput.exonic_variant_function
# NOTICE: Reading gene annotation from data/pyseer_dataset/Spn23F/Spn23F_refGene.txt ... Done with 2271 transcripts (including 70 without coding sequence annotation) for 2268 unique genes
# NOTICE: Output files are written to data/pyseer_dataset/annovar_files/snps.6925_2#79.avinput.variant_function, data/pyseer_dataset/annovar_files/snps.6925_2#79.avinput.exonic_variant_function
# NOTICE: Reading gene annotation from data/pyseer_dataset/Spn23F/Spn23F_refGene.txt ...
# ---------------------------------------------------------------------------------------
# WARNING: 2229 exonic SNPs have WRONG reference alleles specified in your input file!
# WARNING: An example input line is <NC_011900.1	1071040	1071040	A	G	hom	.	.>
# WARNING: ANNOVAR can still annotate exonic_variant_function for the mutation correctly!
# WARNING: you may have used wrong -buildver, or specified incorrect reference allele, or used outdated mRNA FASTA file!
# ---------------------------------------------------------------------------------------
#
# Done with 2271 transcripts (including 70 without coding sequence annotation) for 2268 unique genes
# NOTICE: Processing next batch with 10390 unique variants in 10390 input lines
# 2025-04-15 21:03:04,748 - INFO - Successfully annotated data/pyseer_dataset/annovar_files/snps.7622_3#74.avinput
# NOTICE: Processing next batch with 10652 unique variants in 10652 input lines
#
# ---------------------------------------------------------------------------------------
# WARNING: 2328 exonic SNPs have WRONG reference alleles specified in your input file!
# WARNING: An example input line is <NC_011900.1	2104901	2104901	G	A	hom	.	.>
# WARNING: ANNOVAR can still annotate exonic_variant_function for the mutation correctly!
# WARNING: you may have used wrong -buildver, or specified incorrect reference allele, or used outdated mRNA FASTA file!
# ---------------------------------------------------------------------------------------
#
# 2025-04-15 21:03:04,834 - INFO - Successfully annotated data/pyseer_dataset/annovar_files/snps.7622_5#56.avinput
# NOTICE: Output files are written to data/pyseer_dataset/annovar_files/snps.6999_2#20.avinput.variant_function, data/pyseer_dataset/annovar_files/snps.6999_2#20.avinput.exonic_variant_function
# NOTICE: Reading gene annotation from data/pyseer_dataset/Spn23F/Spn23F_refGene.txt ... NOTICE: Reading FASTA sequences from data/pyseer_dataset/Spn23F/Spn23F_refGeneMrna.fa ... Done with 1438 sequences
# WARNING: A total of 111 sequences will be ignored due to lack of correct ORF annotation
# Done with 2271 transcripts (including 70 without coding sequence annotation) for 2268 unique genes
# NOTICE: Output files are written to data/pyseer_dataset/annovar_files/snps.6952_4#8.avinput.variant_function, data/pyseer_dataset/annovar_files/snps.6952_4#8.avinput.exonic_variant_function
# NOTICE: Reading gene annotation from data/pyseer_dataset/Spn23F/Spn23F_refGene.txt ... NOTICE: Processing next batch with 10445 unique variants in 10445 input lines
# Done with 2271 transcripts (including 70 without coding sequence annotation) for 2268 unique genes
# NOTICE: Processing next batch with 10684 unique variants in 10684 input lines
#
# ---------------------------------------------------------------------------------------
# WARNING: 2000 exonic SNPs have WRONG reference alleles specified in your input file!
# WARNING: An example input line is <NC_011900.1	284547	284547	G	A	hom	.	.>
# WARNING: ANNOVAR can still annotate exonic_variant_function for the mutation correctly!
# WARNING: you may have used wrong -buildver, or specified incorrect reference allele, or used outdated mRNA FASTA file!
# ---------------------------------------------------------------------------------------
#
# 2025-04-15 21:03:05,130 - INFO - Successfully annotated data/pyseer_dataset/annovar_files/snps.7622_3#80.avinput
# NOTICE: Output files are written to data/pyseer_dataset/annovar_files/snps.6930_8#7.avinput.variant_function, data/pyseer_dataset/annovar_files/snps.6930_8#7.avinput.exonic_variant_function
# NOTICE: Reading gene annotation from data/pyseer_dataset/Spn23F/Spn23F_refGene.txt ... Done with 2271 transcripts (including 70 without coding sequence annotation) for 2268 unique genes
# NOTICE: Processing next batch with 10778 unique variants in 10778 input lines
# NOTICE: Reading FASTA sequences from data/pyseer_dataset/Spn23F/Spn23F_refGeneMrna.fa ... Done with 1343 sequences
# WARNING: A total of 111 sequences will be ignored due to lack of correct ORF annotation
#
# ---------------------------------------------------------------------------------------
# WARNING: 3050 exonic SNPs have WRONG reference alleles specified in your input file!
# WARNING: An example input line is <NC_011900.1	206398	206398	G	A	hom	.	.>
# WARNING: ANNOVAR can still annotate exonic_variant_function for the mutation correctly!
# WARNING: you may have used wrong -buildver, or specified incorrect reference allele, or used outdated mRNA FASTA file!
# ---------------------------------------------------------------------------------------
#
# 2025-04-15 21:03:05,924 - INFO - Successfully annotated data/pyseer_dataset/annovar_files/snps.7622_4#22.avinput
# NOTICE: Output files are written to data/pyseer_dataset/annovar_files/snps.6930_8#19.avinput.variant_function, data/pyseer_dataset/annovar_files/snps.6930_8#19.avinput.exonic_variant_function
# NOTICE: Reading gene annotation from data/pyseer_dataset/Spn23F/Spn23F_refGene.txt ... Done with 2271 transcripts (including 70 without coding sequence annotation) for 2268 unique genes
# NOTICE: Processing next batch with 11135 unique variants in 11135 input lines
# NOTICE: Reading FASTA sequences from data/pyseer_dataset/Spn23F/Spn23F_refGeneMrna.fa ... Done with 1486 sequences
# WARNING: A total of 111 sequences will be ignored due to lack of correct ORF annotation
#
# ---------------------------------------------------------------------------------------
# WARNING: 2318 exonic SNPs have WRONG reference alleles specified in your input file!
# WARNING: An example input line is <NC_011900.1	1421868	1421868	G	A	hom	.	.>
# WARNING: ANNOVAR can still annotate exonic_variant_function for the mutation correctly!
# WARNING: you may have used wrong -buildver, or specified incorrect reference allele, or used outdated mRNA FASTA file!
# ---------------------------------------------------------------------------------------
#
# 2025-04-15 21:03:06,495 - INFO - Successfully annotated data/pyseer_dataset/annovar_files/snps.7622_4#32.avinput
# NOTICE: Reading FASTA sequences from data/pyseer_dataset/Spn23F/Spn23F_refGeneMrna.fa ... NOTICE: Output files are written to data/pyseer_dataset/annovar_files/snps.7622_5#79.avinput.variant_function, data/pyseer_dataset/annovar_files/snps.7622_5#79.avinput.exonic_variant_function
# NOTICE: Reading gene annotation from data/pyseer_dataset/Spn23F/Spn23F_refGene.txt ... Done with 1473 sequences
# WARNING: A total of 111 sequences will be ignored due to lack of correct ORF annotation
# Done with 2271 transcripts (including 70 without coding sequence annotation) for 2268 unique genes
# NOTICE: Processing next batch with 10850 unique variants in 10850 input lines
#
# ---------------------------------------------------------------------------------------
# WARNING: 2288 exonic SNPs have WRONG reference alleles specified in your input file!
# WARNING: An example input line is <NC_011900.1	876572	876572	G	A	hom	.	.>
# WARNING: ANNOVAR can still annotate exonic_variant_function for the mutation correctly!
# WARNING: you may have used wrong -buildver, or specified incorrect reference allele, or used outdated mRNA FASTA file!
# ---------------------------------------------------------------------------------------
#
# NOTICE: Reading FASTA sequences from data/pyseer_dataset/Spn23F/Spn23F_refGeneMrna.fa ... 2025-04-15 21:03:06,801 - INFO - Successfully annotated data/pyseer_dataset/annovar_files/snps.7622_3#64.avinput
# Done with 1478 sequences
# WARNING: A total of 111 sequences will be ignored due to lack of correct ORF annotation
# NOTICE: Reading FASTA sequences from data/pyseer_dataset/Spn23F/Spn23F_refGeneMrna.fa ... Done with 1510 sequences
# WARNING: A total of 111 sequences will be ignored due to lack of correct ORF annotation
# NOTICE: Output files are written to data/pyseer_dataset/annovar_files/snps.7622_2#6.avinput.variant_function, data/pyseer_dataset/annovar_files/snps.7622_2#6.avinput.exonic_variant_function
# NOTICE: Reading gene annotation from data/pyseer_dataset/Spn23F/Spn23F_refGene.txt ...
# ---------------------------------------------------------------------------------------
# WARNING: 2128 exonic SNPs have WRONG reference alleles specified in your input file!
# WARNING: An example input line is <NC_011900.1	2133577	2133577	A	G	hom	.	.>
# WARNING: ANNOVAR can still annotate exonic_variant_function for the mutation correctly!
# WARNING: you may have used wrong -buildver, or specified incorrect reference allele, or used outdated mRNA FASTA file!
# ---------------------------------------------------------------------------------------
#
# Done with 2271 transcripts (including 70 without coding sequence annotation) for 2268 unique genes
# 2025-04-15 21:03:06,961 - INFO - Successfully annotated data/pyseer_dataset/annovar_files/snps.6925_1#65.avinput
# NOTICE: Reading FASTA sequences from data/pyseer_dataset/Spn23F/Spn23F_refGeneMrna.fa ... Done with 1469 sequences
# WARNING: A total of 111 sequences will be ignored due to lack of correct ORF annotation
#
# ---------------------------------------------------------------------------------------
# WARNING: 2168 exonic SNPs have WRONG reference alleles specified in your input file!
# WARNING: An example input line is <NC_011900.1	2006732	2006732	T	C	hom	.	.>
# WARNING: ANNOVAR can still annotate exonic_variant_function for the mutation correctly!
# WARNING: you may have used wrong -buildver, or specified incorrect reference allele, or used outdated mRNA FASTA file!
# ---------------------------------------------------------------------------------------
#
# 2025-04-15 21:03:07,039 - INFO - Successfully annotated data/pyseer_dataset/annovar_files/snps.6925_2#79.avinput
# NOTICE: Processing next batch with 11599 unique variants in 11599 input lines
# NOTICE: Reading FASTA sequences from data/pyseer_dataset/Spn23F/Spn23F_refGeneMrna.fa ... Done with 1482 sequences
# WARNING: A total of 111 sequences will be ignored due to lack of correct ORF annotation
# NOTICE: Output files are written to data/pyseer_dataset/annovar_files/snps.7622_4#40.avinput.variant_function, data/pyseer_dataset/annovar_files/snps.7622_4#40.avinput.exonic_variant_function
# NOTICE: Reading gene annotation from data/pyseer_dataset/Spn23F/Spn23F_refGene.txt ... Done with 2271 transcripts (including 70 without coding sequence annotation) for 2268 unique genes
# NOTICE: Output files are written to data/pyseer_dataset/annovar_files/snps.6999_1#12.avinput.variant_function, data/pyseer_dataset/annovar_files/snps.6999_1#12.avinput.exonic_variant_function
# NOTICE: Reading gene annotation from data/pyseer_dataset/Spn23F/Spn23F_refGene.txt ...
# ---------------------------------------------------------------------------------------
# WARNING: 1973 exonic SNPs have WRONG reference alleles specified in your input file!
# WARNING: An example input line is <NC_011900.1	1847423	1847423	G	A	hom	.	.>
# WARNING: ANNOVAR can still annotate exonic_variant_function for the mutation correctly!
# WARNING: you may have used wrong -buildver, or specified incorrect reference allele, or used outdated mRNA FASTA file!
# ---------------------------------------------------------------------------------------
#
# NOTICE: Processing next batch with 8578 unique variants in 8578 input lines
# 2025-04-15 21:03:07,205 - INFO - Successfully annotated data/pyseer_dataset/annovar_files/snps.6999_2#20.avinput
# Done with 2271 transcripts (including 70 without coding sequence annotation) for 2268 unique genes
#
# ---------------------------------------------------------------------------------------
# WARNING: 2081 exonic SNPs have WRONG reference alleles specified in your input file!
# WARNING: An example input line is <NC_011900.1	99278	99278	C	T	hom	.	.>
# WARNING: ANNOVAR can still annotate exonic_variant_function for the mutation correctly!
# WARNING: you may have used wrong -buildver, or specified incorrect reference allele, or used outdated mRNA FASTA file!
# ---------------------------------------------------------------------------------------
#
# 2025-04-15 21:03:07,242 - INFO - Successfully annotated data/pyseer_dataset/annovar_files/snps.6952_4#8.avinput
# NOTICE: Processing next batch with 9837 unique variants in 9837 input lines
# NOTICE: Output files are written to data/pyseer_dataset/annovar_files/snps.6952_4#16.avinput.variant_function, data/pyseer_dataset/annovar_files/snps.6952_4#16.avinput.exonic_variant_function
# NOTICE: Reading gene annotation from data/pyseer_dataset/Spn23F/Spn23F_refGene.txt ... Done with 2271 transcripts (including 70 without coding sequence annotation) for 2268 unique genes
# NOTICE: Output files are written to data/pyseer_dataset/annovar_files/snps.7622_3#81.avinput.variant_function, data/pyseer_dataset/annovar_files/snps.7622_3#81.avinput.exonic_variant_function
# NOTICE: Reading gene annotation from data/pyseer_dataset/Spn23F/Spn23F_refGene.txt ... NOTICE: Reading FASTA sequences from data/pyseer_dataset/Spn23F/Spn23F_refGeneMrna.fa ... Done with 1429 sequences
# WARNING: A total of 111 sequences will be ignored due to lack of correct ORF annotation
# Done with 2271 transcripts (including 70 without coding sequence annotation) for 2268 unique genes
# NOTICE: Processing next batch with 10282 unique variants in 10282 input lines
# NOTICE: Processing next batch with 12037 unique variants in 12037 input lines
#
# ---------------------------------------------------------------------------------------
# WARNING: 2527 exonic SNPs have WRONG reference alleles specified in your input file!
# WARNING: An example input line is <NC_011900.1	126669	126669	T	C	hom	.	.>
# WARNING: ANNOVAR can still annotate exonic_variant_function for the mutation correctly!
# WARNING: you may have used wrong -buildver, or specified incorrect reference allele, or used outdated mRNA FASTA file!
# ---------------------------------------------------------------------------------------
#
# 2025-04-15 21:03:07,579 - INFO - Successfully annotated data/pyseer_dataset/annovar_files/snps.6930_8#7.avinput
# NOTICE: Output files are written to data/pyseer_dataset/annovar_files/snps.7622_3#91.avinput.variant_function, data/pyseer_dataset/annovar_files/snps.7622_3#91.avinput.exonic_variant_function
# NOTICE: Reading gene annotation from data/pyseer_dataset/Spn23F/Spn23F_refGene.txt ... Done with 2271 transcripts (including 70 without coding sequence annotation) for 2268 unique genes
# NOTICE: Processing next batch with 11587 unique variants in 11587 input lines
# NOTICE: Reading FASTA sequences from data/pyseer_dataset/Spn23F/Spn23F_refGeneMrna.fa ... Done with 1428 sequences
# WARNING: A total of 111 sequences will be ignored due to lack of correct ORF annotation
#
# ---------------------------------------------------------------------------------------
# WARNING: 1862 exonic SNPs have WRONG reference alleles specified in your input file!
# WARNING: An example input line is <NC_011900.1	696153	696153	C	T	hom	.	.>
# WARNING: ANNOVAR can still annotate exonic_variant_function for the mutation correctly!
# WARNING: you may have used wrong -buildver, or specified incorrect reference allele, or used outdated mRNA FASTA file!
# ---------------------------------------------------------------------------------------
#
# ...
# WARNING: An example input line is <NC_011900.1	1640033	1640033	T	C	hom	.	.>
# WARNING: ANNOVAR can still annotate exonic_variant_function for the mutation correctly!
# WARNING: you may have used wrong -buildver, or specified incorrect reference allele, or used outdated mRNA FASTA file!
# ---------------------------------------------------------------------------------------
#
# 2025-04-15 21:04:26,715 - INFO - Successfully annotated data/pyseer_dataset/annovar_files/snps.7622_3#78.avinput
# NOTICE: Output files are written to data/pyseer_dataset/annovar_files/snps.7622_5#91.avinput.variant_function, data/pyseer_dataset/annovar_files/snps.7622_5#91.avinput.exonic_variant_function
# NOTICE: Reading gene annotation from data/pyseer_dataset/Spn23F/Spn23F_refGene.txt ... Done with 2271 transcripts (including 70 without coding sequence annotation) for 2268 unique genes
# NOTICE: Processing next batch with 10131 unique variants in 10131 input lines
# NOTICE: Reading FASTA sequences from data/pyseer_dataset/Spn23F/Spn23F_refGeneMrna.fa ... Done with 1346 sequences
# WARNING: A total of 111 sequences will be ignored due to lack of correct ORF annotation
# NOTICE: Reading FASTA sequences from data/pyseer_dataset/Spn23F/Spn23F_refGeneMrna.fa ... Done with 1430 sequences
# WARNING: A total of 111 sequences will be ignored due to lack of correct ORF annotation
#
# ---------------------------------------------------------------------------------------
# WARNING: 3062 exonic SNPs have WRONG reference alleles specified in your input file!
# WARNING: An example input line is <NC_011900.1	976669	976669	G	A	hom	.	.>
# WARNING: ANNOVAR can still annotate exonic_variant_function for the mutation correctly!
# WARNING: you may have used wrong -buildver, or specified incorrect reference allele, or used outdated mRNA FASTA file!
# ---------------------------------------------------------------------------------------
#
# NOTICE: Reading FASTA sequences from data/pyseer_dataset/Spn23F/Spn23F_refGeneMrna.fa ... 2025-04-15 21:04:27,445 - INFO - Successfully annotated data/pyseer_dataset/annovar_files/snps.6925_2#91.avinput
# NOTICE: Reading FASTA sequences from data/pyseer_dataset/Spn23F/Spn23F_refGeneMrna.fa ... Done with 1456 sequences
# WARNING: A total of 111 sequences will be ignored due to lack of correct ORF annotation
# Done with 1554 sequences
# WARNING: A total of 111 sequences will be ignored due to lack of correct ORF annotation
#
# ---------------------------------------------------------------------------------------
# WARNING: 2223 exonic SNPs have WRONG reference alleles specified in your input file!
# WARNING: An example input line is <NC_011900.1	1033124	1033124	T	G	hom	.	.>
# WARNING: ANNOVAR can still annotate exonic_variant_function for the mutation correctly!
# WARNING: you may have used wrong -buildver, or specified incorrect reference allele, or used outdated mRNA FASTA file!
# ---------------------------------------------------------------------------------------
#
# 2025-04-15 21:04:27,514 - INFO - Successfully annotated data/pyseer_dataset/annovar_files/snps.6925_1#69.avinput
# NOTICE: Output files are written to data/pyseer_dataset/annovar_files/snps.6952_7#17.avinput.variant_function, data/pyseer_dataset/annovar_files/snps.6952_7#17.avinput.exonic_variant_function
# NOTICE: Reading gene annotation from data/pyseer_dataset/Spn23F/Spn23F_refGene.txt ... Done with 2271 transcripts (including 70 without coding sequence annotation) for 2268 unique genes
#
# ---------------------------------------------------------------------------------------
# WARNING: 2365 exonic SNPs have WRONG reference alleles specified in your input file!
# WARNING: An example input line is <NC_011900.1	1889707	1889707	T	C	hom	.	.>
# WARNING: ANNOVAR can still annotate exonic_variant_function for the mutation correctly!
# WARNING: you may have used wrong -buildver, or specified incorrect reference allele, or used outdated mRNA FASTA file!
# ---------------------------------------------------------------------------------------
#
#
# ---------------------------------------------------------------------------------------
# WARNING: 2636 exonic SNPs have WRONG reference alleles specified in your input file!
# WARNING: An example input line is <NC_011900.1	1721446	1721446	T	C	hom	.	.>
# WARNING: ANNOVAR can still annotate exonic_variant_function for the mutation correctly!
# WARNING: you may have used wrong -buildver, or specified incorrect reference allele, or used outdated mRNA FASTA file!
# ---------------------------------------------------------------------------------------
#
# 2025-04-15 21:04:27,638 - INFO - Successfully annotated data/pyseer_dataset/annovar_files/snps.6930_8#15.avinput
# NOTICE: Output files are written to data/pyseer_dataset/annovar_files/snps.7622_4#2.avinput.variant_function, data/pyseer_dataset/annovar_files/snps.7622_4#2.avinput.exonic_variant_function
# NOTICE: Reading gene annotation from data/pyseer_dataset/Spn23F/Spn23F_refGene.txt ... NOTICE: Reading FASTA sequences from data/pyseer_dataset/Spn23F/Spn23F_refGeneMrna.fa ... 2025-04-15 21:04:27,657 - INFO - Successfully annotated data/pyseer_dataset/annovar_files/snps.7622_3#68.avinput
# NOTICE: Processing next batch with 10344 unique variants in 10344 input lines
# NOTICE: Reading FASTA sequences from data/pyseer_dataset/Spn23F/Spn23F_refGeneMrna.fa ... Done with 1438 sequences
# WARNING: A total of 111 sequences will be ignored due to lack of correct ORF annotation
# Done with 2271 transcripts (including 70 without coding sequence annotation) for 2268 unique genes
# Done with 1461 sequences
# WARNING: A total of 111 sequences will be ignored due to lack of correct ORF annotation
# NOTICE: Processing next batch with 9995 unique variants in 9995 input lines
# NOTICE: Output files are written to data/pyseer_dataset/annovar_files/snps.7622_3#57.avinput.variant_function, data/pyseer_dataset/annovar_files/snps.7622_3#57.avinput.exonic_variant_function
# NOTICE: Reading gene annotation from data/pyseer_dataset/Spn23F/Spn23F_refGene.txt ...
# ---------------------------------------------------------------------------------------
# WARNING: 2262 exonic SNPs have WRONG reference alleles specified in your input file!
# WARNING: An example input line is <NC_011900.1	1648133	1648133	C	T	hom	.	.>
# WARNING: ANNOVAR can still annotate exonic_variant_function for the mutation correctly!
# WARNING: you may have used wrong -buildver, or specified incorrect reference allele, or used outdated mRNA FASTA file!
# ---------------------------------------------------------------------------------------
#
#
# ---------------------------------------------------------------------------------------
# WARNING: 2169 exonic SNPs have WRONG reference alleles specified in your input file!
# WARNING: An example input line is <NC_011900.1	1777494	1777494	G	A	hom	.	.>
# WARNING: ANNOVAR can still annotate exonic_variant_function for the mutation correctly!
# WARNING: you may have used wrong -buildver, or specified incorrect reference allele, or used outdated mRNA FASTA file!
# ---------------------------------------------------------------------------------------
#
# 2025-04-15 21:04:27,807 - INFO - Successfully annotated data/pyseer_dataset/annovar_files/snps.6952_4#4.avinput
# Done with 2271 transcripts (including 70 without coding sequence annotation) for 2268 unique genes
# 2025-04-15 21:04:27,819 - INFO - Successfully annotated data/pyseer_dataset/annovar_files/snps.6925_2#81.avinput
# NOTICE: Output files are written to data/pyseer_dataset/annovar_files/snps.7622_4#11.avinput.variant_function, data/pyseer_dataset/annovar_files/snps.7622_4#11.avinput.exonic_variant_function
# NOTICE: Reading gene annotation from data/pyseer_dataset/Spn23F/Spn23F_refGene.txt ... Done with 2271 transcripts (including 70 without coding sequence annotation) for 2268 unique genes
# NOTICE: Processing next batch with 7739 unique variants in 7739 input lines
# NOTICE: Processing next batch with 10154 unique variants in 10154 input lines
# NOTICE: Output files are written to data/pyseer_dataset/annovar_files/snps.6925_1#56.avinput.variant_function, data/pyseer_dataset/annovar_files/snps.6925_1#56.avinput.exonic_variant_function
# NOTICE: Reading gene annotation from data/pyseer_dataset/Spn23F/Spn23F_refGene.txt ... Done with 2271 transcripts (including 70 without coding sequence annotation) for 2268 unique genes
# NOTICE: Output files are written to data/pyseer_dataset/annovar_files/snps.6999_2#13.avinput.variant_function, data/pyseer_dataset/annovar_files/snps.6999_2#13.avinput.exonic_variant_function
# NOTICE: Reading gene annotation from data/pyseer_dataset/Spn23F/Spn23F_refGene.txt ... Done with 2271 transcripts (including 70 without coding sequence annotation) for 2268 unique genes
# NOTICE: Processing next batch with 11112 unique variants in 11112 input lines
# NOTICE: Processing next batch with 12199 unique variants in 12199 input lines
# NOTICE: Reading FASTA sequences from data/pyseer_dataset/Spn23F/Spn23F_refGeneMrna.fa ... Done with 1452 sequences
# WARNING: A total of 111 sequences will be ignored due to lack of correct ORF annotation
#
# ---------------------------------------------------------------------------------------
# WARNING: 2359 exonic SNPs have WRONG reference alleles specified in your input file!
# WARNING: An example input line is <NC_011900.1	622817	622817	C	T	hom	.	.>
# WARNING: ANNOVAR can still annotate exonic_variant_function for the mutation correctly!
# WARNING: you may have used wrong -buildver, or specified incorrect reference allele, or used outdated mRNA FASTA file!
# ---------------------------------------------------------------------------------------
#
# 2025-04-15 21:04:28,724 - INFO - Successfully annotated data/pyseer_dataset/annovar_files/snps.7622_5#81.avinput
# NOTICE: Reading FASTA sequences from data/pyseer_dataset/Spn23F/Spn23F_refGeneMrna.fa ... Done with 1456 sequences
# WARNING: A total of 111 sequences will be ignored due to lack of correct ORF annotation
#
# ---------------------------------------------------------------------------------------
# WARNING: 1976 exonic SNPs have WRONG reference alleles specified in your input file!
# WARNING: An example input line is <NC_011900.1	123165	123165	C	T	hom	.	.>
# WARNING: ANNOVAR can still annotate exonic_variant_function for the mutation correctly!
# WARNING: you may have used wrong -buildver, or specified incorrect reference allele, or used outdated mRNA FASTA file!
# ---------------------------------------------------------------------------------------
#
# 2025-04-15 21:04:29,072 - INFO - Successfully annotated data/pyseer_dataset/annovar_files/snps.7622_5#91.avinput
# NOTICE: Reading FASTA sequences from data/pyseer_dataset/Spn23F/Spn23F_refGeneMrna.fa ... Done with 1353 sequences
# WARNING: A total of 111 sequences will be ignored due to lack of correct ORF annotation
#
# ---------------------------------------------------------------------------------------
# WARNING: 3026 exonic SNPs have WRONG reference alleles specified in your input file!
# WARNING: An example input line is <NC_011900.1	707732	707732	A	C	hom	.	.>
# WARNING: ANNOVAR can still annotate exonic_variant_function for the mutation correctly!
# WARNING: you may have used wrong -buildver, or specified incorrect reference allele, or used outdated mRNA FASTA file!
# ---------------------------------------------------------------------------------------
#
# 2025-04-15 21:04:29,436 - INFO - Successfully annotated data/pyseer_dataset/annovar_files/snps.7622_3#57.avinput
# NOTICE: Reading FASTA sequences from data/pyseer_dataset/Spn23F/Spn23F_refGeneMrna.fa ... NOTICE: Reading FASTA sequences from data/pyseer_dataset/Spn23F/Spn23F_refGeneMrna.fa ... Done with 1433 sequences
# WARNING: A total of 111 sequences will be ignored due to lack of correct ORF annotation
# Done with 1450 sequences
# WARNING: A total of 111 sequences will be ignored due to lack of correct ORF annotation
#
# ---------------------------------------------------------------------------------------
# WARNING: 2206 exonic SNPs have WRONG reference alleles specified in your input file!
# WARNING: An example input line is <NC_011900.1	737946	737946	C	A	hom	.	.>
# WARNING: ANNOVAR can still annotate exonic_variant_function for the mutation correctly!
# WARNING: you may have used wrong -buildver, or specified incorrect reference allele, or used outdated mRNA FASTA file!
# ---------------------------------------------------------------------------------------
#
#
# ---------------------------------------------------------------------------------------
# WARNING: 1972 exonic SNPs have WRONG reference alleles specified in your input file!
# WARNING: An example input line is <NC_011900.1	3397	3397	G	A	hom	.	.>
# WARNING: ANNOVAR can still annotate exonic_variant_function for the mutation correctly!
# WARNING: you may have used wrong -buildver, or specified incorrect reference allele, or used outdated mRNA FASTA file!
# ---------------------------------------------------------------------------------------
#
# 2025-04-15 21:04:29,707 - INFO - Successfully annotated data/pyseer_dataset/annovar_files/snps.6952_7#17.avinput
# 2025-04-15 21:04:29,710 - INFO - Successfully annotated data/pyseer_dataset/annovar_files/snps.7622_4#2.avinput
# NOTICE: Reading FASTA sequences from data/pyseer_dataset/Spn23F/Spn23F_refGeneMrna.fa ... Done with 1441 sequences
# WARNING: A total of 111 sequences will be ignored due to lack of correct ORF annotation
#
# ---------------------------------------------------------------------------------------
# WARNING: 1947 exonic SNPs have WRONG reference alleles specified in your input file!
# WARNING: An example input line is <NC_011900.1	1881469	1881469	A	G	hom	.	.>
# WARNING: ANNOVAR can still annotate exonic_variant_function for the mutation correctly!
# WARNING: you may have used wrong -buildver, or specified incorrect reference allele, or used outdated mRNA FASTA file!
# ---------------------------------------------------------------------------------------
#
# 2025-04-15 21:04:29,960 - INFO - Successfully annotated data/pyseer_dataset/annovar_files/snps.7622_4#11.avinput
# NOTICE: Reading FASTA sequences from data/pyseer_dataset/Spn23F/Spn23F_refGeneMrna.fa ... Done with 1469 sequences
# WARNING: A total of 111 sequences will be ignored due to lack of correct ORF annotation
# NOTICE: Reading FASTA sequences from data/pyseer_dataset/Spn23F/Spn23F_refGeneMrna.fa ... Done with 1519 sequences
# WARNING: A total of 111 sequences will be ignored due to lack of correct ORF annotation
#
# ---------------------------------------------------------------------------------------
# WARNING: 2794 exonic SNPs have WRONG reference alleles specified in your input file!
# WARNING: An example input line is <NC_011900.1	1824656	1824656	A	G	hom	.	.>
# WARNING: ANNOVAR can still annotate exonic_variant_function for the mutation correctly!
# WARNING: you may have used wrong -buildver, or specified incorrect reference allele, or used outdated mRNA FASTA file!
# ---------------------------------------------------------------------------------------
#
# 2025-04-15 21:04:30,150 - INFO - Successfully annotated data/pyseer_dataset/annovar_files/snps.6925_1#56.avinput
#
# ---------------------------------------------------------------------------------------
# WARNING: 2015 exonic SNPs have WRONG reference alleles specified in your input file!
# WARNING: An example input line is <NC_011900.1	656554	656554	C	T	hom	.	.>
# WARNING: ANNOVAR can still annotate exonic_variant_function for the mutation correctly!
# WARNING: you may have used wrong -buildver, or specified incorrect reference allele, or used outdated mRNA FASTA file!
# ---------------------------------------------------------------------------------------
#
# 2025-04-15 21:04:30,259 - INFO - Successfully annotated data/pyseer_dataset/annovar_files/snps.6999_2#13.avinput
# 2025-04-15 21:04:30,373 - INFO - Completed parallel annotation of avinput files.
# Annotated 300 avinput files in 93.93 seconds.
# Annotated avinput files are saved in data/pyseer_dataset/annovar_files/.

# %% [markdown]
# ### **Step 2: Build Gene Mutation Table:**
#
# For each sample:
# 1. **Build gene maps** from the gff3 file.
# 2. Compile mutation info **gene-by-gene**.
# 3. **Determine mutation types**.
#     - binary: mutation or wildtype
#     - multiple: nonsense, nonstop, missense, silent or wildtype
# 4. **Output mutation types per gene** across all samples:
#
#     |Gene|Sample1|Sample2|Sample3|
#     |:-:|:-:|:-:|:-:|
#     |g1|m|w|w|m|
#     |g2|m|m|m|w|
#     |g3|w|w|w|m|
#     |...|...|...|...|
#
# **Import functions and annotation data**

# %%
from muggwas import compile_gene_mutations, write_gene_mutation_summary, write_gene_annotation_summary

# Directory containing the ANNOVAR output files
annovar_output_dir = 'pyseer_dataset/annovar_files'
# Read gff3 to build gene maps
gff_file = 'pyseer_dataset/Spn23F/Spn23F.gff3'
# Write the mutation types to a tab delimited file
output_mutation_table = 'pyseer_dataset/gene_mutation_summary.txt'
# Write the annotations to a tab delimited file
output_annotation_table = 'pyseer_dataset/gene_annotation_summary.txt'

# %% [markdown]
# **Compile mutation and output gene summary table**

# %%
## Compile the gene mutations for each sample
# if you want to output binary mutation types (mutated or not), set model = 'binary'
gene_mutation_summary = compile_gene_mutations(annovar_output_dir, gff_file, model = 'binary')
## Write the gene mutation summary
write_gene_mutation_summary(gene_mutation_summary, output_mutation_table)
## Write the gene annotations
write_gene_annotation_summary(gff_file, output_annotation_table)
# Out:
# Time elapsed for compiling gene mutations: 19.00 seconds
# Total number of samples processed: 300
# Gene mutation summary has been written to data/pyseer_dataset/gene_mutation_summary.txt.
#
# Gene annotation summary has been written to data/pyseer_dataset/gene_annotation_summary.txt.

# %% [markdown]
# #### **Step 3: Estimate Population Structure Effect:**
#
# In gene-trait association analyses, false positives could arise from shared genetic lineage, especially in clonal organisms. There are two methods to estimate the effect of population structure:
# - Phylogenetic-based: Infer population structure based on phylogenetic distances. Since MugGWAS will use a linear mixed model, the distance will be estimated from the shared branch length between the MRCA and the root.
# - Kinship: Variants on core gene sequences represent the result of vertical evolution. To make inferences for identical by descent, the script will calculate the kinship matrix from the genotype matrix of the presence and absence of variants. --> (not supported yet as of 2025.04.15)
#
# Inputs:
# - Phylogeny-based: Output from IQ-tree `core_gene_tree.nwk`. A high-quality phylogeny based on single-copy core genes from a pangenome.
# - Kinship: A VCF file documenting variants on core genes `core_gene_snp.vcf.gz`. --> (not supported yet as of 2025.04.15)
#
# Output:
# - `phylogeny_distances.tsv`: a distance matrix to account for population structure effect in pyseer.
#
#     | |Sample1|Sample2|Sample3|Sample4|
#     |:-:|:-:|:-:|:-:|:-:|
#     |Sample1|0|4|0|0|
#     |Sample2|4|0|0|0|
#     |Sample3|0|0|0|3|
#     |Sample4|0|0|3|0|
#     |...|...|...|...|
#
# **Phylogeny-based method**

# %%
from muggwas import phylogeny2distmatrix

# Read the phylogenetic tree
phylogeny = 'pyseer_dataset/core_genome_aln.tree'
output_file = 'pyseer_dataset/phylogeny_distances.tsv'

# Convert the phylogenetic tree to a distance matrix
phylogeny2distmatrix(phylogeny, output_file)

# %% [markdown]
# ### **Step 4: Run GWAS on pyseer**
#
# This function filter the genes that have no mutations in the population and run the [linear mixed effect model (FaST-LMM)](https://pyseer.readthedocs.io/en/master/usage.html#mixed-model-fast-lmm) from `pyseer` to infer gene-trait association. Read the GWAS [tutorial](https://pyseer.readthedocs.io/en/master/tutorial.html) for more details.
#
#
#
# - Input:
#     1. The **phenotype file**: a tab-delimited file with the first column as sample names and the second column as the phenotypic value (support binary or numeric).
#     2. The **gene mutation summary table**: the output from step 2.
#     3. The **distance matrix**: the output from step 3.
#
# - Output: A summary table of **GWAS result** that looks like this:
#
#     |Genes|Allele Freq.|filter-value|lrt-pvalue|beta|beta-std-err|variant_h2|notes|
#     |:---|:--|:------|:----------|:------|:-----------|:------|:-----------|
#     |g1|3.00E-01|6.96E-02|1.59E-01|2.09E-01|1.35E-01|4.81E-01|
#     |g2|6.00E-01|2.89E-01|2.50E-01|-8.73E-02|7.03E-02|4.02E-01|
#     |g3|6.00E-01|7.02E-01|8.27E-01|-2.92E-02|1.30E-01|7.94E-02|
#     |...|...|...|...|...|...|...|...|

# %%
from muggwas import run_pyseer

phenotype_file = 'pyseer_dataset/resistances.subset.txt'
mutation_file = 'pyseer_dataset/gene_mutation_summary.txt'
similarity_matrix_file = 'pyseer_dataset/phylogeny_distances.tsv'
output_dir = 'pyseer_dataset/'

# Run pyseer
run_pyseer(phenotype_file, similarity_matrix_file, mutation_file, output_dir)
# Out:
# 2025-04-15 23:09:46,264 - INFO - Start running GWAS with pyseer
# 2025-04-15 23:09:46,282 - INFO - Gene gene-SPN23F_RS00005 has a mutation rate of 0.27.
# 2025-04-15 23:09:46,282 - INFO - Gene cds-WP_000660615.1 has no mutations in the population. Skipping this gene.
# 2025-04-15 23:09:46,283 - INFO - Gene gene-SPN23F_RS00010 has a mutation rate of 0.27.
# 2025-04-15 23:09:46,284 - INFO - Gene cds-WP_000581157.1 has no mutations in the population. Skipping this gene.
# 2025-04-15 23:09:46,285 - INFO - Gene gene-SPN23F_RS00015 has a mutation rate of 0.11333333333333333.
# 2025-04-15 23:09:46,285 - INFO - Gene cds-WP_000285194.1 has no mutations in the population. Skipping this gene.
# 2025-04-15 23:09:46,286 - INFO - Gene gene-SPN23F_RS00020 has a mutation rate of 0.2966666666666667.
# 2025-04-15 23:09:46,286 - INFO - Gene cds-WP_001218707.1 has no mutations in the population. Skipping this gene.
# 2025-04-15 23:09:46,287 - INFO - Gene gene-SPN23F_RS00025 has a mutation rate of 0.7133333333333334.
# 2025-04-15 23:09:46,287 - INFO - Gene cds-WP_000163930.1 has no mutations in the population. Skipping this gene.
# 2025-04-15 23:09:46,287 - INFO - Gene gene-SPN23F_RS00030 has a mutation rate of 0.5933333333333334.
# 2025-04-15 23:09:46,288 - INFO - Gene cds-WP_000258117.1 has no mutations in the population. Skipping this gene.
# 2025-04-15 23:09:46,288 - INFO - Gene gene-SPN23F_RS00035 has a mutation rate of 0.02.
# 2025-04-15 23:09:46,289 - INFO - Gene cds-WP_001234978.1 has no mutations in the population. Skipping this gene.
# 2025-04-15 23:09:46,289 - INFO - Gene gene-SPN23F_RS00040 has a mutation rate of 0.06.
# 2025-04-15 23:09:46,290 - INFO - Gene cds-WP_000041909.1 has no mutations in the population. Skipping this gene.
# 2025-04-15 23:09:46,290 - INFO - Gene gene-SPN23F_RS14045 has a mutation rate of 0.28.
# 2025-04-15 23:09:46,290 - INFO - Gene cds-WP_000429334.1 has no mutations in the population. Skipping this gene.
# 2025-04-15 23:09:46,291 - INFO - Gene gene-SPN23F_RS00050 has a mutation rate of 0.3933333333333333.
# 2025-04-15 23:09:46,291 - INFO - Gene cds-WP_001224768.1 has no mutations in the population. Skipping this gene.
# 2025-04-15 23:09:46,292 - INFO - Gene gene-SPN23F_RS00055 has a mutation rate of 0.94.
# 2025-04-15 23:09:46,292 - INFO - Gene cds-WP_001208992.1 has no mutations in the population. Skipping this gene.
# 2025-04-15 23:09:46,293 - INFO - Gene gene-SPN23F_RS00060 has a mutation rate of 0.12333333333333334.
# 2025-04-15 23:09:46,293 - INFO - Gene cds-WP_000892185.1 has no mutations in the population. Skipping this gene.
# 2025-04-15 23:09:46,294 - INFO - Gene gene-SPN23F_RS00065 has a mutation rate of 0.5666666666666667.
# 2025-04-15 23:09:46,294 - INFO - Gene cds-WP_000744545.1 has no mutations in the population. Skipping this gene.
# 2025-04-15 23:09:46,295 - INFO - Gene gene-SPN23F_RS00070 has no mutations in the population. Skipping this gene.
# 2025-04-15 23:09:46,295 - INFO - Gene cds-WP_000436644.1 has no mutations in the population. Skipping this gene.
# 2025-04-15 23:09:46,296 - INFO - Gene gene-SPN23F_RS00075 has no mutations in the population. Skipping this gene.
# 2025-04-15 23:09:46,296 - INFO - Gene cds-WP_000588897.1 has no mutations in the population. Skipping this gene.
# 2025-04-15 23:09:46,296 - INFO - Gene gene-SPN23F_RS00080 has no mutations in the population. Skipping this gene.
# 2025-04-15 23:09:46,297 - INFO - Gene gene-SPN23F_RS00085 has no mutations in the population. Skipping this gene.
# 2025-04-15 23:09:46,297 - INFO - Gene gene-SPN23F_RS00090 has no mutations in the population. Skipping this gene.
# 2025-04-15 23:09:46,297 - INFO - Gene gene-SPN23F_RS00095 has no mutations in the population. Skipping this gene.
# 2025-04-15 23:09:46,297 - INFO - Gene gene-SPN23F_RS00100 has no mutations in the population. Skipping this gene.
# 2025-04-15 23:09:46,298 - INFO - Gene gene-SPN23F_RS00105 has no mutations in the population. Skipping this gene.
# 2025-04-15 23:09:46,298 - INFO - Gene cds-SPN23F_RS11705 has no mutations in the population. Skipping this gene.
# 2025-04-15 23:09:46,299 - INFO - Gene cds-SPN23F_RS11710 has no mutations in the population. Skipping this gene.
# 2025-04-15 23:09:46,299 - INFO - Gene gene-SPN23F_RS00140 has a mutation rate of 0.4.
# 2025-04-15 23:09:46,299 - INFO - Gene cds-WP_000939545.1 has no mutations in the population. Skipping this gene.
# 2025-04-15 23:09:46,299 - INFO - Gene gene-SPN23F_RS00145 has a mutation rate of 0.11.
# 2025-04-15 23:09:46,300 - INFO - Gene cds-WP_000205044.1 has no mutations in the population. Skipping this gene.
# 2025-04-15 23:09:46,300 - INFO - Gene gene-SPN23F_RS00150 has a mutation rate of 0.46.
# 2025-04-15 23:09:46,300 - INFO - Gene cds-WP_000291870.1 has no mutations in the population. Skipping this gene.
# 2025-04-15 23:09:46,301 - INFO - Gene gene-SPN23F_RS11715 has no mutations in the population. Skipping this gene.
# 2025-04-15 23:09:46,301 - INFO - Gene gene-SPN23F_RS13665 has a mutation rate of 0.01.
# 2025-04-15 23:09:46,301 - INFO - Gene cds-WP_001106362.1 has no mutations in the population. Skipping this gene.
# 2025-04-15 23:09:46,302 - INFO - Gene gene-SPN23F_RS13670 has a mutation rate of 0.05.
# 2025-04-15 23:09:46,302 - INFO - Gene cds-WP_001814135.1 has no mutations in the population. Skipping this gene.
# 2025-04-15 23:09:46,303 - INFO - Gene gene-SPN23F_RS00165 has no mutations in the population. Skipping this gene.
# 2025-04-15 23:09:46,303 - INFO - Gene cds-WP_000401841.1 has no mutations in the population. Skipping this gene.
# 2025-04-15 23:09:46,304 - INFO - Gene gene-SPN23F_RS00170 has a mutation rate of 0.11333333333333333.
# 2025-04-15 23:09:46,304 - INFO - Gene cds-WP_000170931.1 has no mutations in the population. Skipping this gene.
# 2025-04-15 23:09:46,305 - INFO - Gene gene-SPN23F_RS00175 has a mutation rate of 0.03.
# 2025-04-15 23:09:46,305 - INFO - Gene cds-WP_000285962.1 has no mutations in the population. Skipping this gene.
# 2025-04-15 23:09:46,306 - INFO - Gene gene-SPN23F_RS00180 has a mutation rate of 0.03666666666666667.
# 2025-04-15 23:09:46,306 - INFO - Gene cds-WP_000156419.1 has no mutations in the population. Skipping this gene.
# 2025-04-15 23:09:46,306 - INFO - Gene gene-SPN23F_RS00185 has a mutation rate of 0.06333333333333334.
# 2025-04-15 23:09:46,307 - INFO - Gene cds-WP_000464160.1 has no mutations in the population. Skipping this gene.
# 2025-04-15 23:09:46,307 - INFO - Gene gene-SPN23F_RS00190 has no mutations in the population. Skipping this gene.
# 2025-04-15 23:09:46,307 - INFO - Gene cds-WP_001112859.1 has no mutations in the population. Skipping this gene.
# 2025-04-15 23:09:46,307 - INFO - Gene gene-SPN23F_RS00195 has a mutation rate of 0.07.
# 2025-04-15 23:09:46,308 - INFO - Gene cds-WP_001247549.1 has no mutations in the population. Skipping this gene.
# 2025-04-15 23:09:46,308 - INFO - Gene gene-SPN23F_RS11720 has a mutation rate of 0.02.
# 2025-04-15 23:09:46,308 - INFO - Gene cds-WP_000024181.1 has no mutations in the population. Skipping this gene.
# 2025-04-15 23:09:46,309 - INFO - Gene cds-SPN23F_RS00200 has no mutations in the population. Skipping this gene.
# 2025-04-15 23:09:46,309 - INFO - Gene gene-SPN23F_RS00205 has a mutation rate of 0.04.
# 2025-04-15 23:09:46,309 - INFO - Gene cds-WP_001209433.1 has no mutations in the population. Skipping this gene.
# 2025-04-15 23:09:46,309 - INFO - Gene gene-SPN23F_RS13455 has a mutation rate of 0.023333333333333334.
# 2025-04-15 23:09:46,310 - INFO - Gene cds-WP_001030863.1 has no mutations in the population. Skipping this gene.
# 2025-04-15 23:09:46,310 - INFO - Gene gene-SPN23F_RS00210 has a mutation rate of 0.26666666666666666.
# 2025-04-15 23:09:46,310 - INFO - Gene cds-WP_000701992.1 has no mutations in the population. Skipping this gene.
# 2025-04-15 23:09:46,311 - INFO - Gene gene-SPN23F_RS00215 has a mutation rate of 0.2966666666666667.
# 2025-04-15 23:09:46,311 - INFO - Gene cds-WP_000691236.1 has no mutations in the population. Skipping this gene.
# 2025-04-15 23:09:46,311 - INFO - Gene gene-SPN23F_RS00220 has a mutation rate of 0.26666666666666666.
# 2025-04-15 23:09:46,311 - INFO - Gene cds-WP_075213698.1 has no mutations in the population. Skipping this gene.
# 2025-04-15 23:09:46,312 - INFO - Gene gene-SPN23F_RS00225 has a mutation rate of 0.34.
# 2025-04-15 23:09:46,312 - INFO - Gene cds-WP_001809263.1 has no mutations in the population. Skipping this gene.
# 2025-04-15 23:09:46,312 - INFO - Gene cds-SPN23F_RS00230 has no mutations in the population. Skipping this gene.
# 2025-04-15 23:09:46,313 - INFO - Gene gene-SPN23F_RS00240 has a mutation rate of 0.22333333333333333.
# 2025-04-15 23:09:46,313 - INFO - Gene cds-WP_000010163.1 has no mutations in the population. Skipping this gene.
# 2025-04-15 23:09:46,314 - INFO - Gene cds-SPN23F_RS13675 has no mutations in the population. Skipping this gene.
# 2025-04-15 23:09:46,314 - INFO - Gene gene-SPN23F_RS00260 has a mutation rate of 0.7433333333333333.
# 2025-04-15 23:09:46,315 - INFO - Gene cds-WP_001812055.1 has no mutations in the population. Skipping this gene.
# 2025-04-15 23:09:46,315 - INFO - Gene gene-SPN23F_RS00265 has a mutation rate of 0.2866666666666667.
# 2025-04-15 23:09:46,315 - INFO - Gene cds-WP_000076479.1 has no mutations in the population. Skipping this gene.
# 2025-04-15 23:09:46,316 - INFO - Gene gene-SPN23F_RS13680 has a mutation rate of 0.41333333333333333.
# 2025-04-15 23:09:46,316 - INFO - Gene cds-WP_001814139.1 has no mutations in the population. Skipping this gene.
# 2025-04-15 23:09:46,317 - INFO - Gene gene-SPN23F_RS00275 has a mutation rate of 0.8533333333333334.
# 2025-04-15 23:09:46,317 - INFO - Gene cds-WP_000009180.1 has no mutations in the population. Skipping this gene.
# 2025-04-15 23:09:46,318 - INFO - Gene gene-SPN23F_RS00280 has a mutation rate of 0.7166666666666667.
# 2025-04-15 23:09:46,318 - INFO - Gene cds-WP_000366348.1 has no mutations in the population. Skipping this gene.
# 2025-04-15 23:09:46,318 - INFO - Gene gene-SPN23F_RS00285 has a mutation rate of 0.5866666666666667.
# 2025-04-15 23:09:46,319 - INFO - Gene cds-WP_000616164.1 has no mutations in the population. Skipping this gene.
# 2025-04-15 23:09:46,319 - INFO - Gene gene-SPN23F_RS00290 has a mutation rate of 0.69.
# 2025-04-15 23:09:46,319 - INFO - Gene cds-WP_000717451.1 has no mutations in the population. Skipping this gene.
# 2025-04-15 23:09:46,320 - INFO - Gene gene-SPN23F_RS00295 has a mutation rate of 0.14.
# 2025-04-15 23:09:46,320 - INFO - Gene cds-WP_000136449.1 has no mutations in the population. Skipping this gene.
# 2025-04-15 23:09:46,320 - INFO - Gene cds-SPN23F_RS11730 has no mutations in the population. Skipping this gene.
# 2025-04-15 23:09:46,320 - INFO - Gene gene-SPN23F_RS00300 has a mutation rate of 0.7233333333333334.
# 2025-04-15 23:09:46,321 - INFO - Gene cds-WP_001093075.1 has no mutations in the population. Skipping this gene.
# 2025-04-15 23:09:46,321 - INFO - Gene gene-SPN23F_RS14050 has a mutation rate of 0.023333333333333334.
# 2025-04-15 23:09:46,321 - INFO - Gene cds-WP_000346297.1 has no mutations in the population. Skipping this gene.
# 2025-04-15 23:09:46,322 - INFO - Gene gene-SPN23F_RS00315 has a mutation rate of 0.5666666666666667.
# 2025-04-15 23:09:46,322 - INFO - Gene cds-WP_000668272.1 has no mutations in the population. Skipping this gene.
# 2025-04-15 23:09:46,327 - INFO - Gene gene-SPN23F_RS00320 has a mutation rate of 0.87.
# 2025-04-15 23:09:46,327 - INFO - Gene cds-WP_000801611.1 has no mutations in the population. Skipping this gene.
# 2025-04-15 23:09:46,327 - INFO - Gene gene-SPN23F_RS00325 has a mutation rate of 0.5433333333333333.
# 2025-04-15 23:09:46,328 - INFO - Gene cds-WP_000043310.1 has no mutations in the population. Skipping this gene.
# 2025-04-15 23:09:46,328 - INFO - Gene gene-SPN23F_RS00330 has a mutation rate of 0.94.
# 2025-04-15 23:09:46,329 - INFO - Gene cds-WP_000361217.1 has no mutations in the population. Skipping this gene.
# 2025-04-15 23:09:46,329 - INFO - Gene gene-SPN23F_RS00335 has a mutation rate of 0.6733333333333333.
# 2025-04-15 23:09:46,330 - INFO - Gene cds-WP_000220632.1 has no mutations in the population. Skipping this gene.
# 2025-04-15 23:09:46,330 - INFO - Gene gene-SPN23F_RS00340 has a mutation rate of 0.44666666666666666.
# 2025-04-15 23:09:46,331 - INFO - Gene cds-WP_000182575.1 has no mutations in the population. Skipping this gene.
# 2025-04-15 23:09:46,331 - INFO - Gene gene-SPN23F_RS00345 has a mutation rate of 0.4766666666666667.
# 2025-04-15 23:09:46,331 - INFO - Gene cds-WP_000717506.1 has no mutations in the population. Skipping this gene.
# 2025-04-15 23:09:46,331 - INFO - Gene gene-SPN23F_RS00350 has a mutation rate of 0.2633333333333333.
# 2025-04-15 23:09:46,332 - INFO - Gene cds-WP_000894018.1 has no mutations in the population. Skipping this gene.
# 2025-04-15 23:09:46,332 - INFO - Gene gene-SPN23F_RS00355 has a mutation rate of 0.66.
# 2025-04-15 23:09:46,332 - INFO - Gene cds-WP_000167083.1 has no mutations in the population. Skipping this gene.
# 2025-04-15 23:09:46,333 - INFO - Gene gene-SPN23F_RS00360 has a mutation rate of 0.82.
# 2025-04-15 23:09:46,333 - INFO - Gene cds-WP_000772228.1 has no mutations in the population. Skipping this gene.
# 2025-04-15 23:09:46,333 - INFO - Gene gene-SPN23F_RS13685 has a mutation rate of 0.02.
# 2025-04-15 23:09:46,333 - INFO - Gene cds-WP_001809271.1 has no mutations in the population. Skipping this gene.
# 2025-04-15 23:09:46,334 - INFO - Gene gene-SPN23F_RS00365 has a mutation rate of 0.18666666666666668.
# 2025-04-15 23:09:46,334 - INFO - Gene cds-WP_000805601.1 has no mutations in the population. Skipping this gene.
# 2025-04-15 23:09:46,334 - INFO - Gene gene-SPN23F_RS00370 has a mutation rate of 0.6833333333333333.
# 2025-04-15 23:09:46,335 - INFO - Gene cds-WP_000099019.1 has no mutations in the population. Skipping this gene.
# 2025-04-15 23:09:46,335 - INFO - Gene gene-SPN23F_RS00375 has no mutations in the population. Skipping this gene.
# 2025-04-15 23:09:46,335 - INFO - Gene cds-WP_001813327.1 has no mutations in the population. Skipping this gene.
# 2025-04-15 23:09:46,336 - INFO - Gene gene-SPN23F_RS00380 has a mutation rate of 0.29333333333333333.
# 2025-04-15 23:09:46,336 - INFO - Gene cds-WP_000610746.1 has no mutations in the population. Skipping this gene.
# 2025-04-15 23:09:46,336 - INFO - Gene gene-SPN23F_RS00385 has a mutation rate of 0.8333333333333334.
# 2025-04-15 23:09:46,337 - INFO - Gene cds-WP_000679942.1 has no mutations in the population. Skipping this gene.
# 2025-04-15 23:09:46,337 - INFO - Gene gene-SPN23F_RS00390 has a mutation rate of 0.26.
# 2025-04-15 23:09:46,337 - INFO - Gene cds-WP_001007198.1 has no mutations in the population. Skipping this gene.
# 2025-04-15 23:09:46,337 - INFO - Gene gene-SPN23F_RS00395 has a mutation rate of 0.6266666666666667.
# 2025-04-15 23:09:46,338 - INFO - Gene cds-WP_000196572.1 has no mutations in the population. Skipping this gene.
# 2025-04-15 23:09:46,338 - INFO - Gene gene-SPN23F_RS00400 has a mutation rate of 0.20333333333333334.
# 2025-04-15 23:09:46,338 - INFO - Gene cds-WP_000156967.1 has no mutations in the population. Skipping this gene.
# 2025-04-15 23:09:46,339 - INFO - Gene gene-SPN23F_RS00405 has a mutation rate of 0.18333333333333332.
# 2025-04-15 23:09:46,339 - INFO - Gene cds-WP_000616999.1 has no mutations in the population. Skipping this gene.
# 2025-04-15 23:09:46,340 - INFO - Gene gene-SPN23F_RS00410 has a mutation rate of 0.13333333333333333.
# 2025-04-15 23:09:46,340 - INFO - Gene cds-WP_000185298.1 has no mutations in the population. Skipping this gene.
# 2025-04-15 23:09:46,340 - INFO - Gene gene-SPN23F_RS00415 has a mutation rate of 0.17.
# 2025-04-15 23:09:46,341 - INFO - Gene cds-WP_000167454.1 has no mutations in the population. Skipping this gene.
# 2025-04-15 23:09:46,341 - INFO - Gene gene-SPN23F_RS00420 has a mutation rate of 0.5566666666666666.
# 2025-04-15 23:09:46,341 - INFO - Gene cds-WP_000903552.1 has no mutations in the population. Skipping this gene.
# 2025-04-15 23:09:46,342 - INFO - Gene gene-SPN23F_RS00425 has a mutation rate of 0.4266666666666667.
# 2025-04-15 23:09:46,342 - INFO - Gene cds-WP_000649425.1 has no mutations in the population. Skipping this gene.
# 2025-04-15 23:09:46,343 - INFO - Gene gene-SPN23F_RS00430 has a mutation rate of 0.75.
# 2025-04-15 23:09:46,343 - INFO - Gene cds-WP_000220701.1 has no mutations in the population. Skipping this gene.
# 2025-04-15 23:09:46,344 - INFO - Gene gene-SPN23F_RS00435 has a mutation rate of 0.48333333333333334.
# 2025-04-15 23:09:46,344 - INFO - Gene cds-WP_000185151.1 has no mutations in the population. Skipping this gene.
# 2025-04-15 23:09:46,344 - INFO - Gene gene-SPN23F_RS13355 has a mutation rate of 0.5233333333333333.
# 2025-04-15 23:09:46,344 - INFO - Gene cds-WP_000695849.1 has no mutations in the population. Skipping this gene.
# 2025-04-15 23:09:46,345 - INFO - Gene gene-SPN23F_RS00445 has a mutation rate of 0.36333333333333334.
# 2025-04-15 23:09:46,345 - INFO - Gene cds-WP_000450181.1 has no mutations in the population. Skipping this gene.
# 2025-04-15 23:09:46,345 - INFO - Gene cds-SPN23F_RS11750 has no mutations in the population. Skipping this gene.
# 2025-04-15 23:09:46,346 - INFO - Gene gene-SPN23F_RS00450 has a mutation rate of 0.79.
# 2025-04-15 23:09:46,346 - INFO - Gene cds-WP_000614999.1 has no mutations in the population. Skipping this gene.
# 2025-04-15 23:09:46,346 - INFO - Gene gene-SPN23F_RS13180 has a mutation rate of 0.5266666666666666.
# 2025-04-15 23:09:46,347 - INFO - Gene cds-WP_000849912.1 has no mutations in the population. Skipping this gene.
# 2025-04-15 23:09:46,347 - INFO - Gene gene-SPN23F_RS00460 has a mutation rate of 0.2733333333333333.
# 2025-04-15 23:09:46,347 - INFO - Gene cds-WP_000897726.1 has no mutations in the population. Skipping this gene.
# 2025-04-15 23:09:46,348 - INFO - Gene gene-SPN23F_RS00465 has a mutation rate of 0.04666666666666667.
# 2025-04-15 23:09:46,348 - INFO - Gene cds-WP_001283896.1 has no mutations in the population. Skipping this gene.
# 2025-04-15 23:09:46,348 - INFO - Gene gene-SPN23F_RS13690 has a mutation rate of 0.5266666666666666.
# 2025-04-15 23:09:46,349 - INFO - Gene cds-WP_000692796.1 has no mutations in the population. Skipping this gene.
# 2025-04-15 23:09:46,349 - INFO - Gene gene-SPN23F_RS00475 has a mutation rate of 0.87.
# 2025-04-15 23:09:46,350 - INFO - Gene cds-WP_000771901.1 has no mutations in the population. Skipping this gene.
# 2025-04-15 23:09:46,350 - INFO - Gene gene-SPN23F_RS00480 has a mutation rate of 0.75.
# 2025-04-15 23:09:46,351 - INFO - Gene cds-WP_000291603.1 has no mutations in the population. Skipping this gene.
# 2025-04-15 23:09:46,351 - INFO - Gene cds-SPN23F_RS00485 has no mutations in the population. Skipping this gene.
# 2025-04-15 23:09:46,351 - INFO - Gene gene-SPN23F_RS00490 has a mutation rate of 0.043333333333333335.
# 2025-04-15 23:09:46,352 - INFO - Gene cds-WP_000520642.1 has no mutations in the population. Skipping this gene.
# 2025-04-15 23:09:46,352 - INFO - Gene gene-SPN23F_RS00495 has a mutation rate of 0.21.
# 2025-04-15 23:09:46,352 - INFO - Gene cds-WP_000769768.1 has no mutations in the population. Skipping this gene.
# 2025-04-15 23:09:46,353 - INFO - Gene gene-SPN23F_RS00500 has no mutations in the population. Skipping this gene.
# 2025-04-15 23:09:46,353 - INFO - Gene cds-WP_000092756.1 has no mutations in the population. Skipping this gene.
# 2025-04-15 23:09:46,353 - INFO - Gene cds-SPN23F_RS11760 has no mutations in the population. Skipping this gene.
# 2025-04-15 23:09:46,354 - INFO - Gene cds-SPN23F_RS12785 has no mutations in the population. Skipping this gene.
# 2025-04-15 23:09:46,354 - INFO - Gene gene-SPN23F_RS00510 has a mutation rate of 0.49333333333333335.
# 2025-04-15 23:09:46,354 - INFO - Gene cds-WP_000148253.1 has no mutations in the population. Skipping this gene.
# 2025-04-15 23:09:46,354 - INFO - Gene gene-SPN23F_RS00515 has a mutation rate of 0.53.
# 2025-04-15 23:09:46,355 - INFO - Gene cds-WP_001809441.1 has no mutations in the population. Skipping this gene.
# 2025-04-15 23:09:46,355 - INFO - Gene gene-SPN23F_RS00520 has a mutation rate of 0.06666666666666667.
# 2025-04-15 23:09:46,356 - INFO - Gene cds-WP_000714582.1 has no mutations in the population. Skipping this gene.
# 2025-04-15 23:09:46,357 - INFO - Gene gene-SPN23F_RS00525 has a mutation rate of 0.03333333333333333.
# 2025-04-15 23:09:46,357 - INFO - Gene cds-WP_001075102.1 has no mutations in the population. Skipping this gene.
# 2025-04-15 23:09:46,357 - INFO - Gene gene-SPN23F_RS00530 has a mutation rate of 0.17666666666666667.
# 2025-04-15 23:09:46,358 - INFO - Gene cds-WP_000800432.1 has no mutations in the population. Skipping this gene.
# 2025-04-15 23:09:46,358 - INFO - Gene gene-SPN23F_RS00535 has a mutation rate of 0.06333333333333334.
# 2025-04-15 23:09:46,359 - INFO - Gene cds-WP_001030031.1 has no mutations in the population. Skipping this gene.
# 2025-04-15 23:09:46,359 - INFO - Gene gene-SPN23F_RS14055 has no mutations in the population. Skipping this gene.
# 2025-04-15 23:09:46,360 - INFO - Gene cds-WP_001813665.1 has no mutations in the population. Skipping this gene.
# 2025-04-15 23:09:46,360 - INFO - Gene gene-SPN23F_RS00540 has a mutation rate of 0.6966666666666667.
# 2025-04-15 23:09:46,361 - INFO - Gene cds-WP_001140340.1 has no mutations in the population. Skipping this gene.
# 2025-04-15 23:09:46,361 - INFO - Gene gene-SPN23F_RS00545 has a mutation rate of 0.6533333333333333.
# 2025-04-15 23:09:46,361 - INFO - Gene cds-WP_000808442.1 has no mutations in the population. Skipping this gene.
# 2025-04-15 23:09:46,362 - INFO - Gene gene-SPN23F_RS00550 has a mutation rate of 0.8666666666666667.
# 2025-04-15 23:09:46,362 - INFO - Gene cds-WP_001233692.1 has no mutations in the population. Skipping this gene.
# 2025-04-15 23:09:46,362 - INFO - Gene gene-SPN23F_RS00555 has a mutation rate of 0.5966666666666667.
# 2025-04-15 23:09:46,363 - INFO - Gene cds-WP_000198687.1 has no mutations in the population. Skipping this gene.
# 2025-04-15 23:09:46,363 - INFO - Gene gene-SPN23F_RS00560 has a mutation rate of 0.4866666666666667.
# 2025-04-15 23:09:46,363 - INFO - Gene cds-WP_000273863.1 has no mutations in the population. Skipping this gene.
# 2025-04-15 23:09:46,363 - INFO - Gene cds-SPN23F_RS00565 has no mutations in the population. Skipping this gene.
# 2025-04-15 23:09:46,364 - INFO - Gene gene-SPN23F_RS00570 has a mutation rate of 0.8333333333333334.
# 2025-04-15 23:09:46,364 - INFO - Gene cds-WP_000096197.1 has no mutations in the population. Skipping this gene.
# 2025-04-15 23:09:46,364 - INFO - Gene gene-SPN23F_RS00575 has a mutation rate of 0.43666666666666665.
# 2025-04-15 23:09:46,365 - INFO - Gene cds-WP_001035700.1 has no mutations in the population. Skipping this gene.
# 2025-04-15 23:09:46,365 - INFO - Gene gene-SPN23F_RS00580 has no mutations in the population. Skipping this gene.
# 2025-04-15 23:09:46,365 - INFO - Gene cds-WP_000436237.1 has no mutations in the population. Skipping this gene.
# 2025-04-15 23:09:46,365 - INFO - Gene gene-SPN23F_RS13190 has a mutation rate of 0.6433333333333333.
# 2025-04-15 23:09:46,366 - INFO - Gene cds-WP_000693348.1 has no mutations in the population. Skipping this gene.
# 2025-04-15 23:09:46,366 - INFO - Gene gene-SPN23F_RS00590 has a mutation rate of 0.42333333333333334.
# 2025-04-15 23:09:46,366 - INFO - Gene cds-WP_000200892.1 has no mutations in the population. Skipping this gene.
# 2025-04-15 23:09:46,367 - INFO - Gene gene-SPN23F_RS00595 has a mutation rate of 0.5533333333333333.
# 2025-04-15 23:09:46,367 - INFO - Gene cds-WP_000500038.1 has no mutations in the population. Skipping this gene.
# 2025-04-15 23:09:46,367 - INFO - Gene gene-SPN23F_RS00600 has a mutation rate of 0.06333333333333334.
# 2025-04-15 23:09:46,368 - INFO - Gene cds-WP_000838912.1 has no mutations in the population. Skipping this gene.
# 2025-04-15 23:09:46,368 - INFO - Gene gene-SPN23F_RS00605 has a mutation rate of 0.33.
# 2025-04-15 23:09:46,368 - INFO - Gene cds-WP_000836442.1 has no mutations in the population. Skipping this gene.
# 2025-04-15 23:09:46,369 - INFO - Gene gene-SPN23F_RS00610 has no mutations in the population. Skipping this gene.
# 2025-04-15 23:09:46,369 - INFO - Gene cds-WP_001861316.1 has no mutations in the population. Skipping this gene.
# 2025-04-15 23:09:46,370 - INFO - Gene gene-SPN23F_RS00615 has no mutations in the population. Skipping this gene.
# 2025-04-15 23:09:46,370 - INFO - Gene cds-WP_001230165.1 has no mutations in the population. Skipping this gene.
# 2025-04-15 23:09:46,371 - INFO - Gene gene-SPN23F_RS00620 has no mutations in the population. Skipping this gene.
# 2025-04-15 23:09:46,371 - INFO - Gene cds-WP_000724257.1 has no mutations in the population. Skipping this gene.
# 2025-04-15 23:09:46,372 - INFO - Gene gene-SPN23F_RS00625 has no mutations in the population. Skipping this gene.
# 2025-04-15 23:09:46,372 - INFO - Gene cds-WP_000571330.1 has no mutations in the population. Skipping this gene.
# 2025-04-15 23:09:46,372 - INFO - Gene gene-SPN23F_RS00630 has no mutations in the population. Skipping this gene.
# 2025-04-15 23:09:46,373 - INFO - Gene cds-WP_001038484.1 has no mutations in the population. Skipping this gene.
# 2025-04-15 23:09:46,373 - INFO - Gene cds-SPN23F_RS00635 has no mutations in the population. Skipping this gene.
# 2025-04-15 23:09:46,373 - INFO - Gene gene-SPN23F_RS00640 has no mutations in the population. Skipping this gene.
# 2025-04-15 23:09:46,373 - INFO - Gene cds-WP_001861316.1-2 has no mutations in the population. Skipping this gene.
# 2025-04-15 23:09:46,374 - INFO - Gene gene-SPN23F_RS00650 has no mutations in the population. Skipping this gene.
# 2025-04-15 23:09:46,374 - INFO - Gene cds-WP_000436237.1-2 has no mutations in the population. Skipping this gene.
# 2025-04-15 23:09:46,374 - INFO - Gene gene-SPN23F_RS13360 has a mutation rate of 0.27666666666666667.
# 2025-04-15 23:09:46,374 - INFO - Gene cds-WP_001814148.1 has no mutations in the population. Skipping this gene.
# 2025-04-15 23:09:46,375 - INFO - Gene gene-SPN23F_RS00665 has a mutation rate of 1.0.
# 2025-04-15 23:09:46,375 - INFO - Gene cds-WP_001814150.1 has no mutations in the population. Skipping this gene.
# 2025-04-15 23:09:46,375 - INFO - Gene cds-SPN23F_RS13695 has no mutations in the population. Skipping this gene.
# 2025-04-15 23:09:46,376 - INFO - Gene gene-SPN23F_RS00670 has a mutation rate of 0.51.
# 2025-04-15 23:09:46,376 - INFO - Gene cds-WP_000770312.1 has no mutations in the population. Skipping this gene.
# 2025-04-15 23:09:46,376 - INFO - Gene gene-SPN23F_RS00675 has a mutation rate of 0.8566666666666667.
# 2025-04-15 23:09:46,376 - INFO - Gene cds-WP_020901307.1 has no mutations in the population. Skipping this gene.
# 2025-04-15 23:09:46,377 - INFO - Gene gene-SPN23F_RS13700 has a mutation rate of 0.8666666666666667.
# 2025-04-15 23:09:46,377 - INFO - Gene cds-WP_231844674.1 has no mutations in the population. Skipping this gene.
# 2025-04-15 23:09:46,377 - INFO - Gene cds-SPN23F_RS14150 has no mutations in the population. Skipping this gene.
# 2025-04-15 23:09:46,377 - INFO - Gene gene-SPN23F_RS00685 has a mutation rate of 0.8166666666666667.
# 2025-04-15 23:09:46,378 - INFO - Gene cds-WP_001282967.1 has no mutations in the population. Skipping this gene.
# 2025-04-15 23:09:46,378 - INFO - Gene gene-SPN23F_RS00690 has a mutation rate of 0.6833333333333333.
# 2025-04-15 23:09:46,379 - INFO - Gene cds-WP_000193610.1 has no mutations in the population. Skipping this gene.
# 2025-04-15 23:09:46,379 - INFO - Gene gene-SPN23F_RS00695 has a mutation rate of 0.59.
# 2025-04-15 23:09:46,379 - INFO - Gene cds-WP_000220946.1 has no mutations in the population. Skipping this gene.
# 2025-04-15 23:09:46,380 - INFO - Gene gene-SPN23F_RS13710 has no mutations in the population. Skipping this gene.
# 2025-04-15 23:09:46,380 - INFO - Gene cds-WP_001838083.1 has no mutations in the population. Skipping this gene.
# 2025-04-15 23:09:46,380 - INFO - Gene gene-SPN23F_RS00705 has a mutation rate of 0.29.
# 2025-04-15 23:09:46,381 - INFO - Gene cds-WP_000331980.1 has no mutations in the population. Skipping this gene.
# 2025-04-15 23:09:46,381 - INFO - Gene gene-SPN23F_RS00710 has a mutation rate of 0.31.
# 2025-04-15 23:09:46,382 - INFO - Gene cds-WP_000639577.1 has no mutations in the population. Skipping this gene.
# 2025-04-15 23:09:46,382 - INFO - Gene cds-SPN23F_RS13715 has no mutations in the population. Skipping this gene.
# 2025-04-15 23:09:46,382 - INFO - Gene gene-SPN23F_RS00715 has a mutation rate of 0.15.
# 2025-04-15 23:09:46,383 - INFO - Gene cds-WP_000977347.1 has no mutations in the population. Skipping this gene.
# 2025-04-15 23:09:46,383 - INFO - Gene gene-SPN23F_RS00720 has a mutation rate of 0.20666666666666667.
# 2025-04-15 23:09:46,384 - INFO - Gene cds-WP_000180803.1 has no mutations in the population. Skipping this gene.
# 2025-04-15 23:09:46,384 - INFO - Gene gene-SPN23F_RS00725 has a mutation rate of 1.0.
# 2025-04-15 23:09:46,385 - INFO - Gene cds-WP_000865706.1 has no mutations in the population. Skipping this gene.
# 2025-04-15 23:09:46,385 - INFO - Gene gene-SPN23F_RS00730 has a mutation rate of 0.6366666666666667.
# 2025-04-15 23:09:46,385 - INFO - Gene cds-WP_000569831.1 has no mutations in the population. Skipping this gene.
# 2025-04-15 23:09:46,386 - INFO - Gene gene-SPN23F_RS00735 has a mutation rate of 0.77.
# 2025-04-15 23:09:46,386 - INFO - Gene cds-WP_000655033.1 has no mutations in the population. Skipping this gene.
# 2025-04-15 23:09:46,386 - INFO - Gene cds-SPN23F_RS00745 has no mutations in the population. Skipping this gene.
# 2025-04-15 23:09:46,386 - INFO - Gene cds-SPN23F_RS13720 has no mutations in the population. Skipping this gene.
# 2025-04-15 23:09:46,387 - INFO - Gene gene-SPN23F_RS13725 has a mutation rate of 0.22333333333333333.
# 2025-04-15 23:09:46,387 - INFO - Gene cds-WP_001810713.1 has no mutations in the population. Skipping this gene.
# 2025-04-15 23:09:46,387 - INFO - Gene gene-SPN23F_RS13730 has a mutation rate of 0.6066666666666667.
# 2025-04-15 23:09:46,387 - INFO - Gene cds-WP_000371189.1 has no mutations in the population. Skipping this gene.
# 2025-04-15 23:09:46,388 - INFO - Gene gene-SPN23F_RS00770 has a mutation rate of 0.43.
# 2025-04-15 23:09:46,388 - INFO - Gene cds-WP_000375722.1 has no mutations in the population. Skipping this gene.
# 2025-04-15 23:09:46,388 - INFO - Gene gene-SPN23F_RS00775 has a mutation rate of 0.3333333333333333.
# 2025-04-15 23:09:46,389 - INFO - Gene cds-WP_000288029.1 has no mutations in the population. Skipping this gene.
# 2025-04-15 23:09:46,389 - INFO - Gene cds-SPN23F_RS14240 has no mutations in the population. Skipping this gene.
# 2025-04-15 23:09:46,389 - INFO - Gene gene-SPN23F_RS00785 has a mutation rate of 0.37333333333333335.
# 2025-04-15 23:09:46,390 - INFO - Gene cds-WP_001290270.1 has no mutations in the population. Skipping this gene.
# 2025-04-15 23:09:46,390 - INFO - Gene gene-SPN23F_RS00790 has a mutation rate of 0.5766666666666667.
# 2025-04-15 23:09:46,391 - INFO - Gene cds-WP_000069860.1 has no mutations in the population. Skipping this gene.
# 2025-04-15 23:09:46,391 - INFO - Gene gene-SPN23F_RS00795 has a mutation rate of 0.5666666666666667.
# 2025-04-15 23:09:46,391 - INFO - Gene cds-WP_001017600.1 has no mutations in the population. Skipping this gene.
# 2025-04-15 23:09:46,392 - INFO - Gene gene-SPN23F_RS00800 has a mutation rate of 0.7733333333333333.
# 2025-04-15 23:09:46,392 - INFO - Gene cds-WP_000570720.1 has no mutations in the population. Skipping this gene.
# 2025-04-15 23:09:46,392 - INFO - Gene gene-SPN23F_RS00805 has a mutation rate of 0.36666666666666664.
# 2025-04-15 23:09:46,393 - INFO - Gene cds-WP_000933464.1 has no mutations in the population. Skipping this gene.
# 2025-04-15 23:09:46,393 - INFO - Gene gene-SPN23F_RS00810 has a mutation rate of 0.7066666666666667.
# 2025-04-15 23:09:46,393 - INFO - Gene cds-WP_000720790.1 has no mutations in the population. Skipping this gene.
# 2025-04-15 23:09:46,393 - INFO - Gene gene-SPN23F_RS00815 has a mutation rate of 0.97.
# 2025-04-15 23:09:46,394 - INFO - Gene cds-WP_000862430.1 has no mutations in the population. Skipping this gene.
# 2025-04-15 23:09:46,394 - INFO - Gene gene-SPN23F_RS00825 has a mutation rate of 0.75.
# 2025-04-15 23:09:46,394 - INFO - Gene cds-WP_001141646.1 has no mutations in the population. Skipping this gene.
# 2025-04-15 23:09:46,395 - INFO - Gene cds-SPN23F_RS13735 has no mutations in the population. Skipping this gene.
# 2025-04-15 23:09:46,395 - INFO - Gene gene-SPN23F_RS00835 has a mutation rate of 0.23333333333333334.
# 2025-04-15 23:09:46,396 - INFO - Gene cds-WP_000724936.1 has no mutations in the population. Skipping this gene.
# 2025-04-15 23:09:46,396 - INFO - Gene gene-SPN23F_RS00840 has a mutation rate of 0.43333333333333335.
# 2025-04-15 23:09:46,396 - INFO - Gene cds-WP_000694512.1 has no mutations in the population. Skipping this gene.
# 2025-04-15 23:09:46,397 - INFO - Gene gene-SPN23F_RS00845 has a mutation rate of 0.6433333333333333.
# 2025-04-15 23:09:46,397 - INFO - Gene cds-WP_000231785.1 has no mutations in the population. Skipping this gene.
# 2025-04-15 23:09:46,397 - INFO - Gene gene-SPN23F_RS00850 has a mutation rate of 0.5933333333333334.
# 2025-04-15 23:09:46,398 - INFO - Gene cds-WP_000085677.1 has no mutations in the population. Skipping this gene.
# 2025-04-15 23:09:46,398 - INFO - Gene gene-SPN23F_RS00855 has a mutation rate of 0.45.
# 2025-04-15 23:09:46,398 - INFO - Gene cds-WP_000444642.1 has no mutations in the population. Skipping this gene.
# 2025-04-15 23:09:46,399 - INFO - Gene gene-SPN23F_RS00860 has a mutation rate of 0.67.
# 2025-04-15 23:09:46,399 - INFO - Gene cds-WP_000748391.1 has no mutations in the population. Skipping this gene.
# 2025-04-15 23:09:46,399 - INFO - Gene gene-SPN23F_RS00865 has a mutation rate of 0.46.
# 2025-04-15 23:09:46,400 - INFO - Gene cds-WP_000532353.1 has no mutations in the population. Skipping this gene.
# 2025-04-15 23:09:46,400 - INFO - Gene gene-SPN23F_RS00870 has a mutation rate of 0.76.
# 2025-04-15 23:09:46,401 - INFO - Gene cds-WP_000800582.1 has no mutations in the population. Skipping this gene.
# 2025-04-15 23:09:46,401 - INFO - Gene gene-SPN23F_RS00875 has a mutation rate of 0.54.
# 2025-04-15 23:09:46,401 - INFO - Gene cds-WP_000278896.1 has no mutations in the population. Skipping this gene.
# 2025-04-15 23:09:46,402 - INFO - Gene gene-SPN23F_RS00880 has a mutation rate of 0.04.
# 2025-04-15 23:09:46,402 - INFO - Gene cds-WP_000729035.1 has no mutations in the population. Skipping this gene.
# 2025-04-15 23:09:46,402 - INFO - Gene gene-SPN23F_RS00885 has a mutation rate of 0.1.
# 2025-04-15 23:09:46,403 - INFO - Gene cds-WP_000849621.1 has no mutations in the population. Skipping this gene.
# 2025-04-15 23:09:46,403 - INFO - Gene gene-SPN23F_RS00890 has a mutation rate of 0.17.
# 2025-04-15 23:09:46,403 - INFO - Gene cds-WP_000075789.1 has no mutations in the population. Skipping this gene.
# 2025-04-15 23:09:46,404 - INFO - Gene gene-SPN23F_RS00895 has a mutation rate of 0.5166666666666667.
# 2025-04-15 23:09:46,404 - INFO - Gene cds-WP_000745054.1 has no mutations in the population. Skipping this gene.
# 2025-04-15 23:09:46,405 - INFO - Gene gene-SPN23F_RS00900 has a mutation rate of 0.36333333333333334.
# 2025-04-15 23:09:46,405 - INFO - Gene cds-WP_000861955.1 has no mutations in the population. Skipping this gene.
# 2025-04-15 23:09:46,405 - INFO - Gene gene-SPN23F_RS14060 has a mutation rate of 0.4.
# 2025-04-15 23:09:46,405 - INFO - Gene cds-WP_001813544.1 has no mutations in the population. Skipping this gene.
# 2025-04-15 23:09:46,406 - INFO - Gene gene-SPN23F_RS00905 has a mutation rate of 0.32.
# 2025-04-15 23:09:46,406 - INFO - Gene cds-WP_000018169.1 has no mutations in the population. Skipping this gene.
# 2025-04-15 23:09:46,406 - INFO - Gene gene-SPN23F_RS00910 has a mutation rate of 0.15666666666666668.
# 2025-04-15 23:09:46,406 - INFO - Gene cds-WP_001099502.1 has no mutations in the population. Skipping this gene.
# 2025-04-15 23:09:46,407 - INFO - Gene gene-SPN23F_RS00915 has a mutation rate of 0.5933333333333334.
# 2025-04-15 23:09:46,407 - INFO - Gene cds-WP_000456639.1 has no mutations in the population. Skipping this gene.
# 2025-04-15 23:09:46,407 - INFO - Gene gene-SPN23F_RS00920 has a mutation rate of 0.6866666666666666.
# 2025-04-15 23:09:46,408 - INFO - Gene cds-WP_000493841.1 has no mutations in the population. Skipping this gene.
# 2025-04-15 23:09:46,408 - INFO - Gene gene-SPN23F_RS00925 has a mutation rate of 0.5833333333333334.
# 2025-04-15 23:09:46,408 - INFO - Gene cds-WP_001284100.1 has no mutations in the population. Skipping this gene.
# 2025-04-15 23:09:46,409 - INFO - Gene gene-SPN23F_RS00930 has a mutation rate of 0.56.
# 2025-04-15 23:09:46,409 - INFO - Gene cds-WP_000271489.1 has no mutations in the population. Skipping this gene.
# 2025-04-15 23:09:46,410 - INFO - Gene gene-SPN23F_RS00935 has a mutation rate of 0.9366666666666666.
# 2025-04-15 23:09:46,410 - INFO - Gene cds-WP_000166600.1 has no mutations in the population. Skipping this gene.
# 2025-04-15 23:09:46,411 - INFO - Gene gene-SPN23F_RS00940 has a mutation rate of 0.75.
# 2025-04-15 23:09:46,411 - INFO - Gene cds-WP_000987429.1 has no mutations in the population. Skipping this gene.
# 2025-04-15 23:09:46,412 - INFO - Gene gene-SPN23F_RS00945 has a mutation rate of 0.76.
# 2025-04-15 23:09:46,412 - INFO - Gene cds-WP_000255102.1 has no mutations in the population. Skipping this gene.
# 2025-04-15 23:09:46,412 - INFO - Gene gene-SPN23F_RS00950 has a mutation rate of 0.25666666666666665.
# 2025-04-15 23:09:46,413 - INFO - Gene cds-WP_000078027.1 has no mutations in the population. Skipping this gene.
# 2025-04-15 23:09:46,413 - INFO - Gene gene-SPN23F_RS00955 has a mutation rate of 0.02666666666666667.
# 2025-04-15 23:09:46,413 - INFO - Gene cds-WP_000815629.1 has no mutations in the population. Skipping this gene.
# 2025-04-15 23:09:46,414 - INFO - Gene gene-SPN23F_RS00960 has a mutation rate of 0.6533333333333333.
# 2025-04-15 23:09:46,414 - INFO - Gene cds-WP_001152894.1 has no mutations in the population. Skipping this gene.
# 2025-04-15 23:09:46,414 - INFO - Gene gene-SPN23F_RS00965 has a mutation rate of 0.47.
# 2025-04-15 23:09:46,414 - INFO - Gene cds-WP_001042860.1 has no mutations in the population. Skipping this gene.
# 2025-04-15 23:09:46,415 - INFO - Gene gene-SPN23F_RS00970 has no mutations in the population. Skipping this gene.
# 2025-04-15 23:09:46,415 - INFO - Gene cds-WP_000591165.1 has no mutations in the population. Skipping this gene.
# 2025-04-15 23:09:46,415 - INFO - Gene gene-SPN23F_RS00975 has a mutation rate of 0.47333333333333333.
# 2025-04-15 23:09:46,415 - INFO - Gene cds-WP_000725133.1 has no mutations in the population. Skipping this gene.
# 2025-04-15 23:09:46,416 - INFO - Gene gene-SPN23F_RS00980 has no mutations in the population. Skipping this gene.
# 2025-04-15 23:09:46,416 - INFO - Gene cds-WP_000507059.1 has no mutations in the population. Skipping this gene.
# 2025-04-15 23:09:46,416 - INFO - Gene gene-SPN23F_RS00985 has a mutation rate of 0.08.
# 2025-04-15 23:09:46,417 - INFO - Gene cds-WP_001808830.1 has no mutations in the population. Skipping this gene.
# 2025-04-15 23:09:46,417 - INFO - Gene gene-SPN23F_RS00990 has no mutations in the population. Skipping this gene.
# 2025-04-15 23:09:46,417 - INFO - Gene cds-WP_000017620.1 has no mutations in the population. Skipping this gene.
# 2025-04-15 23:09:46,417 - INFO - Gene gene-SPN23F_RS00995 has a mutation rate of 0.8366666666666667.
# 2025-04-15 23:09:46,418 - INFO - Gene cds-WP_000464336.1 has no mutations in the population. Skipping this gene.
# 2025-04-15 23:09:46,418 - INFO - Gene gene-SPN23F_RS01000 has a mutation rate of 0.15.
# 2025-04-15 23:09:46,418 - INFO - Gene cds-WP_000769490.1 has no mutations in the population. Skipping this gene.
# 2025-04-15 23:09:46,419 - INFO - Gene gene-SPN23F_RS01005 has a mutation rate of 0.15.
# 2025-04-15 23:09:46,419 - INFO - Gene cds-WP_000877334.1 has no mutations in the population. Skipping this gene.
# 2025-04-15 23:09:46,420 - INFO - Gene gene-SPN23F_RS13460 has a mutation rate of 0.02666666666666667.
# 2025-04-15 23:09:46,420 - INFO - Gene cds-WP_000956126.1 has no mutations in the population. Skipping this gene.
# 2025-04-15 23:09:46,421 - INFO - Gene gene-SPN23F_RS01015 has a mutation rate of 0.5766666666666667.
# 2025-04-15 23:09:46,421 - INFO - Gene cds-WP_000118100.1 has no mutations in the population. Skipping this gene.
# 2025-04-15 23:09:46,421 - INFO - Gene gene-SPN23F_RS01020 has a mutation rate of 0.56.
# 2025-04-15 23:09:46,422 - INFO - Gene cds-WP_000560899.1 has no mutations in the population. Skipping this gene.
# 2025-04-15 23:09:46,422 - INFO - Gene gene-SPN23F_RS13465 has a mutation rate of 0.14333333333333334.
# 2025-04-15 23:09:46,423 - INFO - Gene cds-WP_000521619.1 has no mutations in the population. Skipping this gene.
# 2025-04-15 23:09:46,423 - INFO - Gene gene-SPN23F_RS01030 has a mutation rate of 0.6366666666666667.
# 2025-04-15 23:09:46,424 - INFO - Gene cds-WP_000423414.1 has no mutations in the population. Skipping this gene.
# 2025-04-15 23:09:46,424 - INFO - Gene gene-SPN23F_RS01035 has a mutation rate of 0.4866666666666667.
# 2025-04-15 23:09:46,424 - INFO - Gene cds-WP_001064208.1 has no mutations in the population. Skipping this gene.
# 2025-04-15 23:09:46,425 - INFO - Gene gene-SPN23F_RS01040 has a mutation rate of 0.33666666666666667.
# 2025-04-15 23:09:46,425 - INFO - Gene cds-WP_000725993.1 has no mutations in the population. Skipping this gene.
# 2025-04-15 23:09:46,425 - INFO - Gene gene-SPN23F_RS01045 has a mutation rate of 0.013333333333333334.
# 2025-04-15 23:09:46,425 - INFO - Gene cds-WP_001284513.1 has no mutations in the population. Skipping this gene.
# 2025-04-15 23:09:46,426 - INFO - Gene gene-SPN23F_RS01050 has a mutation rate of 0.02.
# 2025-04-15 23:09:46,426 - INFO - Gene cds-WP_000160197.1 has no mutations in the population. Skipping this gene.
# 2025-04-15 23:09:46,426 - INFO - Gene gene-SPN23F_RS01055 has a mutation rate of 0.04666666666666667.
# 2025-04-15 23:09:46,427 - INFO - Gene cds-WP_000024537.1 has no mutations in the population. Skipping this gene.
# 2025-04-15 23:09:46,427 - INFO - Gene gene-SPN23F_RS01060 has a mutation rate of 0.023333333333333334.
# 2025-04-15 23:09:46,427 - INFO - Gene cds-WP_001055347.1 has no mutations in the population. Skipping this gene.
# 2025-04-15 23:09:46,427 - INFO - Gene gene-SPN23F_RS01065 has no mutations in the population. Skipping this gene.
# 2025-04-15 23:09:46,428 - INFO - Gene cds-WP_000512911.1 has no mutations in the population. Skipping this gene.
# 2025-04-15 23:09:46,428 - INFO - Gene gene-SPN23F_RS01070 has no mutations in the population. Skipping this gene.
# 2025-04-15 23:09:46,428 - INFO - Gene cds-WP_000533766.1 has no mutations in the population. Skipping this gene.
# 2025-04-15 23:09:46,429 - INFO - Gene gene-SPN23F_RS01075 has a mutation rate of 0.023333333333333334.
# 2025-04-15 23:09:46,429 - INFO - Gene cds-WP_000818137.1 has no mutations in the population. Skipping this gene.
# 2025-04-15 23:09:46,430 - INFO - Gene gene-SPN23F_RS01080 has no mutations in the population. Skipping this gene.
# 2025-04-15 23:09:46,430 - INFO - Gene cds-WP_000529936.1 has no mutations in the population. Skipping this gene.
# 2025-04-15 23:09:46,430 - INFO - Gene gene-SPN23F_RS01085 has no mutations in the population. Skipping this gene.
# 2025-04-15 23:09:46,431 - INFO - Gene cds-WP_000960946.1 has no mutations in the population. Skipping this gene.
# 2025-04-15 23:09:46,431 - INFO - Gene gene-SPN23F_RS01090 has no mutations in the population. Skipping this gene.
# 2025-04-15 23:09:46,431 - INFO - Gene cds-WP_000772918.1 has no mutations in the population. Skipping this gene.
# 2025-04-15 23:09:46,432 - INFO - Gene gene-SPN23F_RS01095 has no mutations in the population. Skipping this gene.
# 2025-04-15 23:09:46,432 - INFO - Gene cds-WP_000440801.1 has no mutations in the population. Skipping this gene.
# 2025-04-15 23:09:46,432 - INFO - Gene gene-SPN23F_RS01100 has no mutations in the population. Skipping this gene.
# 2025-04-15 23:09:46,433 - INFO - Gene cds-WP_000616545.1 has no mutations in the population. Skipping this gene.
# 2025-04-15 23:09:46,433 - INFO - Gene gene-SPN23F_RS01105 has a mutation rate of 0.013333333333333334.
# 2025-04-15 23:09:46,433 - INFO - Gene cds-WP_000497691.1 has no mutations in the population. Skipping this gene.
# 2025-04-15 23:09:46,433 - INFO - Gene gene-SPN23F_RS01110 has a mutation rate of 0.1.
# 2025-04-15 23:09:46,434 - INFO - Gene cds-WP_000013542.1 has no mutations in the population. Skipping this gene.
# 2025-04-15 23:09:46,434 - INFO - Gene gene-SPN23F_RS01115 has no mutations in the population. Skipping this gene.
# 2025-04-15 23:09:46,434 - INFO - Gene cds-WP_001085703.1 has no mutations in the population. Skipping this gene.
# 2025-04-15 23:09:46,435 - INFO - Gene gene-SPN23F_RS01120 has a mutation rate of 0.03.
# 2025-04-15 23:09:46,435 - INFO - Gene cds-WP_000245505.1 has no mutations in the population. Skipping this gene.
# 2025-04-15 23:09:46,436 - INFO - Gene gene-SPN23F_RS01125 has a mutation rate of 0.42.
# 2025-04-15 23:09:46,436 - INFO - Gene cds-WP_000086630.1 has no mutations in the population. Skipping this gene.
# 2025-04-15 23:09:46,437 - INFO - Gene gene-SPN23F_RS01130 has no mutations in the population. Skipping this gene.
# 2025-04-15 23:09:46,437 - INFO - Gene cds-WP_000624044.1 has no mutations in the population. Skipping this gene.
# 2025-04-15 23:09:46,437 - INFO - Gene gene-SPN23F_RS01135 has a mutation rate of 0.013333333333333334.
# 2025-04-15 23:09:46,438 - INFO - Gene cds-WP_000874201.1 has no mutations in the population. Skipping this gene.
# 2025-04-15 23:09:46,438 - INFO - Gene gene-SPN23F_RS01140 has a mutation rate of 0.13.
# 2025-04-15 23:09:46,438 - INFO - Gene cds-WP_000057241.1 has no mutations in the population. Skipping this gene.
# 2025-04-15 23:09:46,439 - INFO - Gene gene-SPN23F_RS01145 has no mutations in the population. Skipping this gene.
# 2025-04-15 23:09:46,439 - INFO - Gene cds-WP_000766087.1 has no mutations in the population. Skipping this gene.
# 2025-04-15 23:09:46,440 - INFO - Gene gene-SPN23F_RS01150 has a mutation rate of 0.02666666666666667.
# 2025-04-15 23:09:46,440 - INFO - Gene cds-WP_000465397.1 has no mutations in the population. Skipping this gene.
# 2025-04-15 23:09:46,440 - INFO - Gene gene-SPN23F_RS01155 has a mutation rate of 0.35333333333333333.
# 2025-04-15 23:09:46,440 - INFO - Gene cds-WP_001050431.1 has no mutations in the population. Skipping this gene.
# 2025-04-15 23:09:46,441 - INFO - Gene gene-SPN23F_RS01160 has no mutations in the population. Skipping this gene.
# 2025-04-15 23:09:46,441 - INFO - Gene cds-WP_001029883.1 has no mutations in the population. Skipping this gene.
# 2025-04-15 23:09:46,442 - INFO - Gene gene-SPN23F_RS01165 has no mutations in the population. Skipping this gene.
# 2025-04-15 23:09:46,442 - INFO - Gene cds-WP_001808836.1 has no mutations in the population. Skipping this gene.
# 2025-04-15 23:09:46,442 - INFO - Gene gene-SPN23F_RS01170 has a mutation rate of 0.013333333333333334.
# 2025-04-15 23:09:46,443 - INFO - Gene cds-WP_000090781.1 has no mutations in the population. Skipping this gene.
# 2025-04-15 23:09:46,443 - INFO - Gene gene-SPN23F_RS01175 has no mutations in the population. Skipping this gene.
# 2025-04-15 23:09:46,443 - INFO - Gene cds-WP_001118385.1 has no mutations in the population. Skipping this gene.
# 2025-04-15 23:09:46,443 - INFO - Gene gene-SPN23F_RS01180 has a mutation rate of 0.03.
# 2025-04-15 23:09:46,444 - INFO - Gene cds-WP_000568988.1 has no mutations in the population. Skipping this gene.
# 2025-04-15 23:09:46,444 - INFO - Gene gene-SPN23F_RS01185 has a mutation rate of 0.023333333333333334.
# 2025-04-15 23:09:46,444 - INFO - Gene cds-WP_000331493.1 has no mutations in the population. Skipping this gene.
# 2025-04-15 23:09:46,445 - INFO - Gene gene-SPN23F_RS01190 has a mutation rate of 0.19666666666666666.
# 2025-04-15 23:09:46,445 - INFO - Gene cds-WP_000644124.1 has no mutations in the population. Skipping this gene.
# 2025-04-15 23:09:46,445 - INFO - Gene gene-SPN23F_RS01195 has a mutation rate of 0.58.
# 2025-04-15 23:09:46,446 - INFO - Gene cds-WP_000354918.1 has no mutations in the population. Skipping this gene.
# 2025-04-15 23:09:46,446 - INFO - Gene gene-SPN23F_RS01200 has a mutation rate of 0.16.
# ...
# 2025-04-15 23:09:49,701 - INFO - Gene gene-SPN23F_RS11310 has a mutation rate of 0.44666666666666666.
# 2025-04-15 23:09:49,701 - INFO - Gene cds-WP_000588548.1 has no mutations in the population. Skipping this gene.
# 2025-04-15 23:09:49,701 - INFO - Gene gene-SPN23F_RS11315 has a mutation rate of 0.5733333333333334.
# 2025-04-15 23:09:49,702 - INFO - Gene cds-WP_000724067.1 has no mutations in the population. Skipping this gene.
# 2025-04-15 23:09:49,702 - INFO - Gene gene-SPN23F_RS11320 has a mutation rate of 0.08666666666666667.
# 2025-04-15 23:09:49,702 - INFO - Gene cds-WP_000950018.1 has no mutations in the population. Skipping this gene.
# 2025-04-15 23:09:49,703 - INFO - Gene gene-SPN23F_RS11325 has a mutation rate of 0.6633333333333333.
# 2025-04-15 23:09:49,703 - INFO - Gene cds-WP_001269488.1 has no mutations in the population. Skipping this gene.
# 2025-04-15 23:09:49,703 - INFO - Gene gene-SPN23F_RS11330 has a mutation rate of 0.02.
# 2025-04-15 23:09:49,704 - INFO - Gene cds-WP_001249309.1 has no mutations in the population. Skipping this gene.
# 2025-04-15 23:09:49,704 - INFO - Gene gene-SPN23F_RS11335 has a mutation rate of 0.16.
# 2025-04-15 23:09:49,704 - INFO - Gene cds-WP_000919857.1 has no mutations in the population. Skipping this gene.
# 2025-04-15 23:09:49,705 - INFO - Gene gene-SPN23F_RS11340 has a mutation rate of 0.03666666666666667.
# 2025-04-15 23:09:49,705 - INFO - Gene cds-WP_000351967.1 has no mutations in the population. Skipping this gene.
# 2025-04-15 23:09:49,705 - INFO - Gene gene-SPN23F_RS11345 has a mutation rate of 0.5566666666666666.
# 2025-04-15 23:09:49,705 - INFO - Gene cds-WP_000969733.1 has no mutations in the population. Skipping this gene.
# 2025-04-15 23:09:49,706 - INFO - Gene gene-SPN23F_RS11350 has a mutation rate of 0.72.
# 2025-04-15 23:09:49,706 - INFO - Gene cds-WP_000066731.1 has no mutations in the population. Skipping this gene.
# 2025-04-15 23:09:49,707 - INFO - Gene gene-SPN23F_RS11355 has no mutations in the population. Skipping this gene.
# 2025-04-15 23:09:49,707 - INFO - Gene cds-WP_000813667.1 has no mutations in the population. Skipping this gene.
# 2025-04-15 23:09:49,707 - INFO - Gene gene-SPN23F_RS11360 has a mutation rate of 0.5366666666666666.
# 2025-04-15 23:09:49,708 - INFO - Gene cds-WP_000071468.1 has no mutations in the population. Skipping this gene.
# 2025-04-15 23:09:49,708 - INFO - Gene cds-SPN23F_RS14035 has no mutations in the population. Skipping this gene.
# 2025-04-15 23:09:49,708 - INFO - Gene gene-SPN23F_RS14235 has a mutation rate of 0.056666666666666664.
# 2025-04-15 23:09:49,709 - INFO - Gene cds-WP_000930581.1 has no mutations in the population. Skipping this gene.
# 2025-04-15 23:09:49,709 - INFO - Gene gene-SPN23F_RS11380 has a mutation rate of 0.20333333333333334.
# 2025-04-15 23:09:49,709 - INFO - Gene cds-WP_001808792.1 has no mutations in the population. Skipping this gene.
# 2025-04-15 23:09:49,710 - INFO - Gene gene-SPN23F_RS11385 has a mutation rate of 0.32.
# 2025-04-15 23:09:49,710 - INFO - Gene cds-WP_001127306.1 has no mutations in the population. Skipping this gene.
# 2025-04-15 23:09:49,711 - INFO - Gene gene-SPN23F_RS11390 has a mutation rate of 0.7.
# 2025-04-15 23:09:49,711 - INFO - Gene cds-WP_000980829.1 has no mutations in the population. Skipping this gene.
# 2025-04-15 23:09:49,711 - INFO - Gene gene-SPN23F_RS11395 has a mutation rate of 0.93.
# 2025-04-15 23:09:49,711 - INFO - Gene cds-WP_000395926.1 has no mutations in the population. Skipping this gene.
# 2025-04-15 23:09:49,712 - INFO - Gene gene-SPN23F_RS11400 has a mutation rate of 0.27666666666666667.
# 2025-04-15 23:09:49,712 - INFO - Gene cds-WP_000076765.1 has no mutations in the population. Skipping this gene.
# 2025-04-15 23:09:49,712 - INFO - Gene gene-SPN23F_RS11405 has a mutation rate of 0.5333333333333333.
# 2025-04-15 23:09:49,713 - INFO - Gene cds-WP_000280548.1 has no mutations in the population. Skipping this gene.
# 2025-04-15 23:09:49,713 - INFO - Gene gene-SPN23F_RS11410 has a mutation rate of 0.62.
# 2025-04-15 23:09:49,713 - INFO - Gene cds-WP_000357847.1 has no mutations in the population. Skipping this gene.
# 2025-04-15 23:09:49,714 - INFO - Gene gene-SPN23F_RS11415 has a mutation rate of 0.4.
# 2025-04-15 23:09:49,714 - INFO - Gene cds-WP_000183311.1 has no mutations in the population. Skipping this gene.
# 2025-04-15 23:09:49,714 - INFO - Gene gene-SPN23F_RS12760 has a mutation rate of 0.9866666666666667.
# 2025-04-15 23:09:49,721 - INFO - Gene cds-WP_000458085.1 has no mutations in the population. Skipping this gene.
# 2025-04-15 23:09:49,725 - INFO - Gene gene-SPN23F_RS11425 has a mutation rate of 0.8233333333333334.
# 2025-04-15 23:09:49,742 - INFO - Gene cds-WP_000241928.1 has no mutations in the population. Skipping this gene.
# 2025-04-15 23:09:49,744 - INFO - Gene gene-SPN23F_RS11430 has a mutation rate of 0.16666666666666666.
# 2025-04-15 23:09:49,763 - INFO - Gene cds-WP_000594667.1 has no mutations in the population. Skipping this gene.
# 2025-04-15 23:09:49,764 - INFO - Gene gene-SPN23F_RS11435 has a mutation rate of 0.42.
# 2025-04-15 23:09:49,765 - INFO - Gene cds-WP_001024075.1 has no mutations in the population. Skipping this gene.
# 2025-04-15 23:09:49,765 - INFO - Gene gene-SPN23F_RS11445 has a mutation rate of 0.7766666666666666.
# 2025-04-15 23:09:49,766 - INFO - Gene cds-WP_001109685.1 has no mutations in the population. Skipping this gene.
# 2025-04-15 23:09:49,766 - INFO - Gene gene-SPN23F_RS11450 has a mutation rate of 0.45666666666666667.
# 2025-04-15 23:09:49,767 - INFO - Gene cds-WP_001211273.1 has no mutations in the population. Skipping this gene.
# 2025-04-15 23:09:49,767 - INFO - Gene gene-SPN23F_RS11455 has a mutation rate of 0.12666666666666668.
# 2025-04-15 23:09:49,768 - INFO - Gene cds-WP_000136224.1 has no mutations in the population. Skipping this gene.
# 2025-04-15 23:09:49,768 - INFO - Gene gene-SPN23F_RS11460 has a mutation rate of 0.07333333333333333.
# 2025-04-15 23:09:49,773 - INFO - Gene cds-WP_000754546.1 has no mutations in the population. Skipping this gene.
# 2025-04-15 23:09:49,776 - INFO - Gene gene-SPN23F_RS11465 has a mutation rate of 0.58.
# 2025-04-15 23:09:49,777 - INFO - Gene cds-WP_001813866.1 has no mutations in the population. Skipping this gene.
# 2025-04-15 23:09:49,777 - INFO - Gene gene-SPN23F_RS11470 has a mutation rate of 0.3466666666666667.
# 2025-04-15 23:09:49,777 - INFO - Gene cds-WP_000647690.1 has no mutations in the population. Skipping this gene.
# 2025-04-15 23:09:49,778 - INFO - Gene gene-SPN23F_RS11475 has a mutation rate of 0.7733333333333333.
# 2025-04-15 23:09:49,778 - INFO - Gene cds-WP_000698561.1 has no mutations in the population. Skipping this gene.
# 2025-04-15 23:09:49,779 - INFO - Gene gene-SPN23F_RS11480 has no mutations in the population. Skipping this gene.
# 2025-04-15 23:09:49,779 - INFO - Gene cds-WP_001278167.1 has no mutations in the population. Skipping this gene.
# 2025-04-15 23:09:49,780 - INFO - Gene gene-SPN23F_RS11485 has a mutation rate of 0.17333333333333334.
# 2025-04-15 23:09:49,780 - INFO - Gene cds-WP_000852486.1 has no mutations in the population. Skipping this gene.
# 2025-04-15 23:09:49,780 - INFO - Gene gene-SPN23F_RS11490 has no mutations in the population. Skipping this gene.
# 2025-04-15 23:09:49,781 - INFO - Gene cds-WP_000864220.1 has no mutations in the population. Skipping this gene.
# 2025-04-15 23:09:49,781 - INFO - Gene gene-SPN23F_RS11495 has a mutation rate of 0.42.
# 2025-04-15 23:09:49,837 - INFO - Gene cds-WP_000715123.1 has no mutations in the population. Skipping this gene.
# 2025-04-15 23:09:49,837 - INFO - Gene gene-SPN23F_RS11500 has a mutation rate of 0.02.
# 2025-04-15 23:09:49,838 - INFO - Gene cds-WP_000599107.1 has no mutations in the population. Skipping this gene.
# 2025-04-15 23:09:49,838 - INFO - Gene gene-SPN23F_RS11505 has a mutation rate of 0.16666666666666666.
# 2025-04-15 23:09:49,839 - INFO - Gene cds-WP_000649974.1 has no mutations in the population. Skipping this gene.
# 2025-04-15 23:09:49,843 - INFO - Gene gene-SPN23F_RS11510 has a mutation rate of 0.9266666666666666.
# 2025-04-15 23:09:49,845 - INFO - Gene cds-WP_000867608.1 has no mutations in the population. Skipping this gene.
# 2025-04-15 23:09:49,845 - INFO - Gene gene-SPN23F_RS11515 has a mutation rate of 0.31666666666666665.
# 2025-04-15 23:09:49,846 - INFO - Gene cds-WP_000395739.1 has no mutations in the population. Skipping this gene.
# 2025-04-15 23:09:49,846 - INFO - Gene gene-SPN23F_RS11520 has a mutation rate of 0.59.
# 2025-04-15 23:09:49,846 - INFO - Gene cds-WP_000029866.1 has no mutations in the population. Skipping this gene.
# 2025-04-15 23:09:49,847 - INFO - Gene cds-SPN23F_RS11525 has no mutations in the population. Skipping this gene.
# 2025-04-15 23:09:49,847 - INFO - Gene cds-SPN23F_RS11530 has no mutations in the population. Skipping this gene.
# 2025-04-15 23:09:49,847 - INFO - Gene gene-SPN23F_RS11535 has a mutation rate of 0.54.
# 2025-04-15 23:09:49,847 - INFO - Gene cds-WP_000973408.1 has no mutations in the population. Skipping this gene.
# 2025-04-15 23:09:49,848 - INFO - Gene gene-SPN23F_RS11540 has a mutation rate of 0.18333333333333332.
# 2025-04-15 23:09:49,848 - INFO - Gene cds-WP_000808063.1 has no mutations in the population. Skipping this gene.
# 2025-04-15 23:09:49,849 - INFO - Gene gene-SPN23F_RS11545 has a mutation rate of 0.28.
# 2025-04-15 23:09:49,849 - INFO - Gene cds-WP_000268466.1 has no mutations in the population. Skipping this gene.
# 2025-04-15 23:09:49,849 - INFO - Gene gene-SPN23F_RS11550 has a mutation rate of 0.20666666666666667.
# 2025-04-15 23:09:49,850 - INFO - Gene cds-WP_000727012.1 has no mutations in the population. Skipping this gene.
# 2025-04-15 23:09:49,850 - INFO - Gene gene-SPN23F_RS11555 has a mutation rate of 0.17.
# 2025-04-15 23:09:49,850 - INFO - Gene cds-WP_001249454.1 has no mutations in the population. Skipping this gene.
# 2025-04-15 23:09:49,851 - INFO - Gene gene-SPN23F_RS11560 has a mutation rate of 0.12.
# 2025-04-15 23:09:49,851 - INFO - Gene cds-WP_001078983.1 has no mutations in the population. Skipping this gene.
# 2025-04-15 23:09:49,851 - INFO - Gene gene-SPN23F_RS11565 has a mutation rate of 0.11.
# 2025-04-15 23:09:49,851 - INFO - Gene cds-WP_000377893.1 has no mutations in the population. Skipping this gene.
# 2025-04-15 23:09:49,852 - INFO - Gene gene-SPN23F_RS11570 has a mutation rate of 0.2633333333333333.
# 2025-04-15 23:09:49,852 - INFO - Gene cds-WP_000510412.1 has no mutations in the population. Skipping this gene.
# 2025-04-15 23:09:49,852 - INFO - Gene gene-SPN23F_RS11575 has a mutation rate of 0.36333333333333334.
# 2025-04-15 23:09:49,852 - INFO - Gene cds-WP_000835715.1 has no mutations in the population. Skipping this gene.
# 2025-04-15 23:09:49,853 - INFO - Gene gene-SPN23F_RS11580 has a mutation rate of 0.25666666666666665.
# 2025-04-15 23:09:49,853 - INFO - Gene cds-WP_000712132.1 has no mutations in the population. Skipping this gene.
# 2025-04-15 23:09:49,854 - INFO - Gene gene-SPN23F_RS11585 has a mutation rate of 0.17666666666666667.
# 2025-04-15 23:09:49,854 - INFO - Gene cds-WP_001227958.1 has no mutations in the population. Skipping this gene.
# 2025-04-15 23:09:49,854 - INFO - Gene gene-SPN23F_RS11590 has a mutation rate of 0.86.
# 2025-04-15 23:09:49,854 - INFO - Gene cds-WP_000170191.1 has no mutations in the population. Skipping this gene.
# 2025-04-15 23:09:49,855 - INFO - Gene gene-SPN23F_RS11595 has a mutation rate of 0.6966666666666667.
# 2025-04-15 23:09:49,855 - INFO - Gene cds-WP_000424267.1 has no mutations in the population. Skipping this gene.
# 2025-04-15 23:09:49,856 - INFO - Gene gene-SPN23F_RS11600 has a mutation rate of 0.17666666666666667.
# 2025-04-15 23:09:49,857 - INFO - Gene cds-WP_000455903.1 has no mutations in the population. Skipping this gene.
# 2025-04-15 23:09:49,861 - INFO - Gene gene-SPN23F_RS11605 has a mutation rate of 0.34.
# 2025-04-15 23:09:49,862 - INFO - Gene cds-WP_000266669.1 has no mutations in the population. Skipping this gene.
# 2025-04-15 23:09:49,863 - INFO - Gene gene-SPN23F_RS11610 has a mutation rate of 0.15.
# 2025-04-15 23:09:49,863 - INFO - Gene cds-WP_000073428.1 has no mutations in the population. Skipping this gene.
# 2025-04-15 23:09:49,864 - INFO - Gene gene-SPN23F_RS11615 has a mutation rate of 0.07666666666666666.
# 2025-04-15 23:09:49,864 - INFO - Gene cds-WP_000165444.1 has no mutations in the population. Skipping this gene.
# 2025-04-15 23:09:49,864 - INFO - Gene gene-SPN23F_RS11620 has a mutation rate of 0.03.
# 2025-04-15 23:09:49,865 - INFO - Gene cds-WP_000958769.1 has no mutations in the population. Skipping this gene.
# 2025-04-15 23:09:49,865 - INFO - Gene gene-SPN23F_RS11625 has a mutation rate of 0.85.
# 2025-04-15 23:09:49,865 - INFO - Gene cds-WP_000834663.1 has no mutations in the population. Skipping this gene.
# 2025-04-15 23:09:49,866 - INFO - Gene cds-SPN23F_RS14040 has no mutations in the population. Skipping this gene.
# 2025-04-15 23:09:49,866 - INFO - Gene gene-SPN23F_RS11645 has a mutation rate of 0.16666666666666666.
# 2025-04-15 23:09:49,866 - INFO - Gene cds-WP_001158266.1 has no mutations in the population. Skipping this gene.
# 2025-04-15 23:09:49,866 - INFO - Gene gene-SPN23F_RS11650 has no mutations in the population. Skipping this gene.
# 2025-04-15 23:09:49,867 - INFO - Gene gene-SPN23F_RS11655 has no mutations in the population. Skipping this gene.
# 2025-04-15 23:09:49,867 - INFO - Gene gene-SPN23F_RS11660 has a mutation rate of 0.21.
# 2025-04-15 23:09:49,867 - INFO - Gene cds-WP_000866065.1 has no mutations in the population. Skipping this gene.
# 2025-04-15 23:09:49,868 - INFO - Gene gene-SPN23F_RS11665 has a mutation rate of 0.86.
# 2025-04-15 23:09:49,868 - INFO - Gene cds-WP_000364843.1 has no mutations in the population. Skipping this gene.
# 2025-04-15 23:09:49,868 - INFO - Gene gene-SPN23F_RS11670 has a mutation rate of 0.023333333333333334.
# 2025-04-15 23:09:49,869 - INFO - Gene cds-WP_000799694.1 has no mutations in the population. Skipping this gene.
# 2025-04-15 23:09:49,869 - INFO - Gene gene-SPN23F_RS11675 has no mutations in the population. Skipping this gene.
# 2025-04-15 23:09:49,870 - INFO - Gene gene-SPN23F_RS11680 has a mutation rate of 0.04666666666666667.
# 2025-04-15 23:09:49,870 - INFO - Gene cds-WP_000695929.1 has no mutations in the population. Skipping this gene.
# 2025-04-15 23:09:49,871 - INFO - Gene gene-SPN23F_RS11685 has a mutation rate of 0.30666666666666664.
# 2025-04-15 23:09:49,871 - INFO - Gene cds-WP_000681598.1 has no mutations in the population. Skipping this gene.
# 2025-04-15 23:09:49,871 - INFO - Gene gene-SPN23F_RS11690 has a mutation rate of 0.25333333333333335.
# 2025-04-15 23:09:49,872 - INFO - Gene cds-WP_000410383.1 has no mutations in the population. Skipping this gene.
# 2025-04-15 23:09:49,872 - INFO - Integrating 1775 genes to run GWAS on pyseer.
# 2025-04-15 23:09:49,874 - INFO - Skipped 2536 genes with no mutations.
# 2025-04-15 23:09:49,875 - INFO - Converted mutation summary file pyseer_dataset/gene_mutation_summary.txt to numeric format and saved as pyseer_dataset/gene_mutation_summary_filtered_numeric.txt.
# 2025-04-15 23:09:49,876 - INFO - Running pyseer with command: pyseer --lmm --phenotypes pyseer_dataset/resistances.subset.txt --similarity pyseer_dataset/phylogeny_distances.tsv --pres pyseer_dataset/gene_mutation_summary_filtered_numeric.txt > pyseer_dataset/muggwas_output/pyseer_results.txt
# Read 300 phenotypes
# Detected binary phenotype
# Setting up LMM
# Similarity matrix has dimension (616, 616)
# Analysing 300 samples found in both phenotype and similarity matrix
# h^2 = 0.87
# 1775 loaded variants
# 19 pre-filtered variants
# 1756 tested variants
# 1756 printed variants
# 2025-04-15 23:09:53,103 - INFO - Pyseer run completed successfully.
# 2025-04-15 23:09:53,104 - INFO - GWAS results are saved in pyseer_dataset/muggwas_output
# 2025-04-15 23:09:53,105 - INFO - Script completed in 0 hours, 0 minutes, and 6 seconds.
# 2025-04-15 23:09:53,105 - INFO - Finished running pyseer.
# 2025-04-15 23:09:53,105 - INFO - GWAS analysis completed.

# %% [markdown]
# ## **Future Direction**
#
# 1. Add statistical significance threshold to the GWAS result:
# - The Bonferroni threshold depends on how many genes are tested.
#
# 2. Add a plotting module:
# - Input: `gwas_result.txt`
# - Output:
#     1. Q-Q plot: `gwas_result.qq.png`
#     2. manhattan plot: `gwas_result.man.png`
# - Functionality: Plot Q-Q plots and manhattan plots.
