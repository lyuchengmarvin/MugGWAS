# %% [markdown]
# # **Mutated-gene Genome-Wide Association Study (MugGWAS)**

# %% [markdown]
# MugGWAS offers an non-model-organism-friendly pipeline to infer gene-trait association. It tackles common challenges faced by non-model organism research—such as lack of readily available annotation databases and small sample sizes—by integrating a simple annotation pipeline with mutation-centric GWAS analysis. Users can identify putative gene mutations that drive phenotypic change without the large statistical power required to perform genome-wide tests on a per nucleotide basis.

# %% [markdown]
# ## **Motivation**
#
# Understanding the genetic basis of a trait is central to many biological research that help gain mechanismtic insight into complex biological phenomena. For instance, the discovery of genetic loci that contribute to antibiotic resistance could better our knowledge for how important pathogens evolve to escape medicinal application.
#
# Most association tools classify raw genetic variants (like single nucleotide polymorphisms or structural variants) into reference or alternative genotypes, then perform statistical tests to infer associations between particular variants and phenotypes. However, genome-wide analyses typically require large sample sizes for statistical power—a major challenge for organisms that are difficult to culture or traits that are challenging to measure. Alternative approaches test associations between phenotypes and gene presence/absence, but these methods don't capture finer details like important mutations that potentially disrupt gene function.
#
# Mutated-gene Genome-Wide Association Study (MugGWAS) addresses these limitations by offering a non-model-organism-friendly pipeline to infer gene-trait associations. By annotating disruptive mutation types (nonsense, missense, stopgain, or nonstop), MugGWAS identifies putative gene dysfunctions associated with phenotypic changes. This approach conserves statistical power by avoiding tests on variants that either (1) don't affect function at the gene level or (2) result in disruption of the same gene, allowing users to identify putative gene mutations driving phenotypic changes without the large statistical power required for per-nucleotide genome-wide tests.

# %% [markdown]
# ## **Short Guide:**
# MugGWAS offers an non-model-organism-friendly pipeline to infer gene-trait association.
#
# **Common GWAS tools:**
# - Classify raw genetic variants (like SNPs or Indels) into reference or alternative genotypes.
# - Caveats:
#     1. require large sample sizes for statistical power—a major challenge.
#     2. hard for organisms that are difficult to culture or traits that are challenging to measure.
#     3. most variants don't affect functions on the gene level, i.e. synonymous mutations.
#
# **Mutated-gene (Mug) GWAS:**
# - Tackles common challanges for non-model organisms.
# - Integrates a simple annotation pipeline with mutation-centric GWAS analysis.
# - Identify putative gene mutations associated with phenotypic change.

# %% [markdown]
# ## **Prerquisites**
# MugGWAS uses the external tool-**ANNOVAR** to annotate variants. Please follow the [instructions](http://annovar.openbioinformatics.org/en/latest/) to download **ANNOVAR** (_registration is required_), and specify the path to ANNOVAR scripts for MugGWAS. More instructions are provided below.
#
# This package uses the fixed effect model in [**pyseer**](https://pyseer.readthedocs.io/en/master/index.html) for association analysis. Users don't need to download **Pyseer** and the [prerequisites](https://pyseer.readthedocs.io/en/master/installation.html#prerequisites) themselves. They will be included in the conda environments following the instructions below.

# %% [markdown]
# ## **Installation Guide**
#
# The easiest way to install MugGWAS and fulfill the prerequites is through this path:
#
# #### **Build Conda Environment**
#
# Download the [environmental.yaml](https://github.com/lyuchengmarvin/MugGWAS/blob/main/envs/environment.yaml) file for setting up your conda environement. You can download it using this command in your terminal.
#
# ```{command line}
# wget https://github.com/lyuchengmarvin/MugGWAS/blob/main/envs/environment.yaml
# ```
#
# Build the environment to satisfy software prerequisites and ensure applicability.
#
# ```{command line}
# conda env create --name muggwas --file envs/environment.yaml
# ```
#
# Activate envrionment before use each time:
#
# ```{command line}
# conda activate muggwas
# ```
#
# Deactivate after use:
#
# ```{command line}
# conda deactivate
# ```
#
# #### **Install MugGWAS**
#
# Install MugGWAS in your environment and make sure that all prerequisites are fulfilled.
#
# ```{command line}
# pip install -i https://test.pypi.org/simple/ MugGWAS
# ```
# You might need to restart the kernal to run this tutorial in Jupyter Notebook.

# %% [markdown]
# ## **Tutaorial**
#
# ### **Download the Tutorial Dataset**
# Type this command in your terminal to download the [dataset](https://github.com/lyuchengmarvin/MugGWAS/tree/main/tutorials/data/pyseer_dataset). Remeber to place this under the same directory of this tutorial file.
# ```{comand line}
# wget https://github.com/lyuchengmarvin/MugGWAS/tree/main/tutorials/data/pyseer_dataset
# ```
#
# ### **Description of the Dataset:**
# *Streptococcus pneumoniae* is a common nasopharyngeal commensal bacterium and an important human pathogen. This dataset consists of 616 annotated draft genomes of *S. pneumoniae* isolates collected from children routine primary care visits in Massachusetts in 2001 (Croucher et al. 2015). These genotypic data can be paired with phenotypic information, such as minimum inhibitory concentrations for antibiotics, to study resistance evolution and epidemiology.
#
# ### **Overview:**
# 1. Annotate variants
# 2. Build gene mutation table
# 3. Estimate population structure effect
# 4. Run GWAS with pyseer
#
# ![MugGWAS Workflow](MugGWAS_workflow.png)

# %% [markdown]
# ### **Step 1: Annotate variants with ANNOVAR**
#
# We will use the external tool ANNOVAR and annotate the variants from vcf files. Although one vcf file should contain the variant information for multiple samples, ANNOVAR annotates samples iteratively and create an annotation file per sample.
#
# This tool also assumed that users will build their customized database for their none-model organisms, so a genome annotation **<ref_prefix>.gff3** and a genome fasta file **<ref_prefix>.fna** are required and placed in the directory **<ref_prefix>/**. The database will utilize the tool `gff3ToGenePred` to build the database, which was also built when users created their conda environments.
#
#
# **Annotation workflow**
#
# 1. **Make input files**:
#     - Input: a VCF file `vcf_prefix.vcf` (with multiple samples)
#     - Convert VCF to ANNOVAR input format `vcf_prefix.<sample_name>.avinput`
#     - Store in `/path_to_vcf/annovar_files/`
# 2. **Build database**:
#     - Input: `ref_prefix.gff3` and `ref_prefix.fna` in `db_dir/`
#     - Build customized database: `ref_prefix_refGene.txt` and `ref_prefix_refGeneMrna.fa`
# 3. **Annotate variants with ANNOVAR**:
#     - Output1: `vcf_prefix.<sample_name>.avinput.variant_function` infer mutation position on a gene.
#     - Output2: `vcf_prefix.<sample_name>.avinput.exonic_variant_function` infer mutation effects on translation, namely synonymous, nonsynonymous, stop codon gain, or stop codon loss.

# %%
from muggwas import run_annovar

## User inputs
# the path to the ANNOVAR installation
annovar_dir = '../annovar/'
# the directory where the reference files are located
db_dir = 'pyseer_dataset/Spn23F/' #ref is susceptible to penicillin
# path to the vcf file
input_dir = 'pyseer_dataset/original_dataset/snps.newname.vcf.gz'
# output prefix or the converted annovar input file
vcf_prefix = 'snps'
# output prefix for the annovar database
ref_prefix = 'Spn23F' #ref is susceptible to penicillin

## Run ANNOVAR
run_annovar(
    annovar_dir=annovar_dir,
    db_dir=db_dir,
    input_dir=input_dir,
    vcf_prefix=vcf_prefix,
    ref_prefix=ref_prefix
)
# Out:
# Converting VCF file to annovar input format...
# NOTICE: output files will be written to pyseer_dataset/original_dataset/annovar_files/snps.<samplename>.avinput
# NOTICE: Finished reading 198255 lines from VCF file
# NOTICE: A total of 198248 locus in VCF file passed QC threshold, representing 177962 SNPs (119583 transitions and 41089 transversions) and 0 indels/substitutions
# NOTICE: Finished writing 6466277 SNP genotypes (4889814 transitions and 1576463 transversions) and 0 indels/substitutions for 603 samples
# WARNING: 37576 invalid alternative alleles found in input file
# WARNING: 20286 invalid reference alleles found in input file
# The VCF file has been converted and saved to pyseer_dataset/original_dataset/annovar_files/.
# NOTICE: Reading region file pyseer_dataset/Spn23F/Spn23F_refGene.txt ... Done with 2271 regions from 1 chromosomes
# NOTICE: Finished reading 1 sequences from pyseer_dataset/Spn23F/Spn23F.fna
# NOTICE: Finished writting FASTA for 2271 genomic regions to pyseer_dataset/Spn23F/Spn23F_refGeneMrna.fa
# WARNING: 3 regions occur more than once with discordant sequence length (for example, cds-WP_000997239.1, cds-WP_087671856.1, cds-WP_010963246.1)
# WARNING: 111 gene regions do not have complete ORF (for example, cds-SPN23F_RS12435NC_011900.1:1406982, cds-SPN23F_RS12945NC_011900.1:989147, cds-SPN23F_RS08965NC_011900.1:1716895, cds-SPN23F_RS07285NC_011900.1:1402783, cds-SPN23F_RS13695NC_011900.1:122237)
# 2025-04-23 21:49:12,454 - INFO - Starting parallel annotation of avinput files.
# Database has been built and saved to pyseer_dataset/Spn23F/.
#
# Annotating avinput files...
# NOTICE: Output files are written to pyseer_dataset/original_dataset/annovar_files/snps.6999_5#22.avinput.variant_function, pyseer_dataset/original_dataset/annovar_files/snps.6999_5#22.avinput.exonic_variant_function
# NOTICE: Output files are written to pyseer_dataset/original_dataset/annovar_files/snps.6999_7#17.avinput.variant_function, pyseer_dataset/original_dataset/annovar_files/snps.6999_7#17.avinput.exonic_variant_function
# NOTICE: Reading gene annotation from pyseer_dataset/Spn23F/Spn23F_refGene.txt ... NOTICE: Output files are written to pyseer_dataset/original_dataset/annovar_files/snps.7553_5#63.avinput.variant_function, pyseer_dataset/original_dataset/annovar_files/snps.7553_5#63.avinput.exonic_variant_function
# NOTICE: Reading gene annotation from pyseer_dataset/Spn23F/Spn23F_refGene.txt ... NOTICE: Reading gene annotation from pyseer_dataset/Spn23F/Spn23F_refGene.txt ... NOTICE: Output files are written to pyseer_dataset/original_dataset/annovar_files/snps.7001_1#1.avinput.variant_function, pyseer_dataset/original_dataset/annovar_files/snps.7001_1#1.avinput.exonic_variant_function
# NOTICE: Reading gene annotation from pyseer_dataset/Spn23F/Spn23F_refGene.txt ... NOTICE: Output files are written to pyseer_dataset/original_dataset/annovar_files/snps.7622_2#19.avinput.variant_function, pyseer_dataset/original_dataset/annovar_files/snps.7622_2#19.avinput.exonic_variant_function
# NOTICE: Reading gene annotation from pyseer_dataset/Spn23F/Spn23F_refGene.txt ... NOTICE: Output files are written to pyseer_dataset/original_dataset/annovar_files/snps.6925_2#94.avinput.variant_function, pyseer_dataset/original_dataset/annovar_files/snps.6925_2#94.avinput.exonic_variant_function
# NOTICE: Output files are written to pyseer_dataset/original_dataset/annovar_files/snps.7553_5#73.avinput.variant_function, pyseer_dataset/original_dataset/annovar_files/snps.7553_5#73.avinput.exonic_variant_function
# NOTICE: Reading gene annotation from pyseer_dataset/Spn23F/Spn23F_refGene.txt ... NOTICE: Reading gene annotation from pyseer_dataset/Spn23F/Spn23F_refGene.txt ... Done with 2271 transcripts (including 70 without coding sequence annotation) for 2268 unique genes
# NOTICE: Output files are written to pyseer_dataset/original_dataset/annovar_files/snps.6925_2#84.avinput.variant_function, pyseer_dataset/original_dataset/annovar_files/snps.6925_2#84.avinput.exonic_variant_function
# NOTICE: Reading gene annotation from pyseer_dataset/Spn23F/Spn23F_refGene.txt ... Done with 2271 transcripts (including 70 without coding sequence annotation) for 2268 unique genes
# Done with 2271 transcripts (including 70 without coding sequence annotation) for 2268 unique genes
# Done with 2271 transcripts (including 70 without coding sequence annotation) for 2268 unique genes
# Done with 2271 transcripts (including 70 without coding sequence annotation) for 2268 unique genes
# Done with 2271 transcripts (including 70 without coding sequence annotation) for 2268 unique genes
# Done with 2271 transcripts (including 70 without coding sequence annotation) for 2268 unique genes
# Done with 2271 transcripts (including 70 without coding sequence annotation) for 2268 unique genes
# NOTICE: Processing next batch with 7868 unique variants in 7868 input lines
# NOTICE: Processing next batch with 10786 unique variants in 10786 input lines
# NOTICE: Processing next batch with 10038 unique variants in 10038 input lines
# NOTICE: Processing next batch with 11592 unique variants in 11592 input lines
# NOTICE: Processing next batch with 9595 unique variants in 9595 input lines
# NOTICE: Processing next batch with 11798 unique variants in 11798 input lines
# NOTICE: Processing next batch with 10754 unique variants in 10754 input lines
# NOTICE: Processing next batch with 10811 unique variants in 10811 input lines
# NOTICE: Reading FASTA sequences from pyseer_dataset/Spn23F/Spn23F_refGeneMrna.fa ... Done with 1344 sequences
# WARNING: A total of 111 sequences will be ignored due to lack of correct ORF annotation
#
# ---------------------------------------------------------------------------------------
# WARNING: 3045 exonic SNPs have WRONG reference alleles specified in your input file!
# WARNING: An example input line is <NC_011900.1	731818	731818	A	G	hom	.	.>
# WARNING: ANNOVAR can still annotate exonic_variant_function for the mutation correctly!
# WARNING: you may have used wrong -buildver, or specified incorrect reference allele, or used outdated mRNA FASTA file!
# ---------------------------------------------------------------------------------------
#
# 2025-04-23 21:49:14,972 - INFO - Successfully annotated pyseer_dataset/original_dataset/annovar_files/snps.6999_5#22.avinput
# NOTICE: Output files are written to pyseer_dataset/original_dataset/annovar_files/snps.7622_3#89.avinput.variant_function, pyseer_dataset/original_dataset/annovar_files/snps.7622_3#89.avinput.exonic_variant_function
# NOTICE: Reading gene annotation from pyseer_dataset/Spn23F/Spn23F_refGene.txt ... Done with 2271 transcripts (including 70 without coding sequence annotation) for 2268 unique genes
# NOTICE: Processing next batch with 10571 unique variants in 10571 input lines
# NOTICE: Reading FASTA sequences from pyseer_dataset/Spn23F/Spn23F_refGeneMrna.fa ... NOTICE: Reading FASTA sequences from pyseer_dataset/Spn23F/Spn23F_refGeneMrna.fa ... Done with 1447 sequences
# WARNING: A total of 111 sequences will be ignored due to lack of correct ORF annotation
# Done with 1459 sequences
# WARNING: A total of 111 sequences will be ignored due to lack of correct ORF annotation
# NOTICE: Reading FASTA sequences from pyseer_dataset/Spn23F/Spn23F_refGeneMrna.fa ... Done with 1469 sequences
# WARNING: A total of 111 sequences will be ignored due to lack of correct ORF annotation
# NOTICE: Reading FASTA sequences from pyseer_dataset/Spn23F/Spn23F_refGeneMrna.fa ...
# ---------------------------------------------------------------------------------------
# WARNING: 2023 exonic SNPs have WRONG reference alleles specified in your input file!
# WARNING: An example input line is <NC_011900.1	511990	511990	C	T	hom	.	.>
# WARNING: ANNOVAR can still annotate exonic_variant_function for the mutation correctly!
# WARNING: you may have used wrong -buildver, or specified incorrect reference allele, or used outdated mRNA FASTA file!
# ---------------------------------------------------------------------------------------
#
# NOTICE: Reading FASTA sequences from pyseer_dataset/Spn23F/Spn23F_refGeneMrna.fa ...
# ---------------------------------------------------------------------------------------
# WARNING: 1901 exonic SNPs have WRONG reference alleles specified in your input file!
# WARNING: An example input line is <NC_011900.1	189572	189572	G	T	hom	.	.>
# WARNING: ANNOVAR can still annotate exonic_variant_function for the mutation correctly!
# WARNING: you may have used wrong -buildver, or specified incorrect reference allele, or used outdated mRNA FASTA file!
# ---------------------------------------------------------------------------------------
#
# Done with 1522 sequences
# WARNING: A total of 111 sequences will be ignored due to lack of correct ORF annotation
# 2025-04-23 21:49:15,408 - INFO - Successfully annotated pyseer_dataset/original_dataset/annovar_files/snps.6925_2#94.avinput
# Done with 1534 sequences
# WARNING: A total of 111 sequences will be ignored due to lack of correct ORF annotation
# 2025-04-23 21:49:15,420 - INFO - Successfully annotated pyseer_dataset/original_dataset/annovar_files/snps.6999_7#17.avinput
#
# ---------------------------------------------------------------------------------------
# WARNING: 2131 exonic SNPs have WRONG reference alleles specified in your input file!
# WARNING: An example input line is <NC_011900.1	405131	405131	A	G	hom	.	.>
# WARNING: ANNOVAR can still annotate exonic_variant_function for the mutation correctly!
# WARNING: you may have used wrong -buildver, or specified incorrect reference allele, or used outdated mRNA FASTA file!
# ---------------------------------------------------------------------------------------
#
# NOTICE: Output files are written to pyseer_dataset/original_dataset/annovar_files/snps.7553_6#7.avinput.variant_function, pyseer_dataset/original_dataset/annovar_files/snps.7553_6#7.avinput.exonic_variant_function
# NOTICE: Reading gene annotation from pyseer_dataset/Spn23F/Spn23F_refGene.txt ... NOTICE: Output files are written to pyseer_dataset/original_dataset/annovar_files/snps.7553_4#28.avinput.variant_function, pyseer_dataset/original_dataset/annovar_files/snps.7553_4#28.avinput.exonic_variant_function
# NOTICE: Reading gene annotation from pyseer_dataset/Spn23F/Spn23F_refGene.txt ... NOTICE: Reading FASTA sequences from pyseer_dataset/Spn23F/Spn23F_refGeneMrna.fa ... 2025-04-23 21:49:15,541 - INFO - Successfully annotated pyseer_dataset/original_dataset/annovar_files/snps.6925_2#84.avinput
#
# ---------------------------------------------------------------------------------------
# WARNING: 1942 exonic SNPs have WRONG reference alleles specified in your input file!
# WARNING: An example input line is <NC_011900.1	860468	860468	C	T	hom	.	.>
# WARNING: ANNOVAR can still annotate exonic_variant_function for the mutation correctly!
# WARNING: you may have used wrong -buildver, or specified incorrect reference allele, or used outdated mRNA FASTA file!
# ---------------------------------------------------------------------------------------
#
# Done with 1440 sequences
# WARNING: A total of 111 sequences will be ignored due to lack of correct ORF annotation
# Done with 2271 transcripts (including 70 without coding sequence annotation) for 2268 unique genes
# Done with 2271 transcripts (including 70 without coding sequence annotation) for 2268 unique genes
# 2025-04-23 21:49:15,566 - INFO - Successfully annotated pyseer_dataset/original_dataset/annovar_files/snps.7001_1#1.avinput
#
# ---------------------------------------------------------------------------------------
# WARNING: 2186 exonic SNPs have WRONG reference alleles specified in your input file!
# WARNING: An example input line is <NC_011900.1	422145	422145	C	T	hom	.	.>
# WARNING: ANNOVAR can still annotate exonic_variant_function for the mutation correctly!
# WARNING: you may have used wrong -buildver, or specified incorrect reference allele, or used outdated mRNA FASTA file!
# ---------------------------------------------------------------------------------------
#
# 2025-04-23 21:49:15,614 - INFO - Successfully annotated pyseer_dataset/original_dataset/annovar_files/snps.7553_5#73.avinput
# NOTICE: Processing next batch with 11944 unique variants in 11944 input lines
# NOTICE: Processing next batch with 12517 unique variants in 12517 input lines
# NOTICE: Output files are written to pyseer_dataset/original_dataset/annovar_files/snps.7553_4#38.avinput.variant_function, pyseer_dataset/original_dataset/annovar_files/snps.7553_4#38.avinput.exonic_variant_function
# NOTICE: Reading gene annotation from pyseer_dataset/Spn23F/Spn23F_refGene.txt ... Done with 2271 transcripts (including 70 without coding sequence annotation) for 2268 unique genes
# NOTICE: Output files are written to pyseer_dataset/original_dataset/annovar_files/snps.7622_5#94.avinput.variant_function, pyseer_dataset/original_dataset/annovar_files/snps.7622_5#94.avinput.exonic_variant_function
# NOTICE: Reading gene annotation from pyseer_dataset/Spn23F/Spn23F_refGene.txt ...
# ---------------------------------------------------------------------------------------
# WARNING: 1873 exonic SNPs have WRONG reference alleles specified in your input file!
# WARNING: An example input line is <NC_011900.1	1621668	1621668	T	C	hom	.	.>
# WARNING: ANNOVAR can still annotate exonic_variant_function for the mutation correctly!
# WARNING: you may have used wrong -buildver, or specified incorrect reference allele, or used outdated mRNA FASTA file!
# ---------------------------------------------------------------------------------------
#
# Done with 2271 transcripts (including 70 without coding sequence annotation) for 2268 unique genes
# 2025-04-23 21:49:15,746 - INFO - Successfully annotated pyseer_dataset/original_dataset/annovar_files/snps.7553_5#63.avinput
# NOTICE: Reading FASTA sequences from pyseer_dataset/Spn23F/Spn23F_refGeneMrna.fa ... NOTICE: Output files are written to pyseer_dataset/original_dataset/annovar_files/snps.7622_5#84.avinput.variant_function, pyseer_dataset/original_dataset/annovar_files/snps.7622_5#84.avinput.exonic_variant_function
# NOTICE: Reading gene annotation from pyseer_dataset/Spn23F/Spn23F_refGene.txt ... NOTICE: Processing next batch with 10986 unique variants in 10986 input lines
# Done with 1487 sequences
# WARNING: A total of 111 sequences will be ignored due to lack of correct ORF annotation
# Done with 2271 transcripts (including 70 without coding sequence annotation) for 2268 unique genes
# NOTICE: Processing next batch with 10409 unique variants in 10409 input lines
# NOTICE: Processing next batch with 10218 unique variants in 10218 input lines
# NOTICE: Output files are written to pyseer_dataset/original_dataset/annovar_files/snps.7553_4#9.avinput.variant_function, pyseer_dataset/original_dataset/annovar_files/snps.7553_4#9.avinput.exonic_variant_function
# NOTICE: Reading gene annotation from pyseer_dataset/Spn23F/Spn23F_refGene.txt ... Done with 2271 transcripts (including 70 without coding sequence annotation) for 2268 unique genes
#
# ---------------------------------------------------------------------------------------
# WARNING: 2175 exonic SNPs have WRONG reference alleles specified in your input file!
# WARNING: An example input line is <NC_011900.1	1461333	1461333	A	G	hom	.	.>
# WARNING: ANNOVAR can still annotate exonic_variant_function for the mutation correctly!
# WARNING: you may have used wrong -buildver, or specified incorrect reference allele, or used outdated mRNA FASTA file!
# ---------------------------------------------------------------------------------------
#
# 2025-04-23 21:49:15,936 - INFO - Successfully annotated pyseer_dataset/original_dataset/annovar_files/snps.7622_2#19.avinput
# NOTICE: Processing next batch with 7673 unique variants in 7673 input lines
# NOTICE: Output files are written to pyseer_dataset/original_dataset/annovar_files/snps.6999_5#5.avinput.variant_function, pyseer_dataset/original_dataset/annovar_files/snps.6999_5#5.avinput.exonic_variant_function
# NOTICE: Reading gene annotation from pyseer_dataset/Spn23F/Spn23F_refGene.txt ... Done with 2271 transcripts (including 70 without coding sequence annotation) for 2268 unique genes
# NOTICE: Processing next batch with 11165 unique variants in 11165 input lines
# NOTICE: Reading FASTA sequences from pyseer_dataset/Spn23F/Spn23F_refGeneMrna.fa ... Done with 1498 sequences
# WARNING: A total of 111 sequences will be ignored due to lack of correct ORF annotation
#
# ---------------------------------------------------------------------------------------
# WARNING: 2024 exonic SNPs have WRONG reference alleles specified in your input file!
# WARNING: An example input line is <NC_011900.1	1316404	1316404	G	A	hom	.	.>
# WARNING: ANNOVAR can still annotate exonic_variant_function for the mutation correctly!
# WARNING: you may have used wrong -buildver, or specified incorrect reference allele, or used outdated mRNA FASTA file!
# ---------------------------------------------------------------------------------------
#
# 2025-04-23 21:49:17,363 - INFO - Successfully annotated pyseer_dataset/original_dataset/annovar_files/snps.7622_3#89.avinput
# NOTICE: Reading FASTA sequences from pyseer_dataset/Spn23F/Spn23F_refGeneMrna.fa ... Done with 1358 sequences
# WARNING: A total of 111 sequences will be ignored due to lack of correct ORF annotation
# NOTICE: Output files are written to pyseer_dataset/original_dataset/annovar_files/snps.6999_2#16.avinput.variant_function, pyseer_dataset/original_dataset/annovar_files/snps.6999_2#16.avinput.exonic_variant_function
# NOTICE: Reading gene annotation from pyseer_dataset/Spn23F/Spn23F_refGene.txt ...
# ---------------------------------------------------------------------------------------
# WARNING: 2907 exonic SNPs have WRONG reference alleles specified in your input file!
# WARNING: An example input line is <NC_011900.1	1038349	1038349	G	A	hom	.	.>
# WARNING: ANNOVAR can still annotate exonic_variant_function for the mutation correctly!
# WARNING: you may have used wrong -buildver, or specified incorrect reference allele, or used outdated mRNA FASTA file!
# ---------------------------------------------------------------------------------------
#
# 2025-04-23 21:49:17,494 - INFO - Successfully annotated pyseer_dataset/original_dataset/annovar_files/snps.7553_4#9.avinput
# Done with 2271 transcripts (including 70 without coding sequence annotation) for 2268 unique genes
# NOTICE: Processing next batch with 10175 unique variants in 10175 input lines
# NOTICE: Output files are written to pyseer_dataset/original_dataset/annovar_files/snps.7622_4#14.avinput.variant_function, pyseer_dataset/original_dataset/annovar_files/snps.7622_4#14.avinput.exonic_variant_function
# NOTICE: Reading gene annotation from pyseer_dataset/Spn23F/Spn23F_refGene.txt ... Done with 2271 transcripts (including 70 without coding sequence annotation) for 2268 unique genes
# NOTICE: Reading FASTA sequences from pyseer_dataset/Spn23F/Spn23F_refGeneMrna.fa ... Done with 1465 sequences
# WARNING: A total of 111 sequences will be ignored due to lack of correct ORF annotation
# NOTICE: Processing next batch with 13054 unique variants in 13054 input lines
# NOTICE: Reading FASTA sequences from pyseer_dataset/Spn23F/Spn23F_refGeneMrna.fa ... Done with 1500 sequences
# WARNING: A total of 111 sequences will be ignored due to lack of correct ORF annotation
#
# ---------------------------------------------------------------------------------------
# WARNING: 1898 exonic SNPs have WRONG reference alleles specified in your input file!
# WARNING: An example input line is <NC_011900.1	2003139	2003139	A	G	hom	.	.>
# WARNING: ANNOVAR can still annotate exonic_variant_function for the mutation correctly!
# WARNING: you may have used wrong -buildver, or specified incorrect reference allele, or used outdated mRNA FASTA file!
# ---------------------------------------------------------------------------------------
#
# NOTICE: Reading FASTA sequences from pyseer_dataset/Spn23F/Spn23F_refGeneMrna.fa ... Done with 1459 sequences
# WARNING: A total of 111 sequences will be ignored due to lack of correct ORF annotation
# 2025-04-23 21:49:17,892 - INFO - Successfully annotated pyseer_dataset/original_dataset/annovar_files/snps.7622_5#94.avinput
# NOTICE: Reading FASTA sequences from pyseer_dataset/Spn23F/Spn23F_refGeneMrna.fa ... Done with 1520 sequences
# WARNING: A total of 111 sequences will be ignored due to lack of correct ORF annotation
# NOTICE: Reading FASTA sequences from pyseer_dataset/Spn23F/Spn23F_refGeneMrna.fa ... Done with 1485 sequences
# WARNING: A total of 111 sequences will be ignored due to lack of correct ORF annotation
#
# ---------------------------------------------------------------------------------------
# WARNING: 2448 exonic SNPs have WRONG reference alleles specified in your input file!
# WARNING: An example input line is <NC_011900.1	1453103	1453103	G	A	hom	.	.>
# WARNING: ANNOVAR can still annotate exonic_variant_function for the mutation correctly!
# WARNING: you may have used wrong -buildver, or specified incorrect reference allele, or used outdated mRNA FASTA file!
# ---------------------------------------------------------------------------------------
#
# NOTICE: Output files are written to pyseer_dataset/original_dataset/annovar_files/snps.7622_3#52.avinput.variant_function, pyseer_dataset/original_dataset/annovar_files/snps.7622_3#52.avinput.exonic_variant_function
# 2025-04-23 21:49:18,017 - INFO - Successfully annotated pyseer_dataset/original_dataset/annovar_files/snps.7553_4#38.avinput
# NOTICE: Reading gene annotation from pyseer_dataset/Spn23F/Spn23F_refGene.txt ...
# ---------------------------------------------------------------------------------------
# WARNING: 1826 exonic SNPs have WRONG reference alleles specified in your input file!
# WARNING: An example input line is <NC_011900.1	2016840	2016840	T	G	hom	.	.>
# WARNING: ANNOVAR can still annotate exonic_variant_function for the mutation correctly!
# WARNING: you may have used wrong -buildver, or specified incorrect reference allele, or used outdated mRNA FASTA file!
# ---------------------------------------------------------------------------------------
#
# 2025-04-23 21:49:18,047 - INFO - Successfully annotated pyseer_dataset/original_dataset/annovar_files/snps.7622_5#84.avinput
# Done with 2271 transcripts (including 70 without coding sequence annotation) for 2268 unique genes
#
# ---------------------------------------------------------------------------------------
# WARNING: 2332 exonic SNPs have WRONG reference alleles specified in your input file!
# WARNING: An example input line is <NC_011900.1	98814	98814	C	T	hom	.	.>
# WARNING: ANNOVAR can still annotate exonic_variant_function for the mutation correctly!
# WARNING: you may have used wrong -buildver, or specified incorrect reference allele, or used outdated mRNA FASTA file!
# ---------------------------------------------------------------------------------------
#
# NOTICE: Reading FASTA sequences from pyseer_dataset/Spn23F/Spn23F_refGeneMrna.fa ...
# ---------------------------------------------------------------------------------------
# WARNING: 2372 exonic SNPs have WRONG reference alleles specified in your input file!
# WARNING: An example input line is <NC_011900.1	1623888	1623888	C	T	hom	.	.>
# WARNING: ANNOVAR can still annotate exonic_variant_function for the mutation correctly!
# WARNING: you may have used wrong -buildver, or specified incorrect reference allele, or used outdated mRNA FASTA file!
# ---------------------------------------------------------------------------------------
#
# Done with 1491 sequences
# WARNING: A total of 111 sequences will be ignored due to lack of correct ORF annotation
# 2025-04-23 21:49:18,122 - INFO - Successfully annotated pyseer_dataset/original_dataset/annovar_files/snps.7553_6#7.avinput
# NOTICE: Processing next batch with 10475 unique variants in 10475 input lines
# NOTICE: Output files are written to pyseer_dataset/original_dataset/annovar_files/snps.7622_4#7.avinput.variant_function, pyseer_dataset/original_dataset/annovar_files/snps.7622_4#7.avinput.exonic_variant_function
# NOTICE: Reading gene annotation from pyseer_dataset/Spn23F/Spn23F_refGene.txt ... 2025-04-23 21:49:18,148 - INFO - Successfully annotated pyseer_dataset/original_dataset/annovar_files/snps.7553_4#28.avinput
# Done with 2271 transcripts (including 70 without coding sequence annotation) for 2268 unique genes
# NOTICE: Output files are written to pyseer_dataset/original_dataset/annovar_files/snps.6925_1#53.avinput.variant_function, pyseer_dataset/original_dataset/annovar_files/snps.6925_1#53.avinput.exonic_variant_function
# NOTICE: Reading gene annotation from pyseer_dataset/Spn23F/Spn23F_refGene.txt ... Done with 2271 transcripts (including 70 without coding sequence annotation) for 2268 unique genes
# NOTICE: Processing next batch with 10122 unique variants in 10122 input lines
# NOTICE: Output files are written to pyseer_dataset/original_dataset/annovar_files/snps.6952_7#5.avinput.variant_function, pyseer_dataset/original_dataset/annovar_files/snps.6952_7#5.avinput.exonic_variant_function
# NOTICE: Reading gene annotation from pyseer_dataset/Spn23F/Spn23F_refGene.txt ... Done with 2271 transcripts (including 70 without coding sequence annotation) for 2268 unique genes
# NOTICE: Processing next batch with 7694 unique variants in 7694 input lines
#
# ---------------------------------------------------------------------------------------
# WARNING: 1978 exonic SNPs have WRONG reference alleles specified in your input file!
# WARNING: An example input line is <NC_011900.1	1070512	1070512	A	T	hom	.	.>
# WARNING: ANNOVAR can still annotate exonic_variant_function for the mutation correctly!
# WARNING: you may have used wrong -buildver, or specified incorrect reference allele, or used outdated mRNA FASTA file!
# ---------------------------------------------------------------------------------------
#
# NOTICE: Output files are written to pyseer_dataset/original_dataset/annovar_files/snps.7001_2#18.avinput.variant_function, pyseer_dataset/original_dataset/annovar_files/snps.7001_2#18.avinput.exonic_variant_function
# NOTICE: Reading gene annotation from pyseer_dataset/Spn23F/Spn23F_refGene.txt ... 2025-04-23 21:49:18,292 - INFO - Successfully annotated pyseer_dataset/original_dataset/annovar_files/snps.6999_5#5.avinput
# Done with 2271 transcripts (including 70 without coding sequence annotation) for 2268 unique genes
# NOTICE: Processing next batch with 10122 unique variants in 10122 input lines
# NOTICE: Processing next batch with 10632 unique variants in 10632 input lines
# NOTICE: Output files are written to pyseer_dataset/original_dataset/annovar_files/snps.7622_5#70.avinput.variant_function, pyseer_dataset/original_dataset/annovar_files/snps.7622_5#70.avinput.exonic_variant_function
# NOTICE: Reading gene annotation from pyseer_dataset/Spn23F/Spn23F_refGene.txt ... Done with 2271 transcripts (including 70 without coding sequence annotation) for 2268 unique genes
# NOTICE: Processing next batch with 7587 unique variants in 7587 input lines
# NOTICE: Reading FASTA sequences from pyseer_dataset/Spn23F/Spn23F_refGeneMrna.fa ... Done with 1469 sequences
# WARNING: A total of 111 sequences will be ignored due to lack of correct ORF annotation
#
# ---------------------------------------------------------------------------------------
# WARNING: 2197 exonic SNPs have WRONG reference alleles specified in your input file!
# WARNING: An example input line is <NC_011900.1	2048161	2048161	C	T	hom	.	.>
# WARNING: ANNOVAR can still annotate exonic_variant_function for the mutation correctly!
# WARNING: you may have used wrong -buildver, or specified incorrect reference allele, or used outdated mRNA FASTA file!
# ---------------------------------------------------------------------------------------
#
# 2025-04-23 21:49:19,609 - INFO - Successfully annotated pyseer_dataset/original_dataset/annovar_files/snps.6999_2#16.avinput
# NOTICE: Reading FASTA sequences from pyseer_dataset/Spn23F/Spn23F_refGeneMrna.fa ... Done with 1352 sequences
# WARNING: A total of 111 sequences will be ignored due to lack of correct ORF annotation
# NOTICE: Output files are written to pyseer_dataset/original_dataset/annovar_files/snps.7622_2#36.avinput.variant_function, pyseer_dataset/original_dataset/annovar_files/snps.7622_2#36.avinput.exonic_variant_function
# NOTICE: Reading gene annotation from pyseer_dataset/Spn23F/Spn23F_refGene.txt ... Done with 2271 transcripts (including 70 without coding sequence annotation) for 2268 unique genes
#
# ---------------------------------------------------------------------------------------
# WARNING: 2905 exonic SNPs have WRONG reference alleles specified in your input file!
# WARNING: An example input line is <NC_011900.1	381850	381850	A	G	hom	.	.>
# WARNING: ANNOVAR can still annotate exonic_variant_function for the mutation correctly!
# WARNING: you may have used wrong -buildver, or specified incorrect reference allele, or used outdated mRNA FASTA file!
# ---------------------------------------------------------------------------------------
#
# 2025-04-23 21:49:19,821 - INFO - Successfully annotated pyseer_dataset/original_dataset/annovar_files/snps.6925_1#53.avinput
# NOTICE: Processing next batch with 11391 unique variants in 11391 input lines
# NOTICE: Reading FASTA sequences from pyseer_dataset/Spn23F/Spn23F_refGeneMrna.fa ... Done with 1354 sequences
# WARNING: A total of 111 sequences will be ignored due to lack of correct ORF annotation
#
# ---------------------------------------------------------------------------------------
# WARNING: 2707 exonic SNPs have WRONG reference alleles specified in your input file!
# WARNING: An example input line is <NC_011900.1	831321	831321	C	T	hom	.	.>
# WARNING: ANNOVAR can still annotate exonic_variant_function for the mutation correctly!
# WARNING: you may have used wrong -buildver, or specified incorrect reference allele, or used outdated mRNA FASTA file!
# ---------------------------------------------------------------------------------------
#
# NOTICE: Output files are written to pyseer_dataset/original_dataset/annovar_files/snps.7622_2#26.avinput.variant_function, pyseer_dataset/original_dataset/annovar_files/snps.7622_2#26.avinput.exonic_variant_function
# NOTICE: Reading gene annotation from pyseer_dataset/Spn23F/Spn23F_refGene.txt ... 2025-04-23 21:49:19,980 - INFO - Successfully annotated pyseer_dataset/original_dataset/annovar_files/snps.7622_5#70.avinput
# Done with 2271 transcripts (including 70 without coding sequence annotation) for 2268 unique genes
# NOTICE: Reading FASTA sequences from pyseer_dataset/Spn23F/Spn23F_refGeneMrna.fa ... Done with 1452 sequences
# WARNING: A total of 111 sequences will be ignored due to lack of correct ORF annotation
# NOTICE: Reading FASTA sequences from pyseer_dataset/Spn23F/Spn23F_refGeneMrna.fa ... Done with 1434 sequences
# WARNING: A total of 111 sequences will be ignored due to lack of correct ORF annotation
# NOTICE: Processing next batch with 11093 unique variants in 11093 input lines
# NOTICE: Reading FASTA sequences from pyseer_dataset/Spn23F/Spn23F_refGeneMrna.fa ... Done with 1439 sequences
# WARNING: A total of 111 sequences will be ignored due to lack of correct ORF annotation
# NOTICE: Reading FASTA sequences from pyseer_dataset/Spn23F/Spn23F_refGeneMrna.fa ... NOTICE: Output files are written to pyseer_dataset/original_dataset/annovar_files/snps.7622_5#60.avinput.variant_function, pyseer_dataset/original_dataset/annovar_files/snps.7622_5#60.avinput.exonic_variant_function
# NOTICE: Reading gene annotation from pyseer_dataset/Spn23F/Spn23F_refGene.txt ... Done with 1468 sequences
# WARNING: A total of 111 sequences will be ignored due to lack of correct ORF annotation
# Done with 2271 transcripts (including 70 without coding sequence annotation) for 2268 unique genes
#
# ---------------------------------------------------------------------------------------
# WARNING: 1948 exonic SNPs have WRONG reference alleles specified in your input file!
# WARNING: An example input line is <NC_011900.1	867207	867207	T	C	hom	.	.>
# WARNING: ANNOVAR can still annotate exonic_variant_function for the mutation correctly!
# WARNING: you may have used wrong -buildver, or specified incorrect reference allele, or used outdated mRNA FASTA file!
# ---------------------------------------------------------------------------------------
#
# 2025-04-23 21:49:20,214 - INFO - Successfully annotated pyseer_dataset/original_dataset/annovar_files/snps.7622_4#7.avinput
# NOTICE: Processing next batch with 11108 unique variants in 11108 input lines
#
# ---------------------------------------------------------------------------------------
# WARNING: 2228 exonic SNPs have WRONG reference alleles specified in your input file!
# WARNING: An example input line is <NC_011900.1	463155	463155	C	T	hom	.	.>
# WARNING: ANNOVAR can still annotate exonic_variant_function for the mutation correctly!
# WARNING: you may have used wrong -buildver, or specified incorrect reference allele, or used outdated mRNA FASTA file!
# ---------------------------------------------------------------------------------------
#
# 2025-04-23 21:49:20,254 - INFO - Successfully annotated pyseer_dataset/original_dataset/annovar_files/snps.7622_3#52.avinput
# NOTICE: Reading FASTA sequences from pyseer_dataset/Spn23F/Spn23F_refGeneMrna.fa ... Done with 1479 sequences
# WARNING: A total of 111 sequences will be ignored due to lack of correct ORF annotation
#
# ---------------------------------------------------------------------------------------
# WARNING: 2187 exonic SNPs have WRONG reference alleles specified in your input file!
# WARNING: An example input line is <NC_011900.1	2173210	2173210	A	C	hom	.	.>
# WARNING: ANNOVAR can still annotate exonic_variant_function for the mutation correctly!
# WARNING: you may have used wrong -buildver, or specified incorrect reference allele, or used outdated mRNA FASTA file!
# ---------------------------------------------------------------------------------------
#
# NOTICE: Output files are written to pyseer_dataset/original_dataset/annovar_files/snps.7001_3#21.avinput.variant_function, pyseer_dataset/original_dataset/annovar_files/snps.7001_3#21.avinput.exonic_variant_function
# NOTICE: Reading gene annotation from pyseer_dataset/Spn23F/Spn23F_refGene.txt ... 2025-04-23 21:49:20,321 - INFO - Successfully annotated pyseer_dataset/original_dataset/annovar_files/snps.6952_7#5.avinput
#
# ---------------------------------------------------------------------------------------
# WARNING: 2034 exonic SNPs have WRONG reference alleles specified in your input file!
# WARNING: An example input line is <NC_011900.1	2171821	2171821	G	A	hom	.	.>
# WARNING: ANNOVAR can still annotate exonic_variant_function for the mutation correctly!
# WARNING: you may have used wrong -buildver, or specified incorrect reference allele, or used outdated mRNA FASTA file!
# ---------------------------------------------------------------------------------------
#
# Done with 2271 transcripts (including 70 without coding sequence annotation) for 2268 unique genes
# 2025-04-23 21:49:20,377 - INFO - Successfully annotated pyseer_dataset/original_dataset/annovar_files/snps.7622_4#14.avinput
# NOTICE: Output files are written to pyseer_dataset/original_dataset/annovar_files/snps.6999_6#11.avinput.variant_function, pyseer_dataset/original_dataset/annovar_files/snps.6999_6#11.avinput.exonic_variant_function
# NOTICE: Reading gene annotation from pyseer_dataset/Spn23F/Spn23F_refGene.txt ...
# ---------------------------------------------------------------------------------------
# WARNING: 2127 exonic SNPs have WRONG reference alleles specified in your input file!
# WARNING: An example input line is <NC_011900.1	340523	340523	A	T	hom	.	.>
# WARNING: ANNOVAR can still annotate exonic_variant_function for the mutation correctly!
# WARNING: you may have used wrong -buildver, or specified incorrect reference allele, or used outdated mRNA FASTA file!
# ---------------------------------------------------------------------------------------
#
# Done with 2271 transcripts (including 70 without coding sequence annotation) for 2268 unique genes
# NOTICE: Processing next batch with 10917 unique variants in 10917 input lines
# 2025-04-23 21:49:20,432 - INFO - Successfully annotated pyseer_dataset/original_dataset/annovar_files/snps.7001_2#18.avinput
# NOTICE: Output files are written to pyseer_dataset/original_dataset/annovar_files/snps.6999_1#3.avinput.variant_function, pyseer_dataset/original_dataset/annovar_files/snps.6999_1#3.avinput.exonic_variant_function
# NOTICE: Reading gene annotation from pyseer_dataset/Spn23F/Spn23F_refGene.txt ... Done with 2271 transcripts (including 70 without coding sequence annotation) for 2268 unique genes
# NOTICE: Processing next batch with 12858 unique variants in 12858 input lines
# NOTICE: Output files are written to pyseer_dataset/original_dataset/annovar_files/snps.7001_1#14.avinput.variant_function, pyseer_dataset/original_dataset/annovar_files/snps.7001_1#14.avinput.exonic_variant_function
# NOTICE: Reading gene annotation from pyseer_dataset/Spn23F/Spn23F_refGene.txt ... Done with 2271 transcripts (including 70 without coding sequence annotation) for 2268 unique genes
# NOTICE: Output files are written to pyseer_dataset/original_dataset/annovar_files/snps.6999_3#10.avinput.variant_function, pyseer_dataset/original_dataset/annovar_files/snps.6999_3#10.avinput.exonic_variant_function
# NOTICE: Reading gene annotation from pyseer_dataset/Spn23F/Spn23F_refGene.txt ... NOTICE: Processing next batch with 11048 unique variants in 11048 input lines
# Done with 2271 transcripts (including 70 without coding sequence annotation) for 2268 unique genes
# NOTICE: Processing next batch with 10060 unique variants in 10060 input lines
# NOTICE: Processing next batch with 10035 unique variants in 10035 input lines
# NOTICE: Reading FASTA sequences from pyseer_dataset/Spn23F/Spn23F_refGeneMrna.fa ... Done with 1480 sequences
# WARNING: A total of 111 sequences will be ignored due to lack of correct ORF annotation
# NOTICE: Reading FASTA sequences from pyseer_dataset/Spn23F/Spn23F_refGeneMrna.fa ... Done with 1497 sequences
# WARNING: A total of 111 sequences will be ignored due to lack of correct ORF annotation
#
# ---------------------------------------------------------------------------------------
# WARNING: 2137 exonic SNPs have WRONG reference alleles specified in your input file!
# WARNING: An example input line is <NC_011900.1	2207706	2207706	A	G	hom	.	.>
# WARNING: ANNOVAR can still annotate exonic_variant_function for the mutation correctly!
# WARNING: you may have used wrong -buildver, or specified incorrect reference allele, or used outdated mRNA FASTA file!
# ---------------------------------------------------------------------------------------
#
# 2025-04-23 21:49:22,129 - INFO - Successfully annotated pyseer_dataset/original_dataset/annovar_files/snps.7622_2#36.avinput
# NOTICE: Reading FASTA sequences from pyseer_dataset/Spn23F/Spn23F_refGeneMrna.fa ... Done with 1546 sequences
# WARNING: A total of 111 sequences will be ignored due to lack of correct ORF annotation
#
# ---------------------------------------------------------------------------------------
# WARNING: 2082 exonic SNPs have WRONG reference alleles specified in your input file!
# WARNING: An example input line is <NC_011900.1	917635	917635	G	A	hom	.	.>
# WARNING: ANNOVAR can still annotate exonic_variant_function for the mutation correctly!
# WARNING: you may have used wrong -buildver, or specified incorrect reference allele, or used outdated mRNA FASTA file!
# ---------------------------------------------------------------------------------------
#
# 2025-04-23 21:49:22,239 - INFO - Successfully annotated pyseer_dataset/original_dataset/annovar_files/snps.7622_2#26.avinput
# NOTICE: Output files are written to pyseer_dataset/original_dataset/annovar_files/snps.7622_2#44.avinput.variant_function, pyseer_dataset/original_dataset/annovar_files/snps.7622_2#44.avinput.exonic_variant_function
# NOTICE: Reading gene annotation from pyseer_dataset/Spn23F/Spn23F_refGene.txt ... Done with 2271 transcripts (including 70 without coding sequence annotation) for 2268 unique genes
# NOTICE: Processing next batch with 10152 unique variants in 10152 input lines
#
# ---------------------------------------------------------------------------------------
# WARNING: 1958 exonic SNPs have WRONG reference alleles specified in your input file!
# WARNING: An example input line is <NC_011900.1	791377	791377	C	T	hom	.	.>
# WARNING: ANNOVAR can still annotate exonic_variant_function for the mutation correctly!
# WARNING: you may have used wrong -buildver, or specified incorrect reference allele, or used outdated mRNA FASTA file!
# ---------------------------------------------------------------------------------------
#
# NOTICE: Output files are written to pyseer_dataset/original_dataset/annovar_files/snps.6999_2#7.avinput.variant_function, pyseer_dataset/original_dataset/annovar_files/snps.6999_2#7.avinput.exonic_variant_function
# NOTICE: Reading gene annotation from pyseer_dataset/Spn23F/Spn23F_refGene.txt ... NOTICE: Reading FASTA sequences from pyseer_dataset/Spn23F/Spn23F_refGeneMrna.fa ... 2025-04-23 21:49:22,390 - INFO - Successfully annotated pyseer_dataset/original_dataset/annovar_files/snps.7622_5#60.avinput
# NOTICE: Reading FASTA sequences from pyseer_dataset/Spn23F/Spn23F_refGeneMrna.fa ... Done with 1442 sequences
# WARNING: A total of 111 sequences will be ignored due to lack of correct ORF annotation
# Done with 1457 sequences
# WARNING: A total of 111 sequences will be ignored due to lack of correct ORF annotation
# Done with 2271 transcripts (including 70 without coding sequence annotation) for 2268 unique genes
# NOTICE: Reading FASTA sequences from pyseer_dataset/Spn23F/Spn23F_refGeneMrna.fa ... Done with 1471 sequences
# WARNING: A total of 111 sequences will be ignored due to lack of correct ORF annotation
# NOTICE: Reading FASTA sequences from pyseer_dataset/Spn23F/Spn23F_refGeneMrna.fa ... NOTICE: Processing next batch with 10280 unique variants in 10280 input lines
# Done with 1497 sequences
# WARNING: A total of 111 sequences will be ignored due to lack of correct ORF annotation
#
# ---------------------------------------------------------------------------------------
# WARNING: 1770 exonic SNPs have WRONG reference alleles specified in your input file!
# WARNING: An example input line is <NC_011900.1	308205	308205	C	T	hom	.	.>
# WARNING: ANNOVAR can still annotate exonic_variant_function for the mutation correctly!
# WARNING: you may have used wrong -buildver, or specified incorrect reference allele, or used outdated mRNA FASTA file!
# ---------------------------------------------------------------------------------------
#
# NOTICE: Output files are written to pyseer_dataset/original_dataset/annovar_files/snps.7553_5#87.avinput.variant_function, pyseer_dataset/original_dataset/annovar_files/snps.7553_5#87.avinput.exonic_variant_function
# NOTICE: Reading gene annotation from pyseer_dataset/Spn23F/Spn23F_refGene.txt ...
# ---------------------------------------------------------------------------------------
# WARNING: 1859 exonic SNPs have WRONG reference alleles specified in your input file!
# WARNING: An example input line is <NC_011900.1	1964668	1964668	C	T	hom	.	.>
# WARNING: ANNOVAR can still annotate exonic_variant_function for the mutation correctly!
# WARNING: you may have used wrong -buildver, or specified incorrect reference allele, or used outdated mRNA FASTA file!
# ---------------------------------------------------------------------------------------
#
# 2025-04-23 21:49:22,549 - INFO - Successfully annotated pyseer_dataset/original_dataset/annovar_files/snps.6999_3#10.avinput
# 2025-04-23 21:49:22,549 - INFO - Successfully annotated pyseer_dataset/original_dataset/annovar_files/snps.7001_1#14.avinput
# Done with 2271 transcripts (including 70 without coding sequence annotation) for 2268 unique genes
#
# ---------------------------------------------------------------------------------------
# WARNING: 2132 exonic SNPs have WRONG reference alleles specified in your input file!
# WARNING: An example input line is <NC_011900.1	2169458	2169458	A	G	hom	.	.>
# WARNING: ANNOVAR can still annotate exonic_variant_function for the mutation correctly!
# WARNING: you may have used wrong -buildver, or specified incorrect reference allele, or used outdated mRNA FASTA file!
# ---------------------------------------------------------------------------------------
#
# 2025-04-23 21:49:22,605 - INFO - Successfully annotated pyseer_dataset/original_dataset/annovar_files/snps.7001_3#21.avinput
#
# ---------------------------------------------------------------------------------------
# WARNING: 1949 exonic SNPs have WRONG reference alleles specified in your input file!
# WARNING: An example input line is <NC_011900.1	1318089	1318089	G	A	hom	.	.>
# WARNING: ANNOVAR can still annotate exonic_variant_function for the mutation correctly!
# WARNING: you may have used wrong -buildver, or specified incorrect reference allele, or used outdated mRNA FASTA file!
# ---------------------------------------------------------------------------------------
#
# 2025-04-23 21:49:22,660 - INFO - Successfully annotated pyseer_dataset/original_dataset/annovar_files/snps.6999_1#3.avinput
# NOTICE: Output files are written to pyseer_dataset/original_dataset/annovar_files/snps.6952_4#1.avinput.variant_function, pyseer_dataset/original_dataset/annovar_files/snps.6952_4#1.avinput.exonic_variant_function
# NOTICE: Reading gene annotation from pyseer_dataset/Spn23F/Spn23F_refGene.txt ... NOTICE: Output files are written to pyseer_dataset/original_dataset/annovar_files/snps.6930_8#10.avinput.variant_function, pyseer_dataset/original_dataset/annovar_files/snps.6930_8#10.avinput.exonic_variant_function
# NOTICE: Reading gene annotation from pyseer_dataset/Spn23F/Spn23F_refGene.txt ... NOTICE: Processing next batch with 13394 unique variants in 13394 input lines
# Done with 2271 transcripts (including 70 without coding sequence annotation) for 2268 unique genes
# Done with 2271 transcripts (including 70 without coding sequence annotation) for 2268 unique genes
# NOTICE: Output files are written to pyseer_dataset/original_dataset/annovar_files/snps.7553_4#17.avinput.variant_function, pyseer_dataset/original_dataset/annovar_files/snps.7553_4#17.avinput.exonic_variant_function
# NOTICE: Reading gene annotation from pyseer_dataset/Spn23F/Spn23F_refGene.txt ... NOTICE: Reading FASTA sequences from pyseer_dataset/Spn23F/Spn23F_refGeneMrna.fa ... Done with 1520 sequences
# WARNING: A total of 111 sequences will be ignored due to lack of correct ORF annotation
# Done with 2271 transcripts (including 70 without coding sequence annotation) for 2268 unique genes
# NOTICE: Processing next batch with 11798 unique variants in 11798 input lines
# NOTICE: Output files are written to pyseer_dataset/original_dataset/annovar_files/snps.6952_4#21.avinput.variant_function, pyseer_dataset/original_dataset/annovar_files/snps.6952_4#21.avinput.exonic_variant_function
# NOTICE: Reading gene annotation from pyseer_dataset/Spn23F/Spn23F_refGene.txt ... NOTICE: Processing next batch with 12296 unique variants in 12296 input lines
# Done with 2271 transcripts (including 70 without coding sequence annotation) for 2268 unique genes
# NOTICE: Processing next batch with 12475 unique variants in 12475 input lines
# NOTICE: Processing next batch with 12242 unique variants in 12242 input lines
#
# ---------------------------------------------------------------------------------------
# WARNING: 2531 exonic SNPs have WRONG reference alleles specified in your input file!
# WARNING: An example input line is <NC_011900.1	518420	518420	G	C	hom	.	.>
# WARNING: ANNOVAR can still annotate exonic_variant_function for the mutation correctly!
# WARNING: you may have used wrong -buildver, or specified incorrect reference allele, or used outdated mRNA FASTA file!
# ---------------------------------------------------------------------------------------
#
# 2025-04-23 21:49:22,924 - INFO - Successfully annotated pyseer_dataset/original_dataset/annovar_files/snps.6999_6#11.avinput
# ...
# NOTICE: Output files are written to pyseer_dataset/original_dataset/annovar_files/snps.7622_5#91.avinput.variant_function, pyseer_dataset/original_dataset/annovar_files/snps.7622_5#91.avinput.exonic_variant_function
# NOTICE: Reading gene annotation from pyseer_dataset/Spn23F/Spn23F_refGene.txt ... NOTICE: Output files are written to pyseer_dataset/original_dataset/annovar_files/snps.6952_7#17.avinput.variant_function, pyseer_dataset/original_dataset/annovar_files/snps.6952_7#17.avinput.exonic_variant_function
# NOTICE: Reading gene annotation from pyseer_dataset/Spn23F/Spn23F_refGene.txt ...
# ---------------------------------------------------------------------------------------
# WARNING: 2022 exonic SNPs have WRONG reference alleles specified in your input file!
# WARNING: An example input line is <NC_011900.1	254544	254544	A	G	hom	.	.>
# WARNING: ANNOVAR can still annotate exonic_variant_function for the mutation correctly!
# WARNING: you may have used wrong -buildver, or specified incorrect reference allele, or used outdated mRNA FASTA file!
# ---------------------------------------------------------------------------------------
#
# Done with 2271 transcripts (including 70 without coding sequence annotation) for 2268 unique genes
# Done with 2271 transcripts (including 70 without coding sequence annotation) for 2268 unique genes
# 2025-04-23 21:52:12,365 - INFO - Successfully annotated pyseer_dataset/original_dataset/annovar_files/snps.7553_5#66.avinput
# NOTICE: Reading FASTA sequences from pyseer_dataset/Spn23F/Spn23F_refGeneMrna.fa ... Done with 1346 sequences
# WARNING: A total of 111 sequences will be ignored due to lack of correct ORF annotation
# NOTICE: Reading FASTA sequences from pyseer_dataset/Spn23F/Spn23F_refGeneMrna.fa ... Done with 1462 sequences
# WARNING: A total of 111 sequences will be ignored due to lack of correct ORF annotation
# NOTICE: Processing next batch with 10163 unique variants in 10163 input lines
# NOTICE: Processing next batch with 10378 unique variants in 10378 input lines
#
# ---------------------------------------------------------------------------------------
# WARNING: 3062 exonic SNPs have WRONG reference alleles specified in your input file!
# WARNING: An example input line is <NC_011900.1	2218710	2218710	G	A	hom	.	.>
# WARNING: ANNOVAR can still annotate exonic_variant_function for the mutation correctly!
# WARNING: you may have used wrong -buildver, or specified incorrect reference allele, or used outdated mRNA FASTA file!
# ---------------------------------------------------------------------------------------
#
# NOTICE: Output files are written to pyseer_dataset/original_dataset/annovar_files/snps.7553_6#2.avinput.variant_function, pyseer_dataset/original_dataset/annovar_files/snps.7553_6#2.avinput.exonic_variant_function
# NOTICE: Reading gene annotation from pyseer_dataset/Spn23F/Spn23F_refGene.txt ... 2025-04-23 21:52:12,499 - INFO - Successfully annotated pyseer_dataset/original_dataset/annovar_files/snps.6925_2#91.avinput
# Done with 2271 transcripts (including 70 without coding sequence annotation) for 2268 unique genes
#
# ---------------------------------------------------------------------------------------
# WARNING: 1912 exonic SNPs have WRONG reference alleles specified in your input file!
# WARNING: An example input line is <NC_011900.1	1444964	1444964	G	A	hom	.	.>
# WARNING: ANNOVAR can still annotate exonic_variant_function for the mutation correctly!
# WARNING: you may have used wrong -buildver, or specified incorrect reference allele, or used outdated mRNA FASTA file!
# ---------------------------------------------------------------------------------------
#
# 2025-04-23 21:52:12,569 - INFO - Successfully annotated pyseer_dataset/original_dataset/annovar_files/snps.7001_1#4.avinput
# NOTICE: Processing next batch with 13625 unique variants in 13625 input lines
# NOTICE: Output files are written to pyseer_dataset/original_dataset/annovar_files/snps.7622_4#2.avinput.variant_function, pyseer_dataset/original_dataset/annovar_files/snps.7622_4#2.avinput.exonic_variant_function
# NOTICE: Reading gene annotation from pyseer_dataset/Spn23F/Spn23F_refGene.txt ... Done with 2271 transcripts (including 70 without coding sequence annotation) for 2268 unique genes
# NOTICE: Output files are written to pyseer_dataset/original_dataset/annovar_files/snps.7622_3#57.avinput.variant_function, pyseer_dataset/original_dataset/annovar_files/snps.7622_3#57.avinput.exonic_variant_function
# NOTICE: Reading gene annotation from pyseer_dataset/Spn23F/Spn23F_refGene.txt ... NOTICE: Processing next batch with 10026 unique variants in 10026 input lines
# Done with 2271 transcripts (including 70 without coding sequence annotation) for 2268 unique genes
# NOTICE: Reading FASTA sequences from pyseer_dataset/Spn23F/Spn23F_refGeneMrna.fa ... NOTICE: Processing next batch with 7778 unique variants in 7778 input lines
# Done with 1505 sequences
# WARNING: A total of 111 sequences will be ignored due to lack of correct ORF annotation
#
# ---------------------------------------------------------------------------------------
# WARNING: 2169 exonic SNPs have WRONG reference alleles specified in your input file!
# WARNING: An example input line is <NC_011900.1	744176	744176	A	G	hom	.	.>
# WARNING: ANNOVAR can still annotate exonic_variant_function for the mutation correctly!
# WARNING: you may have used wrong -buildver, or specified incorrect reference allele, or used outdated mRNA FASTA file!
# ---------------------------------------------------------------------------------------
#
# 2025-04-23 21:52:12,980 - INFO - Successfully annotated pyseer_dataset/original_dataset/annovar_files/snps.6925_2#81.avinput
# NOTICE: Output files are written to pyseer_dataset/original_dataset/annovar_files/snps.7622_4#11.avinput.variant_function, pyseer_dataset/original_dataset/annovar_files/snps.7622_4#11.avinput.exonic_variant_function
# NOTICE: Reading gene annotation from pyseer_dataset/Spn23F/Spn23F_refGene.txt ... Done with 2271 transcripts (including 70 without coding sequence annotation) for 2268 unique genes
# NOTICE: Reading FASTA sequences from pyseer_dataset/Spn23F/Spn23F_refGeneMrna.fa ... Done with 1534 sequences
# WARNING: A total of 111 sequences will be ignored due to lack of correct ORF annotation
# NOTICE: Processing next batch with 10189 unique variants in 10189 input lines
#
# ---------------------------------------------------------------------------------------
# WARNING: 2047 exonic SNPs have WRONG reference alleles specified in your input file!
# WARNING: An example input line is <NC_011900.1	823106	823106	C	T	hom	.	.>
# WARNING: ANNOVAR can still annotate exonic_variant_function for the mutation correctly!
# WARNING: you may have used wrong -buildver, or specified incorrect reference allele, or used outdated mRNA FASTA file!
# ---------------------------------------------------------------------------------------
#
# 2025-04-23 21:52:13,377 - INFO - Successfully annotated pyseer_dataset/original_dataset/annovar_files/snps.7553_5#76.avinput
# NOTICE: Output files are written to pyseer_dataset/original_dataset/annovar_files/snps.6925_1#56.avinput.variant_function, pyseer_dataset/original_dataset/annovar_files/snps.6925_1#56.avinput.exonic_variant_function
# NOTICE: Reading gene annotation from pyseer_dataset/Spn23F/Spn23F_refGene.txt ... Done with 2271 transcripts (including 70 without coding sequence annotation) for 2268 unique genes
# NOTICE: Processing next batch with 12811 unique variants in 12811 input lines
# NOTICE: Reading FASTA sequences from pyseer_dataset/Spn23F/Spn23F_refGeneMrna.fa ... Done with 1465 sequences
# WARNING: A total of 111 sequences will be ignored due to lack of correct ORF annotation
#
# ---------------------------------------------------------------------------------------
# WARNING: 2359 exonic SNPs have WRONG reference alleles specified in your input file!
# WARNING: An example input line is <NC_011900.1	45417	45417	G	A	hom	.	.>
# WARNING: ANNOVAR can still annotate exonic_variant_function for the mutation correctly!
# WARNING: you may have used wrong -buildver, or specified incorrect reference allele, or used outdated mRNA FASTA file!
# ---------------------------------------------------------------------------------------
#
# 2025-04-23 21:52:13,911 - INFO - Successfully annotated pyseer_dataset/original_dataset/annovar_files/snps.7622_5#81.avinput
# NOTICE: Output files are written to pyseer_dataset/original_dataset/annovar_files/snps.6999_2#13.avinput.variant_function, pyseer_dataset/original_dataset/annovar_files/snps.6999_2#13.avinput.exonic_variant_function
# NOTICE: Reading gene annotation from pyseer_dataset/Spn23F/Spn23F_refGene.txt ... Done with 2271 transcripts (including 70 without coding sequence annotation) for 2268 unique genes
# NOTICE: Reading FASTA sequences from pyseer_dataset/Spn23F/Spn23F_refGeneMrna.fa ... Done with 1363 sequences
# WARNING: A total of 111 sequences will be ignored due to lack of correct ORF annotation
# NOTICE: Processing next batch with 12212 unique variants in 12212 input lines
#
# ---------------------------------------------------------------------------------------
# WARNING: 3026 exonic SNPs have WRONG reference alleles specified in your input file!
# WARNING: An example input line is <NC_011900.1	1888312	1888312	A	G	hom	.	.>
# WARNING: ANNOVAR can still annotate exonic_variant_function for the mutation correctly!
# WARNING: you may have used wrong -buildver, or specified incorrect reference allele, or used outdated mRNA FASTA file!
# ---------------------------------------------------------------------------------------
#
# 2025-04-23 21:52:14,278 - INFO - Successfully annotated pyseer_dataset/original_dataset/annovar_files/snps.7622_3#57.avinput
# NOTICE: Reading FASTA sequences from pyseer_dataset/Spn23F/Spn23F_refGeneMrna.fa ... NOTICE: Reading FASTA sequences from pyseer_dataset/Spn23F/Spn23F_refGeneMrna.fa ... Done with 1436 sequences
# WARNING: A total of 111 sequences will be ignored due to lack of correct ORF annotation
# Done with 1459 sequences
# WARNING: A total of 111 sequences will be ignored due to lack of correct ORF annotation
#
# ---------------------------------------------------------------------------------------
# WARNING: 2206 exonic SNPs have WRONG reference alleles specified in your input file!
# WARNING: An example input line is <NC_011900.1	1735571	1735571	C	T	hom	.	.>
# WARNING: ANNOVAR can still annotate exonic_variant_function for the mutation correctly!
# WARNING: you may have used wrong -buildver, or specified incorrect reference allele, or used outdated mRNA FASTA file!
# ---------------------------------------------------------------------------------------
#
#
# ---------------------------------------------------------------------------------------
# WARNING: 1976 exonic SNPs have WRONG reference alleles specified in your input file!
# WARNING: An example input line is <NC_011900.1	1815339	1815339	G	A	hom	.	.>
# WARNING: ANNOVAR can still annotate exonic_variant_function for the mutation correctly!
# WARNING: you may have used wrong -buildver, or specified incorrect reference allele, or used outdated mRNA FASTA file!
# ---------------------------------------------------------------------------------------
#
# 2025-04-23 21:52:14,511 - INFO - Successfully annotated pyseer_dataset/original_dataset/annovar_files/snps.7622_5#91.avinput
# 2025-04-23 21:52:14,511 - INFO - Successfully annotated pyseer_dataset/original_dataset/annovar_files/snps.6952_7#17.avinput
# NOTICE: Reading FASTA sequences from pyseer_dataset/Spn23F/Spn23F_refGeneMrna.fa ... Done with 1454 sequences
# WARNING: A total of 111 sequences will be ignored due to lack of correct ORF annotation
#
# ---------------------------------------------------------------------------------------
# WARNING: 1972 exonic SNPs have WRONG reference alleles specified in your input file!
# WARNING: An example input line is <NC_011900.1	1104706	1104706	C	T	hom	.	.>
# WARNING: ANNOVAR can still annotate exonic_variant_function for the mutation correctly!
# WARNING: you may have used wrong -buildver, or specified incorrect reference allele, or used outdated mRNA FASTA file!
# ---------------------------------------------------------------------------------------
#
# 2025-04-23 21:52:14,664 - INFO - Successfully annotated pyseer_dataset/original_dataset/annovar_files/snps.7622_4#2.avinput
# NOTICE: Reading FASTA sequences from pyseer_dataset/Spn23F/Spn23F_refGeneMrna.fa ... Done with 1445 sequences
# WARNING: A total of 111 sequences will be ignored due to lack of correct ORF annotation
#
# ---------------------------------------------------------------------------------------
# WARNING: 1947 exonic SNPs have WRONG reference alleles specified in your input file!
# WARNING: An example input line is <NC_011900.1	1387037	1387037	C	A	hom	.	.>
# WARNING: ANNOVAR can still annotate exonic_variant_function for the mutation correctly!
# WARNING: you may have used wrong -buildver, or specified incorrect reference allele, or used outdated mRNA FASTA file!
# ---------------------------------------------------------------------------------------
#
# 2025-04-23 21:52:15,121 - INFO - Successfully annotated pyseer_dataset/original_dataset/annovar_files/snps.7622_4#11.avinput
# NOTICE: Reading FASTA sequences from pyseer_dataset/Spn23F/Spn23F_refGeneMrna.fa ... Done with 1493 sequences
# WARNING: A total of 111 sequences will be ignored due to lack of correct ORF annotation
#
# ---------------------------------------------------------------------------------------
# WARNING: 2629 exonic SNPs have WRONG reference alleles specified in your input file!
# WARNING: An example input line is <NC_011900.1	1156767	1156767	A	G	hom	.	.>
# WARNING: ANNOVAR can still annotate exonic_variant_function for the mutation correctly!
# WARNING: you may have used wrong -buildver, or specified incorrect reference allele, or used outdated mRNA FASTA file!
# ---------------------------------------------------------------------------------------
#
# 2025-04-23 21:52:15,341 - INFO - Successfully annotated pyseer_dataset/original_dataset/annovar_files/snps.7553_6#2.avinput
# NOTICE: Reading FASTA sequences from pyseer_dataset/Spn23F/Spn23F_refGeneMrna.fa ... Done with 1520 sequences
# WARNING: A total of 111 sequences will be ignored due to lack of correct ORF annotation
#
# ---------------------------------------------------------------------------------------
# WARNING: 2814 exonic SNPs have WRONG reference alleles specified in your input file!
# WARNING: An example input line is <NC_011900.1	486190	486190	C	T	hom	.	.>
# WARNING: ANNOVAR can still annotate exonic_variant_function for the mutation correctly!
# WARNING: you may have used wrong -buildver, or specified incorrect reference allele, or used outdated mRNA FASTA file!
# ---------------------------------------------------------------------------------------
#
# 2025-04-23 21:52:15,800 - INFO - Successfully annotated pyseer_dataset/original_dataset/annovar_files/snps.6925_1#56.avinput
# NOTICE: Reading FASTA sequences from pyseer_dataset/Spn23F/Spn23F_refGeneMrna.fa ... Done with 1520 sequences
# WARNING: A total of 111 sequences will be ignored due to lack of correct ORF annotation
#
# ---------------------------------------------------------------------------------------
# WARNING: 2015 exonic SNPs have WRONG reference alleles specified in your input file!
# WARNING: An example input line is <NC_011900.1	1670793	1670793	G	A	hom	.	.>
# WARNING: ANNOVAR can still annotate exonic_variant_function for the mutation correctly!
# WARNING: you may have used wrong -buildver, or specified incorrect reference allele, or used outdated mRNA FASTA file!
# ---------------------------------------------------------------------------------------
#
# 2025-04-23 21:52:16,113 - INFO - Successfully annotated pyseer_dataset/original_dataset/annovar_files/snps.6999_2#13.avinput
# 2025-04-23 21:52:16,231 - INFO - Completed parallel annotation of avinput files.
# Annotated 603 avinput files in 183.78 seconds.
# Annotated avinput files are saved in pyseer_dataset/original_dataset/annovar_files/.

# %% [markdown]
# ### **Step 2: Build Gene Mutation Table:**
#
# For each sample:
# 1. **Build gene maps** from the gff3 file.
# 2. Compile mutation info **gene-by-gene**.
# 3. **Determine mutation types**.
#     - binary: mutation or wildtype
#     - multiple: nonsense, nonstop, missense, silent or wildtype
# 4. **Output mutation types per gene** across all samples:
#
#     |Gene|Sample1|Sample2|Sample3|
#     |:-:|:-:|:-:|:-:|
#     |g1|m|w|w|m|
#     |g2|m|m|m|w|
#     |g3|w|w|w|m|
#     |...|...|...|...|
#
# **Import functions and annotation data**

# %%
from muggwas import compile_gene_mutations, write_gene_mutation_summary, write_gene_annotation_summary

# Directory containing the ANNOVAR output files
annovar_output_dir = 'pyseer_dataset/original_dataset/annovar_files'
# Read gff3 to build gene maps
gff_file = 'pyseer_dataset/Spn23F/Spn23F.gff3'
# Write the mutation types to a tab delimited file
output_mutation_table = 'pyseer_dataset/original_dataset/gene_mutation_summary.txt'
# Write the annotations to a tab delimited file
output_annotation_table = 'pyseer_dataset/original_dataset/gene_annotation_summary.txt'

# %% [markdown]
# **Compile mutation and output gene summary table**

# %%
## Compile the gene mutations for each sample
# if you want to output binary mutation types (mutated or not), set model = 'binary'
gene_mutation_summary = compile_gene_mutations(annovar_output_dir, gff_file, model = 'binary')
## Write the gene mutation summary
write_gene_mutation_summary(gene_mutation_summary, output_mutation_table)
## Write the gene annotations
write_gene_annotation_summary(gff_file, output_annotation_table)
# Out:
# Time elapsed for compiling gene mutations: 37.84 seconds
# Total number of samples processed: 603
# Gene mutation summary has been written to pyseer_dataset/original_dataset/gene_mutation_summary.txt.
#
# Gene annotation summary has been written to pyseer_dataset/original_dataset/gene_annotation_summary.txt.

# %% [markdown]
# #### **Step 3: Estimate Population Structure Effect:**
#
# In gene-trait association analyses, false positives could arise from shared genetic lineage, especially in clonal organisms. There are two methods to estimate the effect of population structure:
# - Phylogenetic-based: Infer population structure based on phylogenetic distances. Since MugGWAS will use a linear mixed model, the distance will be estimated from the shared branch length between the MRCA and the root.
# - Kinship: Variants on core gene sequences represent the result of vertical evolution. To make inferences for identical by descent, the script will calculate the kinship matrix from the genotype matrix of the presence and absence of variants. --> (not supported yet as of 2025.04.15)
#
# Inputs:
# - Phylogeny-based: Output from IQ-tree `core_gene_tree.nwk`. A high-quality phylogeny based on single-copy core genes from a pangenome.
# - Kinship: A VCF file documenting variants on core genes `core_gene_snp.vcf.gz`. --> (not supported yet as of 2025.04.15)
#
# Output:
# - `phylogeny_distances.tsv`: a distance matrix to account for population structure effect in pyseer.
#
#     | |Sample1|Sample2|Sample3|Sample4|
#     |:-:|:-:|:-:|:-:|:-:|
#     |Sample1|0|4|0|0|
#     |Sample2|4|0|0|0|
#     |Sample3|0|0|0|3|
#     |Sample4|0|0|3|0|
#     |...|...|...|...|
#
# **Phylogeny-based method**

# %%
from muggwas import phylogeny2distmatrix

# Read the phylogenetic tree
phylogeny = 'pyseer_dataset/core_genome_aln.tree'
output_file = 'pyseer_dataset/phylogeny_distances.tsv'

# Convert the phylogenetic tree to a distance matrix
phylogeny2distmatrix(phylogeny, output_file)

# %% [markdown]
# ### **Step 4: Run GWAS on pyseer**
#
# This function filter the genes that have no mutations in the population and run the [linear mixed effect model (FaST-LMM)](https://pyseer.readthedocs.io/en/master/usage.html#mixed-model-fast-lmm) from `pyseer` to infer gene-trait association. Read the GWAS [tutorial](https://pyseer.readthedocs.io/en/master/tutorial.html) for more details.
#
#
#
# - Input:
#     1. The **phenotype file**: a tab-delimited file with the first column as sample names and the second column as the phenotypic value (support binary or numeric).
#     2. The **gene mutation summary table**: the output from step 2.
#     3. The **distance matrix**: the output from step 3.
#
# - Output: A summary table of **GWAS result** that looks like this:
#
#     |Genes|Allele Freq.|filter-value|lrt-pvalue|beta|beta-std-err|variant_h2|notes|
#     |:---|:--|:------|:----------|:------|:-----------|:------|:-----------|
#     |g1|3.00E-01|6.96E-02|1.59E-01|2.09E-01|1.35E-01|4.81E-01|
#     |g2|6.00E-01|2.89E-01|2.50E-01|-8.73E-02|7.03E-02|4.02E-01|
#     |g3|6.00E-01|7.02E-01|8.27E-01|-2.92E-02|1.30E-01|7.94E-02|
#     |...|...|...|...|...|...|...|...|

# %%
from muggwas import run_pyseer

phenotype_file = 'pyseer_dataset/resistances.subset.txt'
mutation_file = 'pyseer_dataset/gene_mutation_summary.txt'
similarity_matrix_file = 'pyseer_dataset/phylogeny_distances.tsv'
output_dir = 'pyseer_dataset/'

# Run pyseer
run_pyseer(phenotype_file, similarity_matrix_file, mutation_file, output_dir)
# Out:
# 2025-04-16 11:13:18,980 - INFO - Start running GWAS with pyseer
# 2025-04-16 11:13:18,989 - INFO - Gene gene-SPN23F_RS00005 has a mutation rate of 0.27.
# 2025-04-16 11:13:18,990 - INFO - Gene cds-WP_000660615.1 has no mutations in the population. Skipping this gene.
# 2025-04-16 11:13:18,990 - INFO - Gene gene-SPN23F_RS00010 has a mutation rate of 0.27.
# 2025-04-16 11:13:18,990 - INFO - Gene cds-WP_000581157.1 has no mutations in the population. Skipping this gene.
# 2025-04-16 11:13:18,991 - INFO - Gene gene-SPN23F_RS00015 has a mutation rate of 0.11333333333333333.
# 2025-04-16 11:13:18,991 - INFO - Gene cds-WP_000285194.1 has no mutations in the population. Skipping this gene.
# 2025-04-16 11:13:18,992 - INFO - Gene gene-SPN23F_RS00020 has a mutation rate of 0.2966666666666667.
# 2025-04-16 11:13:18,992 - INFO - Gene cds-WP_001218707.1 has no mutations in the population. Skipping this gene.
# 2025-04-16 11:13:18,992 - INFO - Gene gene-SPN23F_RS00025 has a mutation rate of 0.7133333333333334.
# 2025-04-16 11:13:18,993 - INFO - Gene cds-WP_000163930.1 has no mutations in the population. Skipping this gene.
# 2025-04-16 11:13:18,993 - INFO - Gene gene-SPN23F_RS00030 has a mutation rate of 0.5933333333333334.
# 2025-04-16 11:13:18,994 - INFO - Gene cds-WP_000258117.1 has no mutations in the population. Skipping this gene.
# 2025-04-16 11:13:18,994 - INFO - Gene gene-SPN23F_RS00035 has a mutation rate of 0.02.
# 2025-04-16 11:13:18,994 - INFO - Gene cds-WP_001234978.1 has no mutations in the population. Skipping this gene.
# 2025-04-16 11:13:18,995 - INFO - Gene gene-SPN23F_RS00040 has a mutation rate of 0.06.
# 2025-04-16 11:13:18,995 - INFO - Gene cds-WP_000041909.1 has no mutations in the population. Skipping this gene.
# 2025-04-16 11:13:18,995 - INFO - Gene gene-SPN23F_RS14045 has a mutation rate of 0.28.
# 2025-04-16 11:13:18,995 - INFO - Gene cds-WP_000429334.1 has no mutations in the population. Skipping this gene.
# 2025-04-16 11:13:18,996 - INFO - Gene gene-SPN23F_RS00050 has a mutation rate of 0.3933333333333333.
# 2025-04-16 11:13:18,996 - INFO - Gene cds-WP_001224768.1 has no mutations in the population. Skipping this gene.
# 2025-04-16 11:13:18,996 - INFO - Gene gene-SPN23F_RS00055 has a mutation rate of 0.94.
# 2025-04-16 11:13:18,997 - INFO - Gene cds-WP_001208992.1 has no mutations in the population. Skipping this gene.
# 2025-04-16 11:13:18,997 - INFO - Gene gene-SPN23F_RS00060 has a mutation rate of 0.12333333333333334.
# 2025-04-16 11:13:18,997 - INFO - Gene cds-WP_000892185.1 has no mutations in the population. Skipping this gene.
# 2025-04-16 11:13:18,998 - INFO - Gene gene-SPN23F_RS00065 has a mutation rate of 0.5666666666666667.
# 2025-04-16 11:13:18,998 - INFO - Gene cds-WP_000744545.1 has no mutations in the population. Skipping this gene.
# 2025-04-16 11:13:18,998 - INFO - Gene gene-SPN23F_RS00070 has no mutations in the population. Skipping this gene.
# 2025-04-16 11:13:18,998 - INFO - Gene cds-WP_000436644.1 has no mutations in the population. Skipping this gene.
# 2025-04-16 11:13:18,999 - INFO - Gene gene-SPN23F_RS00075 has no mutations in the population. Skipping this gene.
# 2025-04-16 11:13:18,999 - INFO - Gene cds-WP_000588897.1 has no mutations in the population. Skipping this gene.
# 2025-04-16 11:13:18,999 - INFO - Gene gene-SPN23F_RS00080 has no mutations in the population. Skipping this gene.
# 2025-04-16 11:13:19,000 - INFO - Gene gene-SPN23F_RS00085 has no mutations in the population. Skipping this gene.
# 2025-04-16 11:13:19,000 - INFO - Gene gene-SPN23F_RS00090 has no mutations in the population. Skipping this gene.
# 2025-04-16 11:13:19,001 - INFO - Gene gene-SPN23F_RS00095 has no mutations in the population. Skipping this gene.
# 2025-04-16 11:13:19,001 - INFO - Gene gene-SPN23F_RS00100 has no mutations in the population. Skipping this gene.
# 2025-04-16 11:13:19,001 - INFO - Gene gene-SPN23F_RS00105 has no mutations in the population. Skipping this gene.
# 2025-04-16 11:13:19,001 - INFO - Gene cds-SPN23F_RS11705 has no mutations in the population. Skipping this gene.
# 2025-04-16 11:13:19,002 - INFO - Gene cds-SPN23F_RS11710 has no mutations in the population. Skipping this gene.
# 2025-04-16 11:13:19,002 - INFO - Gene gene-SPN23F_RS00140 has a mutation rate of 0.4.
# 2025-04-16 11:13:19,003 - INFO - Gene cds-WP_000939545.1 has no mutations in the population. Skipping this gene.
# 2025-04-16 11:13:19,003 - INFO - Gene gene-SPN23F_RS00145 has a mutation rate of 0.11.
# 2025-04-16 11:13:19,003 - INFO - Gene cds-WP_000205044.1 has no mutations in the population. Skipping this gene.
# 2025-04-16 11:13:19,004 - INFO - Gene gene-SPN23F_RS00150 has a mutation rate of 0.46.
# 2025-04-16 11:13:19,004 - INFO - Gene cds-WP_000291870.1 has no mutations in the population. Skipping this gene.
# 2025-04-16 11:13:19,004 - INFO - Gene gene-SPN23F_RS11715 has no mutations in the population. Skipping this gene.
# 2025-04-16 11:13:19,005 - INFO - Gene gene-SPN23F_RS13665 has a mutation rate of 0.01.
# 2025-04-16 11:13:19,005 - INFO - Gene cds-WP_001106362.1 has no mutations in the population. Skipping this gene.
# 2025-04-16 11:13:19,005 - INFO - Gene gene-SPN23F_RS13670 has a mutation rate of 0.05.
# 2025-04-16 11:13:19,006 - INFO - Gene cds-WP_001814135.1 has no mutations in the population. Skipping this gene.
# 2025-04-16 11:13:19,006 - INFO - Gene gene-SPN23F_RS00165 has no mutations in the population. Skipping this gene.
# 2025-04-16 11:13:19,006 - INFO - Gene cds-WP_000401841.1 has no mutations in the population. Skipping this gene.
# 2025-04-16 11:13:19,006 - INFO - Gene gene-SPN23F_RS00170 has a mutation rate of 0.11333333333333333.
# 2025-04-16 11:13:19,007 - INFO - Gene cds-WP_000170931.1 has no mutations in the population. Skipping this gene.
# 2025-04-16 11:13:19,007 - INFO - Gene gene-SPN23F_RS00175 has a mutation rate of 0.03.
# 2025-04-16 11:13:19,007 - INFO - Gene cds-WP_000285962.1 has no mutations in the population. Skipping this gene.
# 2025-04-16 11:13:19,008 - INFO - Gene gene-SPN23F_RS00180 has a mutation rate of 0.03666666666666667.
# 2025-04-16 11:13:19,008 - INFO - Gene cds-WP_000156419.1 has no mutations in the population. Skipping this gene.
# 2025-04-16 11:13:19,009 - INFO - Gene gene-SPN23F_RS00185 has a mutation rate of 0.06333333333333334.
# 2025-04-16 11:13:19,009 - INFO - Gene cds-WP_000464160.1 has no mutations in the population. Skipping this gene.
# 2025-04-16 11:13:19,009 - INFO - Gene gene-SPN23F_RS00190 has no mutations in the population. Skipping this gene.
# 2025-04-16 11:13:19,009 - INFO - Gene cds-WP_001112859.1 has no mutations in the population. Skipping this gene.
# 2025-04-16 11:13:19,010 - INFO - Gene gene-SPN23F_RS00195 has a mutation rate of 0.07.
# 2025-04-16 11:13:19,010 - INFO - Gene cds-WP_001247549.1 has no mutations in the population. Skipping this gene.
# 2025-04-16 11:13:19,010 - INFO - Gene gene-SPN23F_RS11720 has a mutation rate of 0.02.
# 2025-04-16 11:13:19,011 - INFO - Gene cds-WP_000024181.1 has no mutations in the population. Skipping this gene.
# 2025-04-16 11:13:19,011 - INFO - Gene cds-SPN23F_RS00200 has no mutations in the population. Skipping this gene.
# 2025-04-16 11:13:19,011 - INFO - Gene gene-SPN23F_RS00205 has a mutation rate of 0.04.
# 2025-04-16 11:13:19,012 - INFO - Gene cds-WP_001209433.1 has no mutations in the population. Skipping this gene.
# 2025-04-16 11:13:19,012 - INFO - Gene gene-SPN23F_RS13455 has a mutation rate of 0.023333333333333334.
# 2025-04-16 11:13:19,012 - INFO - Gene cds-WP_001030863.1 has no mutations in the population. Skipping this gene.
# 2025-04-16 11:13:19,013 - INFO - Gene gene-SPN23F_RS00210 has a mutation rate of 0.26666666666666666.
# 2025-04-16 11:13:19,013 - INFO - Gene cds-WP_000701992.1 has no mutations in the population. Skipping this gene.
# 2025-04-16 11:13:19,014 - INFO - Gene gene-SPN23F_RS00215 has a mutation rate of 0.2966666666666667.
# 2025-04-16 11:13:19,014 - INFO - Gene cds-WP_000691236.1 has no mutations in the population. Skipping this gene.
# 2025-04-16 11:13:19,014 - INFO - Gene gene-SPN23F_RS00220 has a mutation rate of 0.26666666666666666.
# 2025-04-16 11:13:19,014 - INFO - Gene cds-WP_075213698.1 has no mutations in the population. Skipping this gene.
# 2025-04-16 11:13:19,015 - INFO - Gene gene-SPN23F_RS00225 has a mutation rate of 0.34.
# 2025-04-16 11:13:19,015 - INFO - Gene cds-WP_001809263.1 has no mutations in the population. Skipping this gene.
# 2025-04-16 11:13:19,015 - INFO - Gene cds-SPN23F_RS00230 has no mutations in the population. Skipping this gene.
# 2025-04-16 11:13:19,016 - INFO - Gene gene-SPN23F_RS00240 has a mutation rate of 0.22333333333333333.
# 2025-04-16 11:13:19,016 - INFO - Gene cds-WP_000010163.1 has no mutations in the population. Skipping this gene.
# 2025-04-16 11:13:19,016 - INFO - Gene cds-SPN23F_RS13675 has no mutations in the population. Skipping this gene.
# 2025-04-16 11:13:19,017 - INFO - Gene gene-SPN23F_RS00260 has a mutation rate of 0.7433333333333333.
# 2025-04-16 11:13:19,017 - INFO - Gene cds-WP_001812055.1 has no mutations in the population. Skipping this gene.
# 2025-04-16 11:13:19,018 - INFO - Gene gene-SPN23F_RS00265 has a mutation rate of 0.2866666666666667.
# 2025-04-16 11:13:19,018 - INFO - Gene cds-WP_000076479.1 has no mutations in the population. Skipping this gene.
# 2025-04-16 11:13:19,018 - INFO - Gene gene-SPN23F_RS13680 has a mutation rate of 0.41333333333333333.
# 2025-04-16 11:13:19,018 - INFO - Gene cds-WP_001814139.1 has no mutations in the population. Skipping this gene.
# 2025-04-16 11:13:19,019 - INFO - Gene gene-SPN23F_RS00275 has a mutation rate of 0.8533333333333334.
# 2025-04-16 11:13:19,019 - INFO - Gene cds-WP_000009180.1 has no mutations in the population. Skipping this gene.
# 2025-04-16 11:13:19,019 - INFO - Gene gene-SPN23F_RS00280 has a mutation rate of 0.7166666666666667.
# 2025-04-16 11:13:19,020 - INFO - Gene cds-WP_000366348.1 has no mutations in the population. Skipping this gene.
# 2025-04-16 11:13:19,020 - INFO - Gene gene-SPN23F_RS00285 has a mutation rate of 0.5866666666666667.
# 2025-04-16 11:13:19,020 - INFO - Gene cds-WP_000616164.1 has no mutations in the population. Skipping this gene.
# 2025-04-16 11:13:19,020 - INFO - Gene gene-SPN23F_RS00290 has a mutation rate of 0.69.
# 2025-04-16 11:13:19,021 - INFO - Gene cds-WP_000717451.1 has no mutations in the population. Skipping this gene.
# 2025-04-16 11:13:19,021 - INFO - Gene gene-SPN23F_RS00295 has a mutation rate of 0.14.
# 2025-04-16 11:13:19,021 - INFO - Gene cds-WP_000136449.1 has no mutations in the population. Skipping this gene.
# 2025-04-16 11:13:19,022 - INFO - Gene cds-SPN23F_RS11730 has no mutations in the population. Skipping this gene.
# 2025-04-16 11:13:19,022 - INFO - Gene gene-SPN23F_RS00300 has a mutation rate of 0.7233333333333334.
# 2025-04-16 11:13:19,022 - INFO - Gene cds-WP_001093075.1 has no mutations in the population. Skipping this gene.
# 2025-04-16 11:13:19,023 - INFO - Gene gene-SPN23F_RS14050 has a mutation rate of 0.023333333333333334.
# 2025-04-16 11:13:19,023 - INFO - Gene cds-WP_000346297.1 has no mutations in the population. Skipping this gene.
# 2025-04-16 11:13:19,023 - INFO - Gene gene-SPN23F_RS00315 has a mutation rate of 0.5666666666666667.
# 2025-04-16 11:13:19,024 - INFO - Gene cds-WP_000668272.1 has no mutations in the population. Skipping this gene.
# 2025-04-16 11:13:19,024 - INFO - Gene gene-SPN23F_RS00320 has a mutation rate of 0.87.
# 2025-04-16 11:13:19,024 - INFO - Gene cds-WP_000801611.1 has no mutations in the population. Skipping this gene.
# 2025-04-16 11:13:19,025 - INFO - Gene gene-SPN23F_RS00325 has a mutation rate of 0.5433333333333333.
# 2025-04-16 11:13:19,025 - INFO - Gene cds-WP_000043310.1 has no mutations in the population. Skipping this gene.
# 2025-04-16 11:13:19,025 - INFO - Gene gene-SPN23F_RS00330 has a mutation rate of 0.94.
# 2025-04-16 11:13:19,026 - INFO - Gene cds-WP_000361217.1 has no mutations in the population. Skipping this gene.
# 2025-04-16 11:13:19,026 - INFO - Gene gene-SPN23F_RS00335 has a mutation rate of 0.6733333333333333.
# 2025-04-16 11:13:19,026 - INFO - Gene cds-WP_000220632.1 has no mutations in the population. Skipping this gene.
# 2025-04-16 11:13:19,026 - INFO - Gene gene-SPN23F_RS00340 has a mutation rate of 0.44666666666666666.
# 2025-04-16 11:13:19,027 - INFO - Gene cds-WP_000182575.1 has no mutations in the population. Skipping this gene.
# 2025-04-16 11:13:19,027 - INFO - Gene gene-SPN23F_RS00345 has a mutation rate of 0.4766666666666667.
# 2025-04-16 11:13:19,027 - INFO - Gene cds-WP_000717506.1 has no mutations in the population. Skipping this gene.
# 2025-04-16 11:13:19,028 - INFO - Gene gene-SPN23F_RS00350 has a mutation rate of 0.2633333333333333.
# 2025-04-16 11:13:19,028 - INFO - Gene cds-WP_000894018.1 has no mutations in the population. Skipping this gene.
# 2025-04-16 11:13:19,028 - INFO - Gene gene-SPN23F_RS00355 has a mutation rate of 0.66.
# 2025-04-16 11:13:19,028 - INFO - Gene cds-WP_000167083.1 has no mutations in the population. Skipping this gene.
# 2025-04-16 11:13:19,029 - INFO - Gene gene-SPN23F_RS00360 has a mutation rate of 0.82.
# 2025-04-16 11:13:19,029 - INFO - Gene cds-WP_000772228.1 has no mutations in the population. Skipping this gene.
# 2025-04-16 11:13:19,029 - INFO - Gene gene-SPN23F_RS13685 has a mutation rate of 0.02.
# 2025-04-16 11:13:19,029 - INFO - Gene cds-WP_001809271.1 has no mutations in the population. Skipping this gene.
# 2025-04-16 11:13:19,030 - INFO - Gene gene-SPN23F_RS00365 has a mutation rate of 0.18666666666666668.
# 2025-04-16 11:13:19,030 - INFO - Gene cds-WP_000805601.1 has no mutations in the population. Skipping this gene.
# 2025-04-16 11:13:19,030 - INFO - Gene gene-SPN23F_RS00370 has a mutation rate of 0.6833333333333333.
# 2025-04-16 11:13:19,031 - INFO - Gene cds-WP_000099019.1 has no mutations in the population. Skipping this gene.
# 2025-04-16 11:13:19,031 - INFO - Gene gene-SPN23F_RS00375 has no mutations in the population. Skipping this gene.
# 2025-04-16 11:13:19,031 - INFO - Gene cds-WP_001813327.1 has no mutations in the population. Skipping this gene.
# 2025-04-16 11:13:19,032 - INFO - Gene gene-SPN23F_RS00380 has a mutation rate of 0.29333333333333333.
# 2025-04-16 11:13:19,032 - INFO - Gene cds-WP_000610746.1 has no mutations in the population. Skipping this gene.
# 2025-04-16 11:13:19,032 - INFO - Gene gene-SPN23F_RS00385 has a mutation rate of 0.8333333333333334.
# 2025-04-16 11:13:19,033 - INFO - Gene cds-WP_000679942.1 has no mutations in the population. Skipping this gene.
# 2025-04-16 11:13:19,033 - INFO - Gene gene-SPN23F_RS00390 has a mutation rate of 0.26.
# 2025-04-16 11:13:19,033 - INFO - Gene cds-WP_001007198.1 has no mutations in the population. Skipping this gene.
# 2025-04-16 11:13:19,034 - INFO - Gene gene-SPN23F_RS00395 has a mutation rate of 0.6266666666666667.
# 2025-04-16 11:13:19,034 - INFO - Gene cds-WP_000196572.1 has no mutations in the population. Skipping this gene.
# 2025-04-16 11:13:19,034 - INFO - Gene gene-SPN23F_RS00400 has a mutation rate of 0.20333333333333334.
# 2025-04-16 11:13:19,035 - INFO - Gene cds-WP_000156967.1 has no mutations in the population. Skipping this gene.
# 2025-04-16 11:13:19,035 - INFO - Gene gene-SPN23F_RS00405 has a mutation rate of 0.18333333333333332.
# 2025-04-16 11:13:19,035 - INFO - Gene cds-WP_000616999.1 has no mutations in the population. Skipping this gene.
# 2025-04-16 11:13:19,035 - INFO - Gene gene-SPN23F_RS00410 has a mutation rate of 0.13333333333333333.
# 2025-04-16 11:13:19,036 - INFO - Gene cds-WP_000185298.1 has no mutations in the population. Skipping this gene.
# 2025-04-16 11:13:19,036 - INFO - Gene gene-SPN23F_RS00415 has a mutation rate of 0.17.
# 2025-04-16 11:13:19,036 - INFO - Gene cds-WP_000167454.1 has no mutations in the population. Skipping this gene.
# 2025-04-16 11:13:19,037 - INFO - Gene gene-SPN23F_RS00420 has a mutation rate of 0.5566666666666666.
# 2025-04-16 11:13:19,037 - INFO - Gene cds-WP_000903552.1 has no mutations in the population. Skipping this gene.
# 2025-04-16 11:13:19,037 - INFO - Gene gene-SPN23F_RS00425 has a mutation rate of 0.4266666666666667.
# 2025-04-16 11:13:19,037 - INFO - Gene cds-WP_000649425.1 has no mutations in the population. Skipping this gene.
# 2025-04-16 11:13:19,038 - INFO - Gene gene-SPN23F_RS00430 has a mutation rate of 0.75.
# 2025-04-16 11:13:19,038 - INFO - Gene cds-WP_000220701.1 has no mutations in the population. Skipping this gene.
# 2025-04-16 11:13:19,038 - INFO - Gene gene-SPN23F_RS00435 has a mutation rate of 0.48333333333333334.
# 2025-04-16 11:13:19,039 - INFO - Gene cds-WP_000185151.1 has no mutations in the population. Skipping this gene.
# 2025-04-16 11:13:19,039 - INFO - Gene gene-SPN23F_RS13355 has a mutation rate of 0.5233333333333333.
# 2025-04-16 11:13:19,039 - INFO - Gene cds-WP_000695849.1 has no mutations in the population. Skipping this gene.
# 2025-04-16 11:13:19,039 - INFO - Gene gene-SPN23F_RS00445 has a mutation rate of 0.36333333333333334.
# 2025-04-16 11:13:19,040 - INFO - Gene cds-WP_000450181.1 has no mutations in the population. Skipping this gene.
# 2025-04-16 11:13:19,040 - INFO - Gene cds-SPN23F_RS11750 has no mutations in the population. Skipping this gene.
# 2025-04-16 11:13:19,040 - INFO - Gene gene-SPN23F_RS00450 has a mutation rate of 0.79.
# 2025-04-16 11:13:19,041 - INFO - Gene cds-WP_000614999.1 has no mutations in the population. Skipping this gene.
# 2025-04-16 11:13:19,041 - INFO - Gene gene-SPN23F_RS13180 has a mutation rate of 0.5266666666666666.
# 2025-04-16 11:13:19,041 - INFO - Gene cds-WP_000849912.1 has no mutations in the population. Skipping this gene.
# 2025-04-16 11:13:19,042 - INFO - Gene gene-SPN23F_RS00460 has a mutation rate of 0.2733333333333333.
# 2025-04-16 11:13:19,042 - INFO - Gene cds-WP_000897726.1 has no mutations in the population. Skipping this gene.
# 2025-04-16 11:13:19,042 - INFO - Gene gene-SPN23F_RS00465 has a mutation rate of 0.04666666666666667.
# 2025-04-16 11:13:19,042 - INFO - Gene cds-WP_001283896.1 has no mutations in the population. Skipping this gene.
# 2025-04-16 11:13:19,043 - INFO - Gene gene-SPN23F_RS13690 has a mutation rate of 0.5266666666666666.
# 2025-04-16 11:13:19,043 - INFO - Gene cds-WP_000692796.1 has no mutations in the population. Skipping this gene.
# 2025-04-16 11:13:19,044 - INFO - Gene gene-SPN23F_RS00475 has a mutation rate of 0.87.
# 2025-04-16 11:13:19,044 - INFO - Gene cds-WP_000771901.1 has no mutations in the population. Skipping this gene.
# 2025-04-16 11:13:19,044 - INFO - Gene gene-SPN23F_RS00480 has a mutation rate of 0.75.
# 2025-04-16 11:13:19,045 - INFO - Gene cds-WP_000291603.1 has no mutations in the population. Skipping this gene.
# 2025-04-16 11:13:19,045 - INFO - Gene cds-SPN23F_RS00485 has no mutations in the population. Skipping this gene.
# 2025-04-16 11:13:19,045 - INFO - Gene gene-SPN23F_RS00490 has a mutation rate of 0.043333333333333335.
# 2025-04-16 11:13:19,045 - INFO - Gene cds-WP_000520642.1 has no mutations in the population. Skipping this gene.
# 2025-04-16 11:13:19,046 - INFO - Gene gene-SPN23F_RS00495 has a mutation rate of 0.21.
# 2025-04-16 11:13:19,046 - INFO - Gene cds-WP_000769768.1 has no mutations in the population. Skipping this gene.
# 2025-04-16 11:13:19,046 - INFO - Gene gene-SPN23F_RS00500 has no mutations in the population. Skipping this gene.
# 2025-04-16 11:13:19,047 - INFO - Gene cds-WP_000092756.1 has no mutations in the population. Skipping this gene.
# 2025-04-16 11:13:19,047 - INFO - Gene cds-SPN23F_RS11760 has no mutations in the population. Skipping this gene.
# 2025-04-16 11:13:19,047 - INFO - Gene cds-SPN23F_RS12785 has no mutations in the population. Skipping this gene.
# 2025-04-16 11:13:19,047 - INFO - Gene gene-SPN23F_RS00510 has a mutation rate of 0.49333333333333335.
# 2025-04-16 11:13:19,048 - INFO - Gene cds-WP_000148253.1 has no mutations in the population. Skipping this gene.
# 2025-04-16 11:13:19,048 - INFO - Gene gene-SPN23F_RS00515 has a mutation rate of 0.53.
# 2025-04-16 11:13:19,048 - INFO - Gene cds-WP_001809441.1 has no mutations in the population. Skipping this gene.
# 2025-04-16 11:13:19,048 - INFO - Gene gene-SPN23F_RS00520 has a mutation rate of 0.06666666666666667.
# 2025-04-16 11:13:19,049 - INFO - Gene cds-WP_000714582.1 has no mutations in the population. Skipping this gene.
# 2025-04-16 11:13:19,049 - INFO - Gene gene-SPN23F_RS00525 has a mutation rate of 0.03333333333333333.
# 2025-04-16 11:13:19,050 - INFO - Gene cds-WP_001075102.1 has no mutations in the population. Skipping this gene.
# 2025-04-16 11:13:19,050 - INFO - Gene gene-SPN23F_RS00530 has a mutation rate of 0.17666666666666667.
# 2025-04-16 11:13:19,050 - INFO - Gene cds-WP_000800432.1 has no mutations in the population. Skipping this gene.
# 2025-04-16 11:13:19,050 - INFO - Gene gene-SPN23F_RS00535 has a mutation rate of 0.06333333333333334.
# 2025-04-16 11:13:19,051 - INFO - Gene cds-WP_001030031.1 has no mutations in the population. Skipping this gene.
# 2025-04-16 11:13:19,051 - INFO - Gene gene-SPN23F_RS14055 has no mutations in the population. Skipping this gene.
# 2025-04-16 11:13:19,051 - INFO - Gene cds-WP_001813665.1 has no mutations in the population. Skipping this gene.
# 2025-04-16 11:13:19,052 - INFO - Gene gene-SPN23F_RS00540 has a mutation rate of 0.6966666666666667.
# 2025-04-16 11:13:19,052 - INFO - Gene cds-WP_001140340.1 has no mutations in the population. Skipping this gene.
# 2025-04-16 11:13:19,052 - INFO - Gene gene-SPN23F_RS00545 has a mutation rate of 0.6533333333333333.
# 2025-04-16 11:13:19,053 - INFO - Gene cds-WP_000808442.1 has no mutations in the population. Skipping this gene.
# 2025-04-16 11:13:19,053 - INFO - Gene gene-SPN23F_RS00550 has a mutation rate of 0.8666666666666667.
# 2025-04-16 11:13:19,053 - INFO - Gene cds-WP_001233692.1 has no mutations in the population. Skipping this gene.
# 2025-04-16 11:13:19,054 - INFO - Gene gene-SPN23F_RS00555 has a mutation rate of 0.5966666666666667.
# 2025-04-16 11:13:19,054 - INFO - Gene cds-WP_000198687.1 has no mutations in the population. Skipping this gene.
# 2025-04-16 11:13:19,054 - INFO - Gene gene-SPN23F_RS00560 has a mutation rate of 0.4866666666666667.
# 2025-04-16 11:13:19,055 - INFO - Gene cds-WP_000273863.1 has no mutations in the population. Skipping this gene.
# 2025-04-16 11:13:19,055 - INFO - Gene cds-SPN23F_RS00565 has no mutations in the population. Skipping this gene.
# 2025-04-16 11:13:19,055 - INFO - Gene gene-SPN23F_RS00570 has a mutation rate of 0.8333333333333334.
# 2025-04-16 11:13:19,055 - INFO - Gene cds-WP_000096197.1 has no mutations in the population. Skipping this gene.
# 2025-04-16 11:13:19,056 - INFO - Gene gene-SPN23F_RS00575 has a mutation rate of 0.43666666666666665.
# 2025-04-16 11:13:19,056 - INFO - Gene cds-WP_001035700.1 has no mutations in the population. Skipping this gene.
# 2025-04-16 11:13:19,056 - INFO - Gene gene-SPN23F_RS00580 has no mutations in the population. Skipping this gene.
# 2025-04-16 11:13:19,057 - INFO - Gene cds-WP_000436237.1 has no mutations in the population. Skipping this gene.
# 2025-04-16 11:13:19,057 - INFO - Gene gene-SPN23F_RS13190 has a mutation rate of 0.6433333333333333.
# 2025-04-16 11:13:19,057 - INFO - Gene cds-WP_000693348.1 has no mutations in the population. Skipping this gene.
# 2025-04-16 11:13:19,058 - INFO - Gene gene-SPN23F_RS00590 has a mutation rate of 0.42333333333333334.
# 2025-04-16 11:13:19,058 - INFO - Gene cds-WP_000200892.1 has no mutations in the population. Skipping this gene.
# 2025-04-16 11:13:19,058 - INFO - Gene gene-SPN23F_RS00595 has a mutation rate of 0.5533333333333333.
# 2025-04-16 11:13:19,059 - INFO - Gene cds-WP_000500038.1 has no mutations in the population. Skipping this gene.
# 2025-04-16 11:13:19,059 - INFO - Gene gene-SPN23F_RS00600 has a mutation rate of 0.06333333333333334.
# 2025-04-16 11:13:19,059 - INFO - Gene cds-WP_000838912.1 has no mutations in the population. Skipping this gene.
# 2025-04-16 11:13:19,059 - INFO - Gene gene-SPN23F_RS00605 has a mutation rate of 0.33.
# 2025-04-16 11:13:19,060 - INFO - Gene cds-WP_000836442.1 has no mutations in the population. Skipping this gene.
# 2025-04-16 11:13:19,060 - INFO - Gene gene-SPN23F_RS00610 has no mutations in the population. Skipping this gene.
# 2025-04-16 11:13:19,060 - INFO - Gene cds-WP_001861316.1 has no mutations in the population. Skipping this gene.
# 2025-04-16 11:13:19,060 - INFO - Gene gene-SPN23F_RS00615 has no mutations in the population. Skipping this gene.
# 2025-04-16 11:13:19,061 - INFO - Gene cds-WP_001230165.1 has no mutations in the population. Skipping this gene.
# 2025-04-16 11:13:19,061 - INFO - Gene gene-SPN23F_RS00620 has no mutations in the population. Skipping this gene.
# 2025-04-16 11:13:19,061 - INFO - Gene cds-WP_000724257.1 has no mutations in the population. Skipping this gene.
# 2025-04-16 11:13:19,062 - INFO - Gene gene-SPN23F_RS00625 has no mutations in the population. Skipping this gene.
# 2025-04-16 11:13:19,062 - INFO - Gene cds-WP_000571330.1 has no mutations in the population. Skipping this gene.
# 2025-04-16 11:13:19,062 - INFO - Gene gene-SPN23F_RS00630 has no mutations in the population. Skipping this gene.
# 2025-04-16 11:13:19,063 - INFO - Gene cds-WP_001038484.1 has no mutations in the population. Skipping this gene.
# 2025-04-16 11:13:19,063 - INFO - Gene cds-SPN23F_RS00635 has no mutations in the population. Skipping this gene.
# 2025-04-16 11:13:19,063 - INFO - Gene gene-SPN23F_RS00640 has no mutations in the population. Skipping this gene.
# 2025-04-16 11:13:19,064 - INFO - Gene cds-WP_001861316.1-2 has no mutations in the population. Skipping this gene.
# 2025-04-16 11:13:19,064 - INFO - Gene gene-SPN23F_RS00650 has no mutations in the population. Skipping this gene.
# 2025-04-16 11:13:19,064 - INFO - Gene cds-WP_000436237.1-2 has no mutations in the population. Skipping this gene.
# 2025-04-16 11:13:19,065 - INFO - Gene gene-SPN23F_RS13360 has a mutation rate of 0.27666666666666667.
# 2025-04-16 11:13:19,065 - INFO - Gene cds-WP_001814148.1 has no mutations in the population. Skipping this gene.
# 2025-04-16 11:13:19,065 - INFO - Gene gene-SPN23F_RS00665 has a mutation rate of 1.0.
# 2025-04-16 11:13:19,066 - INFO - Gene cds-WP_001814150.1 has no mutations in the population. Skipping this gene.
# 2025-04-16 11:13:19,066 - INFO - Gene cds-SPN23F_RS13695 has no mutations in the population. Skipping this gene.
# 2025-04-16 11:13:19,066 - INFO - Gene gene-SPN23F_RS00670 has a mutation rate of 0.51.
# 2025-04-16 11:13:19,067 - INFO - Gene cds-WP_000770312.1 has no mutations in the population. Skipping this gene.
# 2025-04-16 11:13:19,067 - INFO - Gene gene-SPN23F_RS00675 has a mutation rate of 0.8566666666666667.
# 2025-04-16 11:13:19,067 - INFO - Gene cds-WP_020901307.1 has no mutations in the population. Skipping this gene.
# 2025-04-16 11:13:19,068 - INFO - Gene gene-SPN23F_RS13700 has a mutation rate of 0.8666666666666667.
# 2025-04-16 11:13:19,068 - INFO - Gene cds-WP_231844674.1 has no mutations in the population. Skipping this gene.
# 2025-04-16 11:13:19,068 - INFO - Gene cds-SPN23F_RS14150 has no mutations in the population. Skipping this gene.
# 2025-04-16 11:13:19,068 - INFO - Gene gene-SPN23F_RS00685 has a mutation rate of 0.8166666666666667.
# 2025-04-16 11:13:19,069 - INFO - Gene cds-WP_001282967.1 has no mutations in the population. Skipping this gene.
# 2025-04-16 11:13:19,069 - INFO - Gene gene-SPN23F_RS00690 has a mutation rate of 0.6833333333333333.
# 2025-04-16 11:13:19,069 - INFO - Gene cds-WP_000193610.1 has no mutations in the population. Skipping this gene.
# 2025-04-16 11:13:19,070 - INFO - Gene gene-SPN23F_RS00695 has a mutation rate of 0.59.
# 2025-04-16 11:13:19,070 - INFO - Gene cds-WP_000220946.1 has no mutations in the population. Skipping this gene.
# 2025-04-16 11:13:19,070 - INFO - Gene gene-SPN23F_RS13710 has no mutations in the population. Skipping this gene.
# 2025-04-16 11:13:19,070 - INFO - Gene cds-WP_001838083.1 has no mutations in the population. Skipping this gene.
# 2025-04-16 11:13:19,071 - INFO - Gene gene-SPN23F_RS00705 has a mutation rate of 0.29.
# 2025-04-16 11:13:19,071 - INFO - Gene cds-WP_000331980.1 has no mutations in the population. Skipping this gene.
# 2025-04-16 11:13:19,071 - INFO - Gene gene-SPN23F_RS00710 has a mutation rate of 0.31.
# 2025-04-16 11:13:19,071 - INFO - Gene cds-WP_000639577.1 has no mutations in the population. Skipping this gene.
# 2025-04-16 11:13:19,072 - INFO - Gene cds-SPN23F_RS13715 has no mutations in the population. Skipping this gene.
# 2025-04-16 11:13:19,072 - INFO - Gene gene-SPN23F_RS00715 has a mutation rate of 0.15.
# 2025-04-16 11:13:19,072 - INFO - Gene cds-WP_000977347.1 has no mutations in the population. Skipping this gene.
# 2025-04-16 11:13:19,073 - INFO - Gene gene-SPN23F_RS00720 has a mutation rate of 0.20666666666666667.
# 2025-04-16 11:13:19,073 - INFO - Gene cds-WP_000180803.1 has no mutations in the population. Skipping this gene.
# 2025-04-16 11:13:19,074 - INFO - Gene gene-SPN23F_RS00725 has a mutation rate of 1.0.
# 2025-04-16 11:13:19,074 - INFO - Gene cds-WP_000865706.1 has no mutations in the population. Skipping this gene.
# 2025-04-16 11:13:19,074 - INFO - Gene gene-SPN23F_RS00730 has a mutation rate of 0.6366666666666667.
# 2025-04-16 11:13:19,075 - INFO - Gene cds-WP_000569831.1 has no mutations in the population. Skipping this gene.
# 2025-04-16 11:13:19,075 - INFO - Gene gene-SPN23F_RS00735 has a mutation rate of 0.77.
# 2025-04-16 11:13:19,075 - INFO - Gene cds-WP_000655033.1 has no mutations in the population. Skipping this gene.
# 2025-04-16 11:13:19,076 - INFO - Gene cds-SPN23F_RS00745 has no mutations in the population. Skipping this gene.
# 2025-04-16 11:13:19,076 - INFO - Gene cds-SPN23F_RS13720 has no mutations in the population. Skipping this gene.
# 2025-04-16 11:13:19,076 - INFO - Gene gene-SPN23F_RS13725 has a mutation rate of 0.22333333333333333.
# 2025-04-16 11:13:19,077 - INFO - Gene cds-WP_001810713.1 has no mutations in the population. Skipping this gene.
# 2025-04-16 11:13:19,077 - INFO - Gene gene-SPN23F_RS13730 has a mutation rate of 0.6066666666666667.
# 2025-04-16 11:13:19,077 - INFO - Gene cds-WP_000371189.1 has no mutations in the population. Skipping this gene.
# 2025-04-16 11:13:19,078 - INFO - Gene gene-SPN23F_RS00770 has a mutation rate of 0.43.
# 2025-04-16 11:13:19,078 - INFO - Gene cds-WP_000375722.1 has no mutations in the population. Skipping this gene.
# 2025-04-16 11:13:19,078 - INFO - Gene gene-SPN23F_RS00775 has a mutation rate of 0.3333333333333333.
# 2025-04-16 11:13:19,078 - INFO - Gene cds-WP_000288029.1 has no mutations in the population. Skipping this gene.
# 2025-04-16 11:13:19,079 - INFO - Gene cds-SPN23F_RS14240 has no mutations in the population. Skipping this gene.
# 2025-04-16 11:13:19,079 - INFO - Gene gene-SPN23F_RS00785 has a mutation rate of 0.37333333333333335.
# 2025-04-16 11:13:19,079 - INFO - Gene cds-WP_001290270.1 has no mutations in the population. Skipping this gene.
# 2025-04-16 11:13:19,079 - INFO - Gene gene-SPN23F_RS00790 has a mutation rate of 0.5766666666666667.
# 2025-04-16 11:13:19,080 - INFO - Gene cds-WP_000069860.1 has no mutations in the population. Skipping this gene.
# 2025-04-16 11:13:19,080 - INFO - Gene gene-SPN23F_RS00795 has a mutation rate of 0.5666666666666667.
# 2025-04-16 11:13:19,080 - INFO - Gene cds-WP_001017600.1 has no mutations in the population. Skipping this gene.
# 2025-04-16 11:13:19,081 - INFO - Gene gene-SPN23F_RS00800 has a mutation rate of 0.7733333333333333.
# 2025-04-16 11:13:19,081 - INFO - Gene cds-WP_000570720.1 has no mutations in the population. Skipping this gene.
# 2025-04-16 11:13:19,081 - INFO - Gene gene-SPN23F_RS00805 has a mutation rate of 0.36666666666666664.
# 2025-04-16 11:13:19,081 - INFO - Gene cds-WP_000933464.1 has no mutations in the population. Skipping this gene.
# 2025-04-16 11:13:19,082 - INFO - Gene gene-SPN23F_RS00810 has a mutation rate of 0.7066666666666667.
# 2025-04-16 11:13:19,082 - INFO - Gene cds-WP_000720790.1 has no mutations in the population. Skipping this gene.
# 2025-04-16 11:13:19,082 - INFO - Gene gene-SPN23F_RS00815 has a mutation rate of 0.97.
# 2025-04-16 11:13:19,083 - INFO - Gene cds-WP_000862430.1 has no mutations in the population. Skipping this gene.
# 2025-04-16 11:13:19,083 - INFO - Gene gene-SPN23F_RS00825 has a mutation rate of 0.75.
# 2025-04-16 11:13:19,084 - INFO - Gene cds-WP_001141646.1 has no mutations in the population. Skipping this gene.
# 2025-04-16 11:13:19,084 - INFO - Gene cds-SPN23F_RS13735 has no mutations in the population. Skipping this gene.
# 2025-04-16 11:13:19,085 - INFO - Gene gene-SPN23F_RS00835 has a mutation rate of 0.23333333333333334.
# 2025-04-16 11:13:19,085 - INFO - Gene cds-WP_000724936.1 has no mutations in the population. Skipping this gene.
# 2025-04-16 11:13:19,085 - INFO - Gene gene-SPN23F_RS00840 has a mutation rate of 0.43333333333333335.
# 2025-04-16 11:13:19,085 - INFO - Gene cds-WP_000694512.1 has no mutations in the population. Skipping this gene.
# 2025-04-16 11:13:19,086 - INFO - Gene gene-SPN23F_RS00845 has a mutation rate of 0.6433333333333333.
# 2025-04-16 11:13:19,086 - INFO - Gene cds-WP_000231785.1 has no mutations in the population. Skipping this gene.
# 2025-04-16 11:13:19,086 - INFO - Gene gene-SPN23F_RS00850 has a mutation rate of 0.5933333333333334.
# 2025-04-16 11:13:19,087 - INFO - Gene cds-WP_000085677.1 has no mutations in the population. Skipping this gene.
# 2025-04-16 11:13:19,087 - INFO - Gene gene-SPN23F_RS00855 has a mutation rate of 0.45.
# 2025-04-16 11:13:19,087 - INFO - Gene cds-WP_000444642.1 has no mutations in the population. Skipping this gene.
# 2025-04-16 11:13:19,087 - INFO - Gene gene-SPN23F_RS00860 has a mutation rate of 0.67.
# 2025-04-16 11:13:19,088 - INFO - Gene cds-WP_000748391.1 has no mutations in the population. Skipping this gene.
# 2025-04-16 11:13:19,088 - INFO - Gene gene-SPN23F_RS00865 has a mutation rate of 0.46.
# 2025-04-16 11:13:19,088 - INFO - Gene cds-WP_000532353.1 has no mutations in the population. Skipping this gene.
# 2025-04-16 11:13:19,089 - INFO - Gene gene-SPN23F_RS00870 has a mutation rate of 0.76.
# 2025-04-16 11:13:19,089 - INFO - Gene cds-WP_000800582.1 has no mutations in the population. Skipping this gene.
# 2025-04-16 11:13:19,089 - INFO - Gene gene-SPN23F_RS00875 has a mutation rate of 0.54.
# 2025-04-16 11:13:19,090 - INFO - Gene cds-WP_000278896.1 has no mutations in the population. Skipping this gene.
# 2025-04-16 11:13:19,090 - INFO - Gene gene-SPN23F_RS00880 has a mutation rate of 0.04.
# 2025-04-16 11:13:19,090 - INFO - Gene cds-WP_000729035.1 has no mutations in the population. Skipping this gene.
# 2025-04-16 11:13:19,091 - INFO - Gene gene-SPN23F_RS00885 has a mutation rate of 0.1.
# 2025-04-16 11:13:19,091 - INFO - Gene cds-WP_000849621.1 has no mutations in the population. Skipping this gene.
# 2025-04-16 11:13:19,091 - INFO - Gene gene-SPN23F_RS00890 has a mutation rate of 0.17.
# 2025-04-16 11:13:19,092 - INFO - Gene cds-WP_000075789.1 has no mutations in the population. Skipping this gene.
# 2025-04-16 11:13:19,092 - INFO - Gene gene-SPN23F_RS00895 has a mutation rate of 0.5166666666666667.
# 2025-04-16 11:13:19,092 - INFO - Gene cds-WP_000745054.1 has no mutations in the population. Skipping this gene.
# 2025-04-16 11:13:19,093 - INFO - Gene gene-SPN23F_RS00900 has a mutation rate of 0.36333333333333334.
# 2025-04-16 11:13:19,093 - INFO - Gene cds-WP_000861955.1 has no mutations in the population. Skipping this gene.
# 2025-04-16 11:13:19,093 - INFO - Gene gene-SPN23F_RS14060 has a mutation rate of 0.4.
# 2025-04-16 11:13:19,094 - INFO - Gene cds-WP_001813544.1 has no mutations in the population. Skipping this gene.
# 2025-04-16 11:13:19,094 - INFO - Gene gene-SPN23F_RS00905 has a mutation rate of 0.32.
# 2025-04-16 11:13:19,094 - INFO - Gene cds-WP_000018169.1 has no mutations in the population. Skipping this gene.
# 2025-04-16 11:13:19,095 - INFO - Gene gene-SPN23F_RS00910 has a mutation rate of 0.15666666666666668.
# 2025-04-16 11:13:19,095 - INFO - Gene cds-WP_001099502.1 has no mutations in the population. Skipping this gene.
# 2025-04-16 11:13:19,095 - INFO - Gene gene-SPN23F_RS00915 has a mutation rate of 0.5933333333333334.
# 2025-04-16 11:13:19,096 - INFO - Gene cds-WP_000456639.1 has no mutations in the population. Skipping this gene.
# 2025-04-16 11:13:19,096 - INFO - Gene gene-SPN23F_RS00920 has a mutation rate of 0.6866666666666666.
# 2025-04-16 11:13:19,096 - INFO - Gene cds-WP_000493841.1 has no mutations in the population. Skipping this gene.
# 2025-04-16 11:13:19,097 - INFO - Gene gene-SPN23F_RS00925 has a mutation rate of 0.5833333333333334.
# 2025-04-16 11:13:19,097 - INFO - Gene cds-WP_001284100.1 has no mutations in the population. Skipping this gene.
# 2025-04-16 11:13:19,097 - INFO - Gene gene-SPN23F_RS00930 has a mutation rate of 0.56.
# 2025-04-16 11:13:19,097 - INFO - Gene cds-WP_000271489.1 has no mutations in the population. Skipping this gene.
# 2025-04-16 11:13:19,098 - INFO - Gene gene-SPN23F_RS00935 has a mutation rate of 0.9366666666666666.
# 2025-04-16 11:13:19,098 - INFO - Gene cds-WP_000166600.1 has no mutations in the population. Skipping this gene.
# 2025-04-16 11:13:19,098 - INFO - Gene gene-SPN23F_RS00940 has a mutation rate of 0.75.
# 2025-04-16 11:13:19,099 - INFO - Gene cds-WP_000987429.1 has no mutations in the population. Skipping this gene.
# 2025-04-16 11:13:19,099 - INFO - Gene gene-SPN23F_RS00945 has a mutation rate of 0.76.
# 2025-04-16 11:13:19,099 - INFO - Gene cds-WP_000255102.1 has no mutations in the population. Skipping this gene.
# 2025-04-16 11:13:19,100 - INFO - Gene gene-SPN23F_RS00950 has a mutation rate of 0.25666666666666665.
# 2025-04-16 11:13:19,100 - INFO - Gene cds-WP_000078027.1 has no mutations in the population. Skipping this gene.
# 2025-04-16 11:13:19,100 - INFO - Gene gene-SPN23F_RS00955 has a mutation rate of 0.02666666666666667.
# 2025-04-16 11:13:19,101 - INFO - Gene cds-WP_000815629.1 has no mutations in the population. Skipping this gene.
# 2025-04-16 11:13:19,101 - INFO - Gene gene-SPN23F_RS00960 has a mutation rate of 0.6533333333333333.
# 2025-04-16 11:13:19,101 - INFO - Gene cds-WP_001152894.1 has no mutations in the population. Skipping this gene.
# 2025-04-16 11:13:19,101 - INFO - Gene gene-SPN23F_RS00965 has a mutation rate of 0.4666666666666667.
# 2025-04-16 11:13:19,102 - INFO - Gene cds-WP_001042860.1 has no mutations in the population. Skipping this gene.
# 2025-04-16 11:13:19,102 - INFO - Gene gene-SPN23F_RS00970 has no mutations in the population. Skipping this gene.
# 2025-04-16 11:13:19,102 - INFO - Gene cds-WP_000591165.1 has no mutations in the population. Skipping this gene.
# 2025-04-16 11:13:19,103 - INFO - Gene gene-SPN23F_RS00975 has a mutation rate of 0.47333333333333333.
# 2025-04-16 11:13:19,103 - INFO - Gene cds-WP_000725133.1 has no mutations in the population. Skipping this gene.
# 2025-04-16 11:13:19,103 - INFO - Gene gene-SPN23F_RS00980 has no mutations in the population. Skipping this gene.
# 2025-04-16 11:13:19,103 - INFO - Gene cds-WP_000507059.1 has no mutations in the population. Skipping this gene.
# 2025-04-16 11:13:19,104 - INFO - Gene gene-SPN23F_RS00985 has a mutation rate of 0.08.
# 2025-04-16 11:13:19,104 - INFO - Gene cds-WP_001808830.1 has no mutations in the population. Skipping this gene.
# 2025-04-16 11:13:19,104 - INFO - Gene gene-SPN23F_RS00990 has no mutations in the population. Skipping this gene.
# 2025-04-16 11:13:19,104 - INFO - Gene cds-WP_000017620.1 has no mutations in the population. Skipping this gene.
# 2025-04-16 11:13:19,105 - INFO - Gene gene-SPN23F_RS00995 has a mutation rate of 0.8366666666666667.
# 2025-04-16 11:13:19,105 - INFO - Gene cds-WP_000464336.1 has no mutations in the population. Skipping this gene.
# 2025-04-16 11:13:19,105 - INFO - Gene gene-SPN23F_RS01000 has a mutation rate of 0.15.
# 2025-04-16 11:13:19,106 - INFO - Gene cds-WP_000769490.1 has no mutations in the population. Skipping this gene.
# 2025-04-16 11:13:19,106 - INFO - Gene gene-SPN23F_RS01005 has a mutation rate of 0.15.
# 2025-04-16 11:13:19,106 - INFO - Gene cds-WP_000877334.1 has no mutations in the population. Skipping this gene.
# 2025-04-16 11:13:19,107 - INFO - Gene gene-SPN23F_RS13460 has a mutation rate of 0.02666666666666667.
# 2025-04-16 11:13:19,107 - INFO - Gene cds-WP_000956126.1 has no mutations in the population. Skipping this gene.
# 2025-04-16 11:13:19,107 - INFO - Gene gene-SPN23F_RS01015 has a mutation rate of 0.5766666666666667.
# 2025-04-16 11:13:19,108 - INFO - Gene cds-WP_000118100.1 has no mutations in the population. Skipping this gene.
# 2025-04-16 11:13:19,108 - INFO - Gene gene-SPN23F_RS01020 has a mutation rate of 0.56.
# 2025-04-16 11:13:19,108 - INFO - Gene cds-WP_000560899.1 has no mutations in the population. Skipping this gene.
# 2025-04-16 11:13:19,109 - INFO - Gene gene-SPN23F_RS13465 has a mutation rate of 0.14333333333333334.
# 2025-04-16 11:13:19,109 - INFO - Gene cds-WP_000521619.1 has no mutations in the population. Skipping this gene.
# 2025-04-16 11:13:19,109 - INFO - Gene gene-SPN23F_RS01030 has a mutation rate of 0.6366666666666667.
# 2025-04-16 11:13:19,110 - INFO - Gene cds-WP_000423414.1 has no mutations in the population. Skipping this gene.
# 2025-04-16 11:13:19,110 - INFO - Gene gene-SPN23F_RS01035 has a mutation rate of 0.4866666666666667.
# 2025-04-16 11:13:19,110 - INFO - Gene cds-WP_001064208.1 has no mutations in the population. Skipping this gene.
# 2025-04-16 11:13:19,110 - INFO - Gene gene-SPN23F_RS01040 has a mutation rate of 0.33666666666666667.
# 2025-04-16 11:13:19,111 - INFO - Gene cds-WP_000725993.1 has no mutations in the population. Skipping this gene.
# 2025-04-16 11:13:19,111 - INFO - Gene gene-SPN23F_RS01045 has a mutation rate of 0.013333333333333334.
# 2025-04-16 11:13:19,111 - INFO - Gene cds-WP_001284513.1 has no mutations in the population. Skipping this gene.
# 2025-04-16 11:13:19,112 - INFO - Gene gene-SPN23F_RS01050 has a mutation rate of 0.02.
# 2025-04-16 11:13:19,112 - INFO - Gene cds-WP_000160197.1 has no mutations in the population. Skipping this gene.
# 2025-04-16 11:13:19,112 - INFO - Gene gene-SPN23F_RS01055 has a mutation rate of 0.04666666666666667.
# 2025-04-16 11:13:19,113 - INFO - Gene cds-WP_000024537.1 has no mutations in the population. Skipping this gene.
# 2025-04-16 11:13:19,113 - INFO - Gene gene-SPN23F_RS01060 has a mutation rate of 0.023333333333333334.
# 2025-04-16 11:13:19,113 - INFO - Gene cds-WP_001055347.1 has no mutations in the population. Skipping this gene.
# 2025-04-16 11:13:19,114 - INFO - Gene gene-SPN23F_RS01065 has no mutations in the population. Skipping this gene.
# 2025-04-16 11:13:19,114 - INFO - Gene cds-WP_000512911.1 has no mutations in the population. Skipping this gene.
# 2025-04-16 11:13:19,115 - INFO - Gene gene-SPN23F_RS01070 has no mutations in the population. Skipping this gene.
# 2025-04-16 11:13:19,115 - INFO - Gene cds-WP_000533766.1 has no mutations in the population. Skipping this gene.
# 2025-04-16 11:13:19,115 - INFO - Gene gene-SPN23F_RS01075 has a mutation rate of 0.023333333333333334.
# 2025-04-16 11:13:19,115 - INFO - Gene cds-WP_000818137.1 has no mutations in the population. Skipping this gene.
# 2025-04-16 11:13:19,116 - INFO - Gene gene-SPN23F_RS01080 has no mutations in the population. Skipping this gene.
# 2025-04-16 11:13:19,116 - INFO - Gene cds-WP_000529936.1 has no mutations in the population. Skipping this gene.
# 2025-04-16 11:13:19,116 - INFO - Gene gene-SPN23F_RS01085 has no mutations in the population. Skipping this gene.
# 2025-04-16 11:13:19,117 - INFO - Gene cds-WP_000960946.1 has no mutations in the population. Skipping this gene.
# 2025-04-16 11:13:19,117 - INFO - Gene gene-SPN23F_RS01090 has no mutations in the population. Skipping this gene.
# 2025-04-16 11:13:19,117 - INFO - Gene cds-WP_000772918.1 has no mutations in the population. Skipping this gene.
# 2025-04-16 11:13:19,118 - INFO - Gene gene-SPN23F_RS01095 has no mutations in the population. Skipping this gene.
# 2025-04-16 11:13:19,118 - INFO - Gene cds-WP_000440801.1 has no mutations in the population. Skipping this gene.
# 2025-04-16 11:13:19,118 - INFO - Gene gene-SPN23F_RS01100 has no mutations in the population. Skipping this gene.
# 2025-04-16 11:13:19,118 - INFO - Gene cds-WP_000616545.1 has no mutations in the population. Skipping this gene.
# 2025-04-16 11:13:19,119 - INFO - Gene gene-SPN23F_RS01105 has a mutation rate of 0.013333333333333334.
# 2025-04-16 11:13:19,119 - INFO - Gene cds-WP_000497691.1 has no mutations in the population. Skipping this gene.
# 2025-04-16 11:13:19,119 - INFO - Gene gene-SPN23F_RS01110 has a mutation rate of 0.1.
# 2025-04-16 11:13:19,120 - INFO - Gene cds-WP_000013542.1 has no mutations in the population. Skipping this gene.
# 2025-04-16 11:13:19,120 - INFO - Gene gene-SPN23F_RS01115 has no mutations in the population. Skipping this gene.
# 2025-04-16 11:13:19,120 - INFO - Gene cds-WP_001085703.1 has no mutations in the population. Skipping this gene.
# 2025-04-16 11:13:19,120 - INFO - Gene gene-SPN23F_RS01120 has a mutation rate of 0.03.
# 2025-04-16 11:13:19,121 - INFO - Gene cds-WP_000245505.1 has no mutations in the population. Skipping this gene.
# 2025-04-16 11:13:19,121 - INFO - Gene gene-SPN23F_RS01125 has a mutation rate of 0.42.
# 2025-04-16 11:13:19,121 - INFO - Gene cds-WP_000086630.1 has no mutations in the population. Skipping this gene.
# 2025-04-16 11:13:19,121 - INFO - Gene gene-SPN23F_RS01130 has no mutations in the population. Skipping this gene.
# 2025-04-16 11:13:19,122 - INFO - Gene cds-WP_000624044.1 has no mutations in the population. Skipping this gene.
# 2025-04-16 11:13:19,122 - INFO - Gene gene-SPN23F_RS01135 has a mutation rate of 0.013333333333333334.
# 2025-04-16 11:13:19,122 - INFO - Gene cds-WP_000874201.1 has no mutations in the population. Skipping this gene.
# 2025-04-16 11:13:19,123 - INFO - Gene gene-SPN23F_RS01140 has a mutation rate of 0.13.
# 2025-04-16 11:13:19,123 - INFO - Gene cds-WP_000057241.1 has no mutations in the population. Skipping this gene.
# 2025-04-16 11:13:19,123 - INFO - Gene gene-SPN23F_RS01145 has no mutations in the population. Skipping this gene.
# 2025-04-16 11:13:19,124 - INFO - Gene cds-WP_000766087.1 has no mutations in the population. Skipping this gene.
# 2025-04-16 11:13:19,124 - INFO - Gene gene-SPN23F_RS01150 has a mutation rate of 0.02666666666666667.
# 2025-04-16 11:13:19,124 - INFO - Gene cds-WP_000465397.1 has no mutations in the population. Skipping this gene.
# 2025-04-16 11:13:19,125 - INFO - Gene gene-SPN23F_RS01155 has a mutation rate of 0.35333333333333333.
# 2025-04-16 11:13:19,125 - INFO - Gene cds-WP_001050431.1 has no mutations in the population. Skipping this gene.
# 2025-04-16 11:13:19,126 - INFO - Gene gene-SPN23F_RS01160 has no mutations in the population. Skipping this gene.
# 2025-04-16 11:13:19,126 - INFO - Gene cds-WP_001029883.1 has no mutations in the population. Skipping this gene.
# 2025-04-16 11:13:19,126 - INFO - Gene gene-SPN23F_RS01165 has no mutations in the population. Skipping this gene.
# 2025-04-16 11:13:19,126 - INFO - Gene cds-WP_001808836.1 has no mutations in the population. Skipping this gene.
# 2025-04-16 11:13:19,127 - INFO - Gene gene-SPN23F_RS01170 has a mutation rate of 0.013333333333333334.
# 2025-04-16 11:13:19,127 - INFO - Gene cds-WP_000090781.1 has no mutations in the population. Skipping this gene.
# 2025-04-16 11:13:19,127 - INFO - Gene gene-SPN23F_RS01175 has no mutations in the population. Skipping this gene.
# 2025-04-16 11:13:19,127 - INFO - Gene cds-WP_001118385.1 has no mutations in the population. Skipping this gene.
# 2025-04-16 11:13:19,128 - INFO - Gene gene-SPN23F_RS01180 has a mutation rate of 0.03.
# 2025-04-16 11:13:19,128 - INFO - Gene cds-WP_000568988.1 has no mutations in the population. Skipping this gene.
# 2025-04-16 11:13:19,128 - INFO - Gene gene-SPN23F_RS01185 has a mutation rate of 0.023333333333333334.
# 2025-04-16 11:13:19,128 - INFO - Gene cds-WP_000331493.1 has no mutations in the population. Skipping this gene.
# 2025-04-16 11:13:19,129 - INFO - Gene gene-SPN23F_RS01190 has a mutation rate of 0.19666666666666666.
# 2025-04-16 11:13:19,129 - INFO - Gene cds-WP_000644124.1 has no mutations in the population. Skipping this gene.
# 2025-04-16 11:13:19,129 - INFO - Gene gene-SPN23F_RS01195 has a mutation rate of 0.58.
# 2025-04-16 11:13:19,130 - INFO - Gene cds-WP_000354918.1 has no mutations in the population. Skipping this gene.
# ...
# 2025-04-16 11:13:22,563 - INFO - Gene cds-WP_000388542.1 has no mutations in the population. Skipping this gene.
# 2025-04-16 11:13:22,564 - INFO - Gene gene-SPN23F_RS11310 has a mutation rate of 0.44666666666666666.
# 2025-04-16 11:13:22,564 - INFO - Gene cds-WP_000588548.1 has no mutations in the population. Skipping this gene.
# 2025-04-16 11:13:22,565 - INFO - Gene gene-SPN23F_RS11315 has a mutation rate of 0.5733333333333334.
# 2025-04-16 11:13:22,565 - INFO - Gene cds-WP_000724067.1 has no mutations in the population. Skipping this gene.
# 2025-04-16 11:13:22,566 - INFO - Gene gene-SPN23F_RS11320 has a mutation rate of 0.08666666666666667.
# 2025-04-16 11:13:22,586 - INFO - Gene cds-WP_000950018.1 has no mutations in the population. Skipping this gene.
# 2025-04-16 11:13:22,596 - INFO - Gene gene-SPN23F_RS11325 has a mutation rate of 0.6633333333333333.
# 2025-04-16 11:13:22,597 - INFO - Gene cds-WP_001269488.1 has no mutations in the population. Skipping this gene.
# 2025-04-16 11:13:22,597 - INFO - Gene gene-SPN23F_RS11330 has a mutation rate of 0.02.
# 2025-04-16 11:13:22,597 - INFO - Gene cds-WP_001249309.1 has no mutations in the population. Skipping this gene.
# 2025-04-16 11:13:22,598 - INFO - Gene gene-SPN23F_RS11335 has a mutation rate of 0.16.
# 2025-04-16 11:13:22,598 - INFO - Gene cds-WP_000919857.1 has no mutations in the population. Skipping this gene.
# 2025-04-16 11:13:22,599 - INFO - Gene gene-SPN23F_RS11340 has a mutation rate of 0.03666666666666667.
# 2025-04-16 11:13:22,599 - INFO - Gene cds-WP_000351967.1 has no mutations in the population. Skipping this gene.
# 2025-04-16 11:13:22,599 - INFO - Gene gene-SPN23F_RS11345 has a mutation rate of 0.5566666666666666.
# 2025-04-16 11:13:22,601 - INFO - Gene cds-WP_000969733.1 has no mutations in the population. Skipping this gene.
# 2025-04-16 11:13:22,605 - INFO - Gene gene-SPN23F_RS11350 has a mutation rate of 0.72.
# 2025-04-16 11:13:22,606 - INFO - Gene cds-WP_000066731.1 has no mutations in the population. Skipping this gene.
# 2025-04-16 11:13:22,606 - INFO - Gene gene-SPN23F_RS11355 has no mutations in the population. Skipping this gene.
# 2025-04-16 11:13:22,607 - INFO - Gene cds-WP_000813667.1 has no mutations in the population. Skipping this gene.
# 2025-04-16 11:13:22,607 - INFO - Gene gene-SPN23F_RS11360 has a mutation rate of 0.5366666666666666.
# 2025-04-16 11:13:22,607 - INFO - Gene cds-WP_000071468.1 has no mutations in the population. Skipping this gene.
# 2025-04-16 11:13:22,608 - INFO - Gene cds-SPN23F_RS14035 has no mutations in the population. Skipping this gene.
# 2025-04-16 11:13:22,608 - INFO - Gene gene-SPN23F_RS14235 has a mutation rate of 0.056666666666666664.
# 2025-04-16 11:13:22,609 - INFO - Gene cds-WP_000930581.1 has no mutations in the population. Skipping this gene.
# 2025-04-16 11:13:22,609 - INFO - Gene gene-SPN23F_RS11380 has a mutation rate of 0.20333333333333334.
# 2025-04-16 11:13:22,609 - INFO - Gene cds-WP_001808792.1 has no mutations in the population. Skipping this gene.
# 2025-04-16 11:13:22,610 - INFO - Gene gene-SPN23F_RS11385 has a mutation rate of 0.32.
# 2025-04-16 11:13:22,610 - INFO - Gene cds-WP_001127306.1 has no mutations in the population. Skipping this gene.
# 2025-04-16 11:13:22,610 - INFO - Gene gene-SPN23F_RS11390 has a mutation rate of 0.7.
# 2025-04-16 11:13:22,611 - INFO - Gene cds-WP_000980829.1 has no mutations in the population. Skipping this gene.
# 2025-04-16 11:13:22,611 - INFO - Gene gene-SPN23F_RS11395 has a mutation rate of 0.93.
# 2025-04-16 11:13:22,612 - INFO - Gene cds-WP_000395926.1 has no mutations in the population. Skipping this gene.
# 2025-04-16 11:13:22,612 - INFO - Gene gene-SPN23F_RS11400 has a mutation rate of 0.27666666666666667.
# 2025-04-16 11:13:22,613 - INFO - Gene cds-WP_000076765.1 has no mutations in the population. Skipping this gene.
# 2025-04-16 11:13:22,613 - INFO - Gene gene-SPN23F_RS11405 has a mutation rate of 0.5333333333333333.
# 2025-04-16 11:13:22,613 - INFO - Gene cds-WP_000280548.1 has no mutations in the population. Skipping this gene.
# 2025-04-16 11:13:22,614 - INFO - Gene gene-SPN23F_RS11410 has a mutation rate of 0.62.
# 2025-04-16 11:13:22,614 - INFO - Gene cds-WP_000357847.1 has no mutations in the population. Skipping this gene.
# 2025-04-16 11:13:22,614 - INFO - Gene gene-SPN23F_RS11415 has a mutation rate of 0.4.
# 2025-04-16 11:13:22,615 - INFO - Gene cds-WP_000183311.1 has no mutations in the population. Skipping this gene.
# 2025-04-16 11:13:22,615 - INFO - Gene gene-SPN23F_RS12760 has a mutation rate of 0.9866666666666667.
# 2025-04-16 11:13:22,616 - INFO - Gene cds-WP_000458085.1 has no mutations in the population. Skipping this gene.
# 2025-04-16 11:13:22,616 - INFO - Gene gene-SPN23F_RS11425 has a mutation rate of 0.8233333333333334.
# 2025-04-16 11:13:22,616 - INFO - Gene cds-WP_000241928.1 has no mutations in the population. Skipping this gene.
# 2025-04-16 11:13:22,616 - INFO - Gene gene-SPN23F_RS11430 has a mutation rate of 0.16666666666666666.
# 2025-04-16 11:13:22,617 - INFO - Gene cds-WP_000594667.1 has no mutations in the population. Skipping this gene.
# 2025-04-16 11:13:22,617 - INFO - Gene gene-SPN23F_RS11435 has a mutation rate of 0.42.
# 2025-04-16 11:13:22,618 - INFO - Gene cds-WP_001024075.1 has no mutations in the population. Skipping this gene.
# 2025-04-16 11:13:22,618 - INFO - Gene gene-SPN23F_RS11445 has a mutation rate of 0.7766666666666666.
# 2025-04-16 11:13:22,619 - INFO - Gene cds-WP_001109685.1 has no mutations in the population. Skipping this gene.
# 2025-04-16 11:13:22,619 - INFO - Gene gene-SPN23F_RS11450 has a mutation rate of 0.45666666666666667.
# 2025-04-16 11:13:22,619 - INFO - Gene cds-WP_001211273.1 has no mutations in the population. Skipping this gene.
# 2025-04-16 11:13:22,620 - INFO - Gene gene-SPN23F_RS11455 has a mutation rate of 0.12666666666666668.
# 2025-04-16 11:13:22,620 - INFO - Gene cds-WP_000136224.1 has no mutations in the population. Skipping this gene.
# 2025-04-16 11:13:22,620 - INFO - Gene gene-SPN23F_RS11460 has a mutation rate of 0.07333333333333333.
# 2025-04-16 11:13:22,621 - INFO - Gene cds-WP_000754546.1 has no mutations in the population. Skipping this gene.
# 2025-04-16 11:13:22,621 - INFO - Gene gene-SPN23F_RS11465 has a mutation rate of 0.58.
# 2025-04-16 11:13:22,621 - INFO - Gene cds-WP_001813866.1 has no mutations in the population. Skipping this gene.
# 2025-04-16 11:13:22,622 - INFO - Gene gene-SPN23F_RS11470 has a mutation rate of 0.3466666666666667.
# 2025-04-16 11:13:22,622 - INFO - Gene cds-WP_000647690.1 has no mutations in the population. Skipping this gene.
# 2025-04-16 11:13:22,623 - INFO - Gene gene-SPN23F_RS11475 has a mutation rate of 0.7733333333333333.
# 2025-04-16 11:13:22,623 - INFO - Gene cds-WP_000698561.1 has no mutations in the population. Skipping this gene.
# 2025-04-16 11:13:22,623 - INFO - Gene gene-SPN23F_RS11480 has no mutations in the population. Skipping this gene.
# 2025-04-16 11:13:22,623 - INFO - Gene cds-WP_001278167.1 has no mutations in the population. Skipping this gene.
# 2025-04-16 11:13:22,624 - INFO - Gene gene-SPN23F_RS11485 has a mutation rate of 0.17333333333333334.
# 2025-04-16 11:13:22,624 - INFO - Gene cds-WP_000852486.1 has no mutations in the population. Skipping this gene.
# 2025-04-16 11:13:22,704 - INFO - Gene gene-SPN23F_RS11490 has no mutations in the population. Skipping this gene.
# 2025-04-16 11:13:22,704 - INFO - Gene cds-WP_000864220.1 has no mutations in the population. Skipping this gene.
# 2025-04-16 11:13:22,705 - INFO - Gene gene-SPN23F_RS11495 has a mutation rate of 0.42.
# 2025-04-16 11:13:22,705 - INFO - Gene cds-WP_000715123.1 has no mutations in the population. Skipping this gene.
# 2025-04-16 11:13:22,706 - INFO - Gene gene-SPN23F_RS11500 has a mutation rate of 0.02.
# 2025-04-16 11:13:22,706 - INFO - Gene cds-WP_000599107.1 has no mutations in the population. Skipping this gene.
# 2025-04-16 11:13:22,706 - INFO - Gene gene-SPN23F_RS11505 has a mutation rate of 0.16666666666666666.
# 2025-04-16 11:13:22,707 - INFO - Gene cds-WP_000649974.1 has no mutations in the population. Skipping this gene.
# 2025-04-16 11:13:22,707 - INFO - Gene gene-SPN23F_RS11510 has a mutation rate of 0.9266666666666666.
# 2025-04-16 11:13:22,707 - INFO - Gene cds-WP_000867608.1 has no mutations in the population. Skipping this gene.
# 2025-04-16 11:13:22,708 - INFO - Gene gene-SPN23F_RS11515 has a mutation rate of 0.31666666666666665.
# 2025-04-16 11:13:22,708 - INFO - Gene cds-WP_000395739.1 has no mutations in the population. Skipping this gene.
# 2025-04-16 11:13:22,708 - INFO - Gene gene-SPN23F_RS11520 has a mutation rate of 0.59.
# 2025-04-16 11:13:22,708 - INFO - Gene cds-WP_000029866.1 has no mutations in the population. Skipping this gene.
# 2025-04-16 11:13:22,709 - INFO - Gene cds-SPN23F_RS11525 has no mutations in the population. Skipping this gene.
# 2025-04-16 11:13:22,709 - INFO - Gene cds-SPN23F_RS11530 has no mutations in the population. Skipping this gene.
# 2025-04-16 11:13:22,710 - INFO - Gene gene-SPN23F_RS11535 has a mutation rate of 0.54.
# 2025-04-16 11:13:22,710 - INFO - Gene cds-WP_000973408.1 has no mutations in the population. Skipping this gene.
# 2025-04-16 11:13:22,710 - INFO - Gene gene-SPN23F_RS11540 has a mutation rate of 0.18333333333333332.
# 2025-04-16 11:13:22,711 - INFO - Gene cds-WP_000808063.1 has no mutations in the population. Skipping this gene.
# 2025-04-16 11:13:22,711 - INFO - Gene gene-SPN23F_RS11545 has a mutation rate of 0.28.
# 2025-04-16 11:13:22,711 - INFO - Gene cds-WP_000268466.1 has no mutations in the population. Skipping this gene.
# 2025-04-16 11:13:22,711 - INFO - Gene gene-SPN23F_RS11550 has a mutation rate of 0.20666666666666667.
# 2025-04-16 11:13:22,712 - INFO - Gene cds-WP_000727012.1 has no mutations in the population. Skipping this gene.
# 2025-04-16 11:13:22,712 - INFO - Gene gene-SPN23F_RS11555 has a mutation rate of 0.17.
# 2025-04-16 11:13:22,712 - INFO - Gene cds-WP_001249454.1 has no mutations in the population. Skipping this gene.
# 2025-04-16 11:13:22,713 - INFO - Gene gene-SPN23F_RS11560 has a mutation rate of 0.12.
# 2025-04-16 11:13:22,713 - INFO - Gene cds-WP_001078983.1 has no mutations in the population. Skipping this gene.
# 2025-04-16 11:13:22,713 - INFO - Gene gene-SPN23F_RS11565 has a mutation rate of 0.11.
# 2025-04-16 11:13:22,713 - INFO - Gene cds-WP_000377893.1 has no mutations in the population. Skipping this gene.
# 2025-04-16 11:13:22,714 - INFO - Gene gene-SPN23F_RS11570 has a mutation rate of 0.2633333333333333.
# 2025-04-16 11:13:22,714 - INFO - Gene cds-WP_000510412.1 has no mutations in the population. Skipping this gene.
# 2025-04-16 11:13:22,714 - INFO - Gene gene-SPN23F_RS11575 has a mutation rate of 0.36333333333333334.
# 2025-04-16 11:13:22,714 - INFO - Gene cds-WP_000835715.1 has no mutations in the population. Skipping this gene.
# 2025-04-16 11:13:22,715 - INFO - Gene gene-SPN23F_RS11580 has a mutation rate of 0.25666666666666665.
# 2025-04-16 11:13:22,715 - INFO - Gene cds-WP_000712132.1 has no mutations in the population. Skipping this gene.
# 2025-04-16 11:13:22,715 - INFO - Gene gene-SPN23F_RS11585 has a mutation rate of 0.17666666666666667.
# 2025-04-16 11:13:22,716 - INFO - Gene cds-WP_001227958.1 has no mutations in the population. Skipping this gene.
# 2025-04-16 11:13:22,716 - INFO - Gene gene-SPN23F_RS11590 has a mutation rate of 0.86.
# 2025-04-16 11:13:22,716 - INFO - Gene cds-WP_000170191.1 has no mutations in the population. Skipping this gene.
# 2025-04-16 11:13:22,717 - INFO - Gene gene-SPN23F_RS11595 has a mutation rate of 0.6966666666666667.
# 2025-04-16 11:13:22,717 - INFO - Gene cds-WP_000424267.1 has no mutations in the population. Skipping this gene.
# 2025-04-16 11:13:22,718 - INFO - Gene gene-SPN23F_RS11600 has a mutation rate of 0.17666666666666667.
# 2025-04-16 11:13:22,718 - INFO - Gene cds-WP_000455903.1 has no mutations in the population. Skipping this gene.
# 2025-04-16 11:13:22,718 - INFO - Gene gene-SPN23F_RS11605 has a mutation rate of 0.34.
# 2025-04-16 11:13:22,719 - INFO - Gene cds-WP_000266669.1 has no mutations in the population. Skipping this gene.
# 2025-04-16 11:13:22,719 - INFO - Gene gene-SPN23F_RS11610 has a mutation rate of 0.15.
# 2025-04-16 11:13:22,719 - INFO - Gene cds-WP_000073428.1 has no mutations in the population. Skipping this gene.
# 2025-04-16 11:13:22,720 - INFO - Gene gene-SPN23F_RS11615 has a mutation rate of 0.07666666666666666.
# 2025-04-16 11:13:22,720 - INFO - Gene cds-WP_000165444.1 has no mutations in the population. Skipping this gene.
# 2025-04-16 11:13:22,720 - INFO - Gene gene-SPN23F_RS11620 has a mutation rate of 0.03.
# 2025-04-16 11:13:22,721 - INFO - Gene cds-WP_000958769.1 has no mutations in the population. Skipping this gene.
# 2025-04-16 11:13:22,721 - INFO - Gene gene-SPN23F_RS11625 has a mutation rate of 0.85.
# 2025-04-16 11:13:22,721 - INFO - Gene cds-WP_000834663.1 has no mutations in the population. Skipping this gene.
# 2025-04-16 11:13:22,722 - INFO - Gene cds-SPN23F_RS14040 has no mutations in the population. Skipping this gene.
# 2025-04-16 11:13:22,722 - INFO - Gene gene-SPN23F_RS11645 has a mutation rate of 0.16666666666666666.
# 2025-04-16 11:13:22,722 - INFO - Gene cds-WP_001158266.1 has no mutations in the population. Skipping this gene.
# 2025-04-16 11:13:22,723 - INFO - Gene gene-SPN23F_RS11650 has no mutations in the population. Skipping this gene.
# 2025-04-16 11:13:22,723 - INFO - Gene gene-SPN23F_RS11655 has no mutations in the population. Skipping this gene.
# 2025-04-16 11:13:22,723 - INFO - Gene gene-SPN23F_RS11660 has a mutation rate of 0.21.
# 2025-04-16 11:13:22,724 - INFO - Gene cds-WP_000866065.1 has no mutations in the population. Skipping this gene.
# 2025-04-16 11:13:22,724 - INFO - Gene gene-SPN23F_RS11665 has a mutation rate of 0.86.
# 2025-04-16 11:13:22,724 - INFO - Gene cds-WP_000364843.1 has no mutations in the population. Skipping this gene.
# 2025-04-16 11:13:22,725 - INFO - Gene gene-SPN23F_RS11670 has a mutation rate of 0.023333333333333334.
# 2025-04-16 11:13:22,725 - INFO - Gene cds-WP_000799694.1 has no mutations in the population. Skipping this gene.
# 2025-04-16 11:13:22,726 - INFO - Gene gene-SPN23F_RS11675 has no mutations in the population. Skipping this gene.
# 2025-04-16 11:13:22,726 - INFO - Gene gene-SPN23F_RS11680 has a mutation rate of 0.04666666666666667.
# 2025-04-16 11:13:22,726 - INFO - Gene cds-WP_000695929.1 has no mutations in the population. Skipping this gene.
# 2025-04-16 11:13:22,727 - INFO - Gene gene-SPN23F_RS11685 has a mutation rate of 0.30666666666666664.
# 2025-04-16 11:13:22,727 - INFO - Gene cds-WP_000681598.1 has no mutations in the population. Skipping this gene.
# 2025-04-16 11:13:22,727 - INFO - Gene gene-SPN23F_RS11690 has a mutation rate of 0.25333333333333335.
# 2025-04-16 11:13:22,727 - INFO - Gene cds-WP_000410383.1 has no mutations in the population. Skipping this gene.
# 2025-04-16 11:13:22,728 - INFO - Integrating 1775 genes to run GWAS on pyseer.
# 2025-04-16 11:13:22,729 - INFO - Skipped 2536 genes with no mutations.
# 2025-04-16 11:13:22,730 - INFO - Converted mutation summary file pyseer_dataset/gene_mutation_summary.txt to numeric format and saved as pyseer_dataset/gene_mutation_summary_filtered_numeric.txt.
# 2025-04-16 11:13:22,731 - INFO - Running pyseer with command: pyseer --lmm --phenotypes pyseer_dataset/resistances.subset.txt --similarity pyseer_dataset/phylogeny_distances.tsv --pres pyseer_dataset/gene_mutation_summary_filtered_numeric.txt > pyseer_dataset/pyseer_results.txt
# Read 300 phenotypes
# Detected binary phenotype
# Setting up LMM
# Similarity matrix has dimension (616, 616)
# Analysing 300 samples found in both phenotype and similarity matrix
# h^2 = 0.87
# 1775 loaded variants
# 19 pre-filtered variants
# 1756 tested variants
# 1756 printed variants
# 2025-04-16 11:13:25,331 - INFO - Pyseer run completed successfully.
# 2025-04-16 11:13:25,332 - INFO - GWAS results are saved in pyseer_dataset
# 2025-04-16 11:13:25,332 - INFO - Script completed in 0 hours, 0 minutes, and 6 seconds.
# 2025-04-16 11:13:25,333 - INFO - Finished running pyseer.
# 2025-04-16 11:13:25,333 - INFO - GWAS analysis completed.

# %% [markdown]
# ## **Future Direction**
#
# 1. Add statistical significance threshold to the GWAS result:
# - The Bonferroni threshold depends on how many genes are tested.
#
# 2. Add a plotting module:
# - Input: `gwas_result.txt`
# - Output:
#     1. Q-Q plot: `gwas_result.qq.png`
#     2. manhattan plot: `gwas_result.man.png`
# - Functionality: Plot Q-Q plots and manhattan plots.
