# %% [markdown]
# # **Mutated-gene Genome-Wide Association Study (MugGWAS)**

# %% [markdown]
# MugGWAS identifies potential causal mutations for phenotypic change through testing associations between mutated genes and phenotypic values. The tool aims to

# %% [markdown]
# ### **Prerquisites**
# MugGWAS uses the external tool-**ANNOVAR** to annotate variants. Please follow the [instructions](http://annovar.openbioinformatics.org/en/latest/) to download ANNOVAR (registration is required), and specify the path to ANNOVAR scripts for MugGWAS. More instructions are provided below.
#
# This package uses the fixed effect model in  [`pyseer`](https://pyseer.readthedocs.io/en/master/index.html) for association analysis. So, the users have to install and match the [requirements](https://pyseer.readthedocs.io/en/master/installation.html#prerequisites) of `pyseer`.

# %% [markdown]
# ### **Installation**
# Clone this repository from GitHub in the terminal:
#
# `git clone https://github.com/lyuchengmarvin/MugGWAS.git`

# %% [markdown]
# ### **Build Environment**
# Build an environment based on an environment.yaml file to satisfy software prerequisites and ensure applicability.
#
# `conda env create --name muggwas --file envs/environment.yaml`
#
# Activate envrionment before use each time:
#
# `conda activate muggwas`
#
# Deactivate after use:
#
# `conda deactivate`

# %% [markdown]
# ### **Install MugGWAS**
#
# `pip install -i https://test.pypi.org/simple/ MugGWAS`

# %% [markdown]
# ### **Tutaorial**
# Steps:
# 1. Annotate variants
# 2. Build gene mutation table
# 3. Estimate population structure
# 4. GWAS with pyseer
# 5. Plot GWAS result

# %% [markdown]
# #### **Annotate variants with ANNOVAR**
#
# We will use the external tool ANNOVAR and annotate the variants from vcf files. Although one vcf file should contain the variant information for multiple samples, ANNOVAR annotates samples iteratively and create an annotation file per sample.
#
# This tool also assumed that users will build their customized database for their none-model organisms, so a genome annotation `<ref_prefix.gff3>` and a genome fasta file `<ref_prefix>.fna` are required and placed in the directory `<ref_prefix>/`. The database will utilize the tool `gff3ToGenePred` to build the database, which was also built when users created their conda environments.
#
#
# **Annotation workflow**
#
# 1. **Make input files**:
#     - Input: a VCF file `vcf_prefix.vcf` (with multiple samples)
#     - Convert VCF to ANNOVAR input format `vcf_prefix.<sample_name>.avinput`
#     - Store in `/path_to_vcf/annovar_files/`
# 2. **Build database**:
#     - Input: `ref_prefix.gff3` and `ref_prefix.fna` in `db_dir/`
#     - Build customized database: `ref_prefix_refGene.txt` and `ref_prefix_refGeneMrna.fa`
# 3. **Annotate variants with ANNOVAR**:
#     - Output1: `vcf_prefix.<sample_name>.avinput.variant_function` infer mutation position on a gene.
#     - Output2: `vcf_prefix.<sample_name>.avinput.exonic_variant_function` infer mutation effects on translation, namely synonymous, nonsynonymous, stop codon gain, or stop codon loss.

# %%
from muggwas import run_annovar

## User inputs
# the path to the ANNOVAR installation
annovar_dir = '../annovar/'
# the directory where the reference files are located
db_dir = 'data/LE18_22/'
# path to the vcf file
input_dir = 'data/graz_LE.snp.vcf'
# output prefix or the converted annovar input file
vcf_prefix = 'graz_LE'
# output prefix for the annovar database
ref_prefix = 'LE18_22'

## Run ANNOVAR
run_annovar(
    annovar_dir=annovar_dir,
    db_dir=db_dir,
    input_dir=input_dir,
    vcf_prefix=vcf_prefix,
    ref_prefix=ref_prefix
)
# Out:
# Converting VCF file to annovar input format...
# NOTICE: output files will be written to data/annovar_files/graz_LE.<samplename>.avinput
# NOTICE: Finished reading 21826 lines from VCF file
# NOTICE: A total of 21154 locus in VCF file passed QC threshold, representing 21154 SNPs (13997 transitions and 7157 transversions) and 0 indels/substitutions
# NOTICE: Finished writing 90239 SNP genotypes (61175 transitions and 29064 transversions) and 0 indels/substitutions for 22 samples
# The VCF file has been converted and saved to data/annovar_files/.
# NOTICE: Reading region file data/LE18_22/LE18_22_refGene.txt ... Done with 5095 regions from 613 chromosomes
# NOTICE: Finished reading 642 sequences from data/LE18_22/LE18_22.fna
# NOTICE: Finished reading 642 sequences from data/LE18_22/LE18_22.fna
# NOTICE: Finished reading 642 sequences from data/LE18_22/LE18_22.fna
# NOTICE: Finished reading 642 sequences from data/LE18_22/LE18_22.fna
# NOTICE: Finished reading 642 sequences from data/LE18_22/LE18_22.fna
# NOTICE: Finished reading 642 sequences from data/LE18_22/LE18_22.fna
# NOTICE: Finished reading 642 sequences from data/LE18_22/LE18_22.fna
# NOTICE: Finished reading 642 sequences from data/LE18_22/LE18_22.fna
# NOTICE: Finished reading 642 sequences from data/LE18_22/LE18_22.fna
# NOTICE: Finished reading 642 sequences from data/LE18_22/LE18_22.fna
# NOTICE: Finished reading 642 sequences from data/LE18_22/LE18_22.fna
# NOTICE: Finished reading 642 sequences from data/LE18_22/LE18_22.fna
# NOTICE: Finished reading 642 sequences from data/LE18_22/LE18_22.fna
# NOTICE: Finished reading 642 sequences from data/LE18_22/LE18_22.fna
# NOTICE: Finished reading 642 sequences from data/LE18_22/LE18_22.fna
# NOTICE: Finished reading 642 sequences from data/LE18_22/LE18_22.fna
# NOTICE: Finished reading 642 sequences from data/LE18_22/LE18_22.fna
# NOTICE: Finished reading 642 sequences from data/LE18_22/LE18_22.fna
# NOTICE: Finished reading 642 sequences from data/LE18_22/LE18_22.fna
# NOTICE: Finished reading 642 sequences from data/LE18_22/LE18_22.fna
# NOTICE: Finished reading 642 sequences from data/LE18_22/LE18_22.fna
# NOTICE: Finished reading 642 sequences from data/LE18_22/LE18_22.fna
# NOTICE: Finished reading 642 sequences from data/LE18_22/LE18_22.fna
# NOTICE: Finished reading 642 sequences from data/LE18_22/LE18_22.fna
# NOTICE: Finished reading 642 sequences from data/LE18_22/LE18_22.fna
# NOTICE: Finished reading 642 sequences from data/LE18_22/LE18_22.fna
# NOTICE: Finished reading 642 sequences from data/LE18_22/LE18_22.fna
# NOTICE: Finished reading 642 sequences from data/LE18_22/LE18_22.fna
# NOTICE: Finished reading 642 sequences from data/LE18_22/LE18_22.fna
# NOTICE: Finished reading 642 sequences from data/LE18_22/LE18_22.fna
# NOTICE: Finished reading 642 sequences from data/LE18_22/LE18_22.fna
# NOTICE: Finished reading 642 sequences from data/LE18_22/LE18_22.fna
# NOTICE: Finished reading 642 sequences from data/LE18_22/LE18_22.fna
# NOTICE: Finished reading 642 sequences from data/LE18_22/LE18_22.fna
# NOTICE: Finished reading 642 sequences from data/LE18_22/LE18_22.fna
# NOTICE: Finished reading 642 sequences from data/LE18_22/LE18_22.fna
# NOTICE: Finished reading 642 sequences from data/LE18_22/LE18_22.fna
# NOTICE: Finished reading 642 sequences from data/LE18_22/LE18_22.fna
# NOTICE: Finished reading 642 sequences from data/LE18_22/LE18_22.fna
# NOTICE: Finished reading 642 sequences from data/LE18_22/LE18_22.fna
# NOTICE: Finished reading 642 sequences from data/LE18_22/LE18_22.fna
# NOTICE: Finished reading 642 sequences from data/LE18_22/LE18_22.fna
# NOTICE: Finished reading 642 sequences from data/LE18_22/LE18_22.fna
# NOTICE: Finished reading 642 sequences from data/LE18_22/LE18_22.fna
# NOTICE: Finished reading 642 sequences from data/LE18_22/LE18_22.fna
# NOTICE: Finished reading 642 sequences from data/LE18_22/LE18_22.fna
# NOTICE: Finished reading 642 sequences from data/LE18_22/LE18_22.fna
# NOTICE: Finished reading 642 sequences from data/LE18_22/LE18_22.fna
# NOTICE: Finished reading 642 sequences from data/LE18_22/LE18_22.fna
# NOTICE: Finished reading 642 sequences from data/LE18_22/LE18_22.fna
# NOTICE: Finished reading 642 sequences from data/LE18_22/LE18_22.fna
# NOTICE: Finished reading 642 sequences from data/LE18_22/LE18_22.fna
# NOTICE: Finished reading 642 sequences from data/LE18_22/LE18_22.fna
# NOTICE: Finished reading 642 sequences from data/LE18_22/LE18_22.fna
# NOTICE: Finished reading 642 sequences from data/LE18_22/LE18_22.fna
# NOTICE: Finished reading 642 sequences from data/LE18_22/LE18_22.fna
# NOTICE: Finished reading 642 sequences from data/LE18_22/LE18_22.fna
# NOTICE: Finished reading 642 sequences from data/LE18_22/LE18_22.fna
# NOTICE: Finished reading 642 sequences from data/LE18_22/LE18_22.fna
# NOTICE: Finished reading 642 sequences from data/LE18_22/LE18_22.fna
# NOTICE: Finished reading 642 sequences from data/LE18_22/LE18_22.fna
# NOTICE: Finished reading 642 sequences from data/LE18_22/LE18_22.fna
# NOTICE: Finished reading 642 sequences from data/LE18_22/LE18_22.fna
# NOTICE: Finished reading 642 sequences from data/LE18_22/LE18_22.fna
# NOTICE: Finished reading 642 sequences from data/LE18_22/LE18_22.fna
# NOTICE: Finished reading 642 sequences from data/LE18_22/LE18_22.fna
# NOTICE: Finished reading 642 sequences from data/LE18_22/LE18_22.fna
# NOTICE: Finished reading 642 sequences from data/LE18_22/LE18_22.fna
# NOTICE: Finished reading 642 sequences from data/LE18_22/LE18_22.fna
# NOTICE: Finished reading 642 sequences from data/LE18_22/LE18_22.fna
# NOTICE: Finished reading 642 sequences from data/LE18_22/LE18_22.fna
# NOTICE: Finished reading 642 sequences from data/LE18_22/LE18_22.fna
# NOTICE: Finished reading 642 sequences from data/LE18_22/LE18_22.fna
# NOTICE: Finished reading 642 sequences from data/LE18_22/LE18_22.fna
# NOTICE: Finished reading 642 sequences from data/LE18_22/LE18_22.fna
# NOTICE: Finished reading 642 sequences from data/LE18_22/LE18_22.fna
# NOTICE: Finished reading 642 sequences from data/LE18_22/LE18_22.fna
# NOTICE: Finished reading 642 sequences from data/LE18_22/LE18_22.fna
# NOTICE: Finished reading 642 sequences from data/LE18_22/LE18_22.fna
# NOTICE: Finished reading 642 sequences from data/LE18_22/LE18_22.fna
# NOTICE: Finished reading 642 sequences from data/LE18_22/LE18_22.fna
# NOTICE: Finished reading 642 sequences from data/LE18_22/LE18_22.fna
# NOTICE: Finished reading 642 sequences from data/LE18_22/LE18_22.fna
# NOTICE: Finished reading 642 sequences from data/LE18_22/LE18_22.fna
# NOTICE: Finished reading 642 sequences from data/LE18_22/LE18_22.fna
# NOTICE: Finished reading 642 sequences from data/LE18_22/LE18_22.fna
# NOTICE: Finished reading 642 sequences from data/LE18_22/LE18_22.fna
# NOTICE: Finished reading 642 sequences from data/LE18_22/LE18_22.fna
# NOTICE: Finished reading 642 sequences from data/LE18_22/LE18_22.fna
# NOTICE: Finished reading 642 sequences from data/LE18_22/LE18_22.fna
# NOTICE: Finished reading 642 sequences from data/LE18_22/LE18_22.fna
# NOTICE: Finished reading 642 sequences from data/LE18_22/LE18_22.fna
# NOTICE: Finished reading 642 sequences from data/LE18_22/LE18_22.fna
# NOTICE: Finished reading 642 sequences from data/LE18_22/LE18_22.fna
# NOTICE: Finished reading 642 sequences from data/LE18_22/LE18_22.fna
# NOTICE: Finished reading 642 sequences from data/LE18_22/LE18_22.fna
# NOTICE: Finished reading 642 sequences from data/LE18_22/LE18_22.fna
# NOTICE: Finished reading 642 sequences from data/LE18_22/LE18_22.fna
# NOTICE: Finished reading 642 sequences from data/LE18_22/LE18_22.fna
# NOTICE: Finished reading 642 sequences from data/LE18_22/LE18_22.fna
# NOTICE: Finished reading 642 sequences from data/LE18_22/LE18_22.fna
# NOTICE: Finished reading 642 sequences from data/LE18_22/LE18_22.fna
# NOTICE: Finished reading 642 sequences from data/LE18_22/LE18_22.fna
# NOTICE: Finished reading 642 sequences from data/LE18_22/LE18_22.fna
# NOTICE: Finished reading 642 sequences from data/LE18_22/LE18_22.fna
# NOTICE: Finished reading 642 sequences from data/LE18_22/LE18_22.fna
# NOTICE: Finished reading 642 sequences from data/LE18_22/LE18_22.fna
# NOTICE: Finished reading 642 sequences from data/LE18_22/LE18_22.fna
# NOTICE: Finished reading 642 sequences from data/LE18_22/LE18_22.fna
# NOTICE: Finished reading 642 sequences from data/LE18_22/LE18_22.fna
# NOTICE: Finished reading 642 sequences from data/LE18_22/LE18_22.fna
# NOTICE: Finished reading 642 sequences from data/LE18_22/LE18_22.fna
# NOTICE: Finished reading 642 sequences from data/LE18_22/LE18_22.fna
# NOTICE: Finished reading 642 sequences from data/LE18_22/LE18_22.fna
# NOTICE: Finished reading 642 sequences from data/LE18_22/LE18_22.fna
# NOTICE: Finished reading 642 sequences from data/LE18_22/LE18_22.fna
# NOTICE: Finished reading 642 sequences from data/LE18_22/LE18_22.fna
# NOTICE: Finished reading 642 sequences from data/LE18_22/LE18_22.fna
# NOTICE: Finished reading 642 sequences from data/LE18_22/LE18_22.fna
# NOTICE: Finished reading 642 sequences from data/LE18_22/LE18_22.fna
# NOTICE: Finished reading 642 sequences from data/LE18_22/LE18_22.fna
# NOTICE: Finished reading 642 sequences from data/LE18_22/LE18_22.fna
# NOTICE: Finished reading 642 sequences from data/LE18_22/LE18_22.fna
# NOTICE: Finished reading 642 sequences from data/LE18_22/LE18_22.fna
# NOTICE: Finished reading 642 sequences from data/LE18_22/LE18_22.fna
# NOTICE: Finished reading 642 sequences from data/LE18_22/LE18_22.fna
# NOTICE: Finished reading 642 sequences from data/LE18_22/LE18_22.fna
# NOTICE: Finished reading 642 sequences from data/LE18_22/LE18_22.fna
# NOTICE: Finished reading 642 sequences from data/LE18_22/LE18_22.fna
# NOTICE: Finished reading 642 sequences from data/LE18_22/LE18_22.fna
# NOTICE: Finished reading 642 sequences from data/LE18_22/LE18_22.fna
# NOTICE: Finished reading 642 sequences from data/LE18_22/LE18_22.fna
# NOTICE: Finished reading 642 sequences from data/LE18_22/LE18_22.fna
# NOTICE: Finished reading 642 sequences from data/LE18_22/LE18_22.fna
# NOTICE: Finished reading 642 sequences from data/LE18_22/LE18_22.fna
# NOTICE: Finished reading 642 sequences from data/LE18_22/LE18_22.fna
# NOTICE: Finished reading 642 sequences from data/LE18_22/LE18_22.fna
# NOTICE: Finished reading 642 sequences from data/LE18_22/LE18_22.fna
# NOTICE: Finished reading 642 sequences from data/LE18_22/LE18_22.fna
# NOTICE: Finished reading 642 sequences from data/LE18_22/LE18_22.fna
# NOTICE: Finished reading 642 sequences from data/LE18_22/LE18_22.fna
# NOTICE: Finished reading 642 sequences from data/LE18_22/LE18_22.fna
# NOTICE: Finished reading 642 sequences from data/LE18_22/LE18_22.fna
# NOTICE: Finished reading 642 sequences from data/LE18_22/LE18_22.fna
# NOTICE: Finished reading 642 sequences from data/LE18_22/LE18_22.fna
# NOTICE: Finished reading 642 sequences from data/LE18_22/LE18_22.fna
# NOTICE: Finished reading 642 sequences from data/LE18_22/LE18_22.fna
# NOTICE: Finished reading 642 sequences from data/LE18_22/LE18_22.fna
# NOTICE: Finished reading 642 sequences from data/LE18_22/LE18_22.fna
# NOTICE: Finished reading 642 sequences from data/LE18_22/LE18_22.fna
# NOTICE: Finished reading 642 sequences from data/LE18_22/LE18_22.fna
# NOTICE: Finished reading 642 sequences from data/LE18_22/LE18_22.fna
# NOTICE: Finished reading 642 sequences from data/LE18_22/LE18_22.fna
# NOTICE: Finished reading 642 sequences from data/LE18_22/LE18_22.fna
# NOTICE: Finished reading 642 sequences from data/LE18_22/LE18_22.fna
# NOTICE: Finished reading 642 sequences from data/LE18_22/LE18_22.fna
# NOTICE: Finished reading 642 sequences from data/LE18_22/LE18_22.fna
# NOTICE: Finished reading 642 sequences from data/LE18_22/LE18_22.fna
# NOTICE: Finished reading 642 sequences from data/LE18_22/LE18_22.fna
# NOTICE: Finished reading 642 sequences from data/LE18_22/LE18_22.fna
# NOTICE: Finished reading 642 sequences from data/LE18_22/LE18_22.fna
# NOTICE: Finished reading 642 sequences from data/LE18_22/LE18_22.fna
# NOTICE: Finished reading 642 sequences from data/LE18_22/LE18_22.fna
# NOTICE: Finished reading 642 sequences from data/LE18_22/LE18_22.fna
# NOTICE: Finished reading 642 sequences from data/LE18_22/LE18_22.fna
# NOTICE: Finished reading 642 sequences from data/LE18_22/LE18_22.fna
# NOTICE: Finished reading 642 sequences from data/LE18_22/LE18_22.fna
# NOTICE: Finished reading 642 sequences from data/LE18_22/LE18_22.fna
# NOTICE: Finished reading 642 sequences from data/LE18_22/LE18_22.fna
# NOTICE: Finished reading 642 sequences from data/LE18_22/LE18_22.fna
# NOTICE: Finished reading 642 sequences from data/LE18_22/LE18_22.fna
# NOTICE: Finished reading 642 sequences from data/LE18_22/LE18_22.fna
# NOTICE: Finished reading 642 sequences from data/LE18_22/LE18_22.fna
# NOTICE: Finished reading 642 sequences from data/LE18_22/LE18_22.fna
# NOTICE: Finished reading 642 sequences from data/LE18_22/LE18_22.fna
# NOTICE: Finished reading 642 sequences from data/LE18_22/LE18_22.fna
# NOTICE: Finished reading 642 sequences from data/LE18_22/LE18_22.fna
# NOTICE: Finished reading 642 sequences from data/LE18_22/LE18_22.fna
# NOTICE: Finished reading 642 sequences from data/LE18_22/LE18_22.fna
# NOTICE: Finished reading 642 sequences from data/LE18_22/LE18_22.fna
# NOTICE: Finished reading 642 sequences from data/LE18_22/LE18_22.fna
# NOTICE: Finished reading 642 sequences from data/LE18_22/LE18_22.fna
# NOTICE: Finished reading 642 sequences from data/LE18_22/LE18_22.fna
# NOTICE: Finished reading 642 sequences from data/LE18_22/LE18_22.fna
# NOTICE: Finished reading 642 sequences from data/LE18_22/LE18_22.fna
# NOTICE: Finished reading 642 sequences from data/LE18_22/LE18_22.fna
# NOTICE: Finished reading 642 sequences from data/LE18_22/LE18_22.fna
# NOTICE: Finished reading 642 sequences from data/LE18_22/LE18_22.fna
# NOTICE: Finished reading 642 sequences from data/LE18_22/LE18_22.fna
# NOTICE: Finished reading 642 sequences from data/LE18_22/LE18_22.fna
# NOTICE: Finished reading 642 sequences from data/LE18_22/LE18_22.fna
# NOTICE: Finished reading 642 sequences from data/LE18_22/LE18_22.fna
# NOTICE: Finished reading 642 sequences from data/LE18_22/LE18_22.fna
# NOTICE: Finished reading 642 sequences from data/LE18_22/LE18_22.fna
# NOTICE: Finished reading 642 sequences from data/LE18_22/LE18_22.fna
# NOTICE: Finished reading 642 sequences from data/LE18_22/LE18_22.fna
# NOTICE: Finished reading 642 sequences from data/LE18_22/LE18_22.fna
# NOTICE: Finished reading 642 sequences from data/LE18_22/LE18_22.fna
# NOTICE: Finished reading 642 sequences from data/LE18_22/LE18_22.fna
# NOTICE: Finished reading 642 sequences from data/LE18_22/LE18_22.fna
# NOTICE: Finished reading 642 sequences from data/LE18_22/LE18_22.fna
# NOTICE: Finished reading 642 sequences from data/LE18_22/LE18_22.fna
# NOTICE: Finished reading 642 sequences from data/LE18_22/LE18_22.fna
# NOTICE: Finished reading 642 sequences from data/LE18_22/LE18_22.fna
# NOTICE: Finished reading 642 sequences from data/LE18_22/LE18_22.fna
# NOTICE: Finished reading 642 sequences from data/LE18_22/LE18_22.fna
# NOTICE: Finished reading 642 sequences from data/LE18_22/LE18_22.fna
# NOTICE: Finished reading 642 sequences from data/LE18_22/LE18_22.fna
# NOTICE: Finished reading 642 sequences from data/LE18_22/LE18_22.fna
# NOTICE: Finished reading 642 sequences from data/LE18_22/LE18_22.fna
# NOTICE: Finished reading 642 sequences from data/LE18_22/LE18_22.fna
# NOTICE: Finished reading 642 sequences from data/LE18_22/LE18_22.fna
# NOTICE: Finished reading 642 sequences from data/LE18_22/LE18_22.fna
# NOTICE: Finished reading 642 sequences from data/LE18_22/LE18_22.fna
# NOTICE: Finished reading 642 sequences from data/LE18_22/LE18_22.fna
# NOTICE: Finished reading 642 sequences from data/LE18_22/LE18_22.fna
# NOTICE: Finished reading 642 sequences from data/LE18_22/LE18_22.fna
# NOTICE: Finished reading 642 sequences from data/LE18_22/LE18_22.fna
# NOTICE: Finished reading 642 sequences from data/LE18_22/LE18_22.fna
# NOTICE: Finished reading 642 sequences from data/LE18_22/LE18_22.fna
# NOTICE: Finished reading 642 sequences from data/LE18_22/LE18_22.fna
# NOTICE: Finished reading 642 sequences from data/LE18_22/LE18_22.fna
# NOTICE: Finished reading 642 sequences from data/LE18_22/LE18_22.fna
# NOTICE: Finished reading 642 sequences from data/LE18_22/LE18_22.fna
# NOTICE: Finished reading 642 sequences from data/LE18_22/LE18_22.fna
# NOTICE: Finished reading 642 sequences from data/LE18_22/LE18_22.fna
# NOTICE: Finished reading 642 sequences from data/LE18_22/LE18_22.fna
# NOTICE: Finished reading 642 sequences from data/LE18_22/LE18_22.fna
# NOTICE: Finished reading 642 sequences from data/LE18_22/LE18_22.fna
# NOTICE: Finished reading 642 sequences from data/LE18_22/LE18_22.fna
# NOTICE: Finished reading 642 sequences from data/LE18_22/LE18_22.fna
# NOTICE: Finished reading 642 sequences from data/LE18_22/LE18_22.fna
# NOTICE: Finished reading 642 sequences from data/LE18_22/LE18_22.fna
# NOTICE: Finished reading 642 sequences from data/LE18_22/LE18_22.fna
# NOTICE: Finished reading 642 sequences from data/LE18_22/LE18_22.fna
# NOTICE: Finished reading 642 sequences from data/LE18_22/LE18_22.fna
# NOTICE: Finished reading 642 sequences from data/LE18_22/LE18_22.fna
# NOTICE: Finished reading 642 sequences from data/LE18_22/LE18_22.fna
# NOTICE: Finished reading 642 sequences from data/LE18_22/LE18_22.fna
# NOTICE: Finished reading 642 sequences from data/LE18_22/LE18_22.fna
# NOTICE: Finished reading 642 sequences from data/LE18_22/LE18_22.fna
# NOTICE: Finished reading 642 sequences from data/LE18_22/LE18_22.fna
# NOTICE: Finished reading 642 sequences from data/LE18_22/LE18_22.fna
# NOTICE: Finished reading 642 sequences from data/LE18_22/LE18_22.fna
# NOTICE: Finished reading 642 sequences from data/LE18_22/LE18_22.fna
# NOTICE: Finished reading 642 sequences from data/LE18_22/LE18_22.fna
# NOTICE: Finished reading 642 sequences from data/LE18_22/LE18_22.fna
# NOTICE: Finished reading 642 sequences from data/LE18_22/LE18_22.fna
# NOTICE: Finished reading 642 sequences from data/LE18_22/LE18_22.fna
# NOTICE: Finished reading 642 sequences from data/LE18_22/LE18_22.fna
# NOTICE: Finished reading 642 sequences from data/LE18_22/LE18_22.fna
# NOTICE: Finished reading 642 sequences from data/LE18_22/LE18_22.fna
# NOTICE: Finished reading 642 sequences from data/LE18_22/LE18_22.fna
# NOTICE: Finished reading 642 sequences from data/LE18_22/LE18_22.fna
# NOTICE: Finished reading 642 sequences from data/LE18_22/LE18_22.fna
# NOTICE: Finished reading 642 sequences from data/LE18_22/LE18_22.fna
# NOTICE: Finished reading 642 sequences from data/LE18_22/LE18_22.fna
# NOTICE: Finished reading 642 sequences from data/LE18_22/LE18_22.fna
# NOTICE: Finished reading 642 sequences from data/LE18_22/LE18_22.fna
# NOTICE: Finished reading 642 sequences from data/LE18_22/LE18_22.fna
# NOTICE: Finished reading 642 sequences from data/LE18_22/LE18_22.fna
# NOTICE: Finished reading 642 sequences from data/LE18_22/LE18_22.fna
# NOTICE: Finished reading 642 sequences from data/LE18_22/LE18_22.fna
# NOTICE: Finished reading 642 sequences from data/LE18_22/LE18_22.fna
# NOTICE: Finished reading 642 sequences from data/LE18_22/LE18_22.fna
# NOTICE: Finished reading 642 sequences from data/LE18_22/LE18_22.fna
# NOTICE: Finished reading 642 sequences from data/LE18_22/LE18_22.fna
# NOTICE: Finished reading 642 sequences from data/LE18_22/LE18_22.fna
# NOTICE: Finished reading 642 sequences from data/LE18_22/LE18_22.fna
# NOTICE: Finished reading 642 sequences from data/LE18_22/LE18_22.fna
# NOTICE: Finished reading 642 sequences from data/LE18_22/LE18_22.fna
# NOTICE: Finished reading 642 sequences from data/LE18_22/LE18_22.fna
# NOTICE: Finished reading 642 sequences from data/LE18_22/LE18_22.fna
# NOTICE: Finished reading 642 sequences from data/LE18_22/LE18_22.fna
# NOTICE: Finished reading 642 sequences from data/LE18_22/LE18_22.fna
# NOTICE: Finished reading 642 sequences from data/LE18_22/LE18_22.fna
# NOTICE: Finished reading 642 sequences from data/LE18_22/LE18_22.fna
# NOTICE: Finished reading 642 sequences from data/LE18_22/LE18_22.fna
# NOTICE: Finished reading 642 sequences from data/LE18_22/LE18_22.fna
# NOTICE: Finished reading 642 sequences from data/LE18_22/LE18_22.fna
# NOTICE: Finished reading 642 sequences from data/LE18_22/LE18_22.fna
# NOTICE: Finished reading 642 sequences from data/LE18_22/LE18_22.fna
# NOTICE: Finished reading 642 sequences from data/LE18_22/LE18_22.fna
# NOTICE: Finished reading 642 sequences from data/LE18_22/LE18_22.fna
# NOTICE: Finished reading 642 sequences from data/LE18_22/LE18_22.fna
# NOTICE: Finished reading 642 sequences from data/LE18_22/LE18_22.fna
# NOTICE: Finished reading 642 sequences from data/LE18_22/LE18_22.fna
# NOTICE: Finished reading 642 sequences from data/LE18_22/LE18_22.fna
# NOTICE: Finished reading 642 sequences from data/LE18_22/LE18_22.fna
# NOTICE: Finished reading 642 sequences from data/LE18_22/LE18_22.fna
# NOTICE: Finished reading 642 sequences from data/LE18_22/LE18_22.fna
# NOTICE: Finished reading 642 sequences from data/LE18_22/LE18_22.fna
# NOTICE: Finished reading 642 sequences from data/LE18_22/LE18_22.fna
# NOTICE: Finished reading 642 sequences from data/LE18_22/LE18_22.fna
# NOTICE: Finished reading 642 sequences from data/LE18_22/LE18_22.fna
# NOTICE: Finished reading 642 sequences from data/LE18_22/LE18_22.fna
# NOTICE: Finished reading 642 sequences from data/LE18_22/LE18_22.fna
# NOTICE: Finished reading 642 sequences from data/LE18_22/LE18_22.fna
# NOTICE: Finished reading 642 sequences from data/LE18_22/LE18_22.fna
# NOTICE: Finished reading 642 sequences from data/LE18_22/LE18_22.fna
# NOTICE: Finished reading 642 sequences from data/LE18_22/LE18_22.fna
# NOTICE: Finished reading 642 sequences from data/LE18_22/LE18_22.fna
# NOTICE: Finished reading 642 sequences from data/LE18_22/LE18_22.fna
# NOTICE: Finished reading 642 sequences from data/LE18_22/LE18_22.fna
# NOTICE: Finished reading 642 sequences from data/LE18_22/LE18_22.fna
# NOTICE: Finished reading 642 sequences from data/LE18_22/LE18_22.fna
# NOTICE: Finished reading 642 sequences from data/LE18_22/LE18_22.fna
# NOTICE: Finished reading 642 sequences from data/LE18_22/LE18_22.fna
# NOTICE: Finished reading 642 sequences from data/LE18_22/LE18_22.fna
# NOTICE: Finished reading 642 sequences from data/LE18_22/LE18_22.fna
# NOTICE: Finished reading 642 sequences from data/LE18_22/LE18_22.fna
# NOTICE: Finished reading 642 sequences from data/LE18_22/LE18_22.fna
# NOTICE: Finished reading 642 sequences from data/LE18_22/LE18_22.fna
# NOTICE: Finished reading 642 sequences from data/LE18_22/LE18_22.fna
# NOTICE: Finished reading 642 sequences from data/LE18_22/LE18_22.fna
# NOTICE: Finished reading 642 sequences from data/LE18_22/LE18_22.fna
# NOTICE: Finished reading 642 sequences from data/LE18_22/LE18_22.fna
# NOTICE: Finished reading 642 sequences from data/LE18_22/LE18_22.fna
# NOTICE: Finished reading 642 sequences from data/LE18_22/LE18_22.fna
# NOTICE: Finished reading 642 sequences from data/LE18_22/LE18_22.fna
# NOTICE: Finished reading 642 sequences from data/LE18_22/LE18_22.fna
# NOTICE: Finished reading 642 sequences from data/LE18_22/LE18_22.fna
# NOTICE: Finished reading 642 sequences from data/LE18_22/LE18_22.fna
# NOTICE: Finished reading 642 sequences from data/LE18_22/LE18_22.fna
# NOTICE: Finished reading 642 sequences from data/LE18_22/LE18_22.fna
# NOTICE: Finished reading 642 sequences from data/LE18_22/LE18_22.fna
# NOTICE: Finished reading 642 sequences from data/LE18_22/LE18_22.fna
# NOTICE: Finished reading 642 sequences from data/LE18_22/LE18_22.fna
# NOTICE: Finished reading 642 sequences from data/LE18_22/LE18_22.fna
# NOTICE: Finished reading 642 sequences from data/LE18_22/LE18_22.fna
# NOTICE: Finished reading 642 sequences from data/LE18_22/LE18_22.fna
# NOTICE: Finished reading 642 sequences from data/LE18_22/LE18_22.fna
# NOTICE: Finished reading 642 sequences from data/LE18_22/LE18_22.fna
# NOTICE: Finished reading 642 sequences from data/LE18_22/LE18_22.fna
# NOTICE: Finished reading 642 sequences from data/LE18_22/LE18_22.fna
# NOTICE: Finished reading 642 sequences from data/LE18_22/LE18_22.fna
# NOTICE: Finished reading 642 sequences from data/LE18_22/LE18_22.fna
# NOTICE: Finished reading 642 sequences from data/LE18_22/LE18_22.fna
# NOTICE: Finished reading 642 sequences from data/LE18_22/LE18_22.fna
# NOTICE: Finished reading 642 sequences from data/LE18_22/LE18_22.fna
# NOTICE: Finished reading 642 sequences from data/LE18_22/LE18_22.fna
# NOTICE: Finished reading 642 sequences from data/LE18_22/LE18_22.fna
# NOTICE: Finished reading 642 sequences from data/LE18_22/LE18_22.fna
# NOTICE: Finished reading 642 sequences from data/LE18_22/LE18_22.fna
# NOTICE: Finished reading 642 sequences from data/LE18_22/LE18_22.fna
# NOTICE: Finished reading 642 sequences from data/LE18_22/LE18_22.fna
# NOTICE: Finished reading 642 sequences from data/LE18_22/LE18_22.fna
# NOTICE: Finished reading 642 sequences from data/LE18_22/LE18_22.fna
# NOTICE: Finished reading 642 sequences from data/LE18_22/LE18_22.fna
# NOTICE: Finished reading 642 sequences from data/LE18_22/LE18_22.fna
# NOTICE: Finished reading 642 sequences from data/LE18_22/LE18_22.fna
# NOTICE: Finished reading 642 sequences from data/LE18_22/LE18_22.fna
# NOTICE: Finished reading 642 sequences from data/LE18_22/LE18_22.fna
# NOTICE: Finished reading 642 sequences from data/LE18_22/LE18_22.fna
# NOTICE: Finished reading 642 sequences from data/LE18_22/LE18_22.fna
# NOTICE: Finished reading 642 sequences from data/LE18_22/LE18_22.fna
# NOTICE: Finished reading 642 sequences from data/LE18_22/LE18_22.fna
# NOTICE: Finished reading 642 sequences from data/LE18_22/LE18_22.fna
# NOTICE: Finished reading 642 sequences from data/LE18_22/LE18_22.fna
# NOTICE: Finished reading 642 sequences from data/LE18_22/LE18_22.fna
# NOTICE: Finished reading 642 sequences from data/LE18_22/LE18_22.fna
# NOTICE: Finished reading 642 sequences from data/LE18_22/LE18_22.fna
# NOTICE: Finished reading 642 sequences from data/LE18_22/LE18_22.fna
# NOTICE: Finished reading 642 sequences from data/LE18_22/LE18_22.fna
# NOTICE: Finished reading 642 sequences from data/LE18_22/LE18_22.fna
# NOTICE: Finished reading 642 sequences from data/LE18_22/LE18_22.fna
# NOTICE: Finished reading 642 sequences from data/LE18_22/LE18_22.fna
# NOTICE: Finished reading 642 sequences from data/LE18_22/LE18_22.fna
# NOTICE: Finished reading 642 sequences from data/LE18_22/LE18_22.fna
# NOTICE: Finished reading 642 sequences from data/LE18_22/LE18_22.fna
# NOTICE: Finished reading 642 sequences from data/LE18_22/LE18_22.fna
# NOTICE: Finished reading 642 sequences from data/LE18_22/LE18_22.fna
# NOTICE: Finished reading 642 sequences from data/LE18_22/LE18_22.fna
# NOTICE: Finished reading 642 sequences from data/LE18_22/LE18_22.fna
# NOTICE: Finished reading 642 sequences from data/LE18_22/LE18_22.fna
# NOTICE: Finished reading 642 sequences from data/LE18_22/LE18_22.fna
# NOTICE: Finished reading 642 sequences from data/LE18_22/LE18_22.fna
# NOTICE: Finished reading 642 sequences from data/LE18_22/LE18_22.fna
# NOTICE: Finished reading 642 sequences from data/LE18_22/LE18_22.fna
# NOTICE: Finished reading 642 sequences from data/LE18_22/LE18_22.fna
# NOTICE: Finished reading 642 sequences from data/LE18_22/LE18_22.fna
# NOTICE: Finished reading 642 sequences from data/LE18_22/LE18_22.fna
# NOTICE: Finished reading 642 sequences from data/LE18_22/LE18_22.fna
# NOTICE: Finished reading 642 sequences from data/LE18_22/LE18_22.fna
# NOTICE: Finished reading 642 sequences from data/LE18_22/LE18_22.fna
# NOTICE: Finished reading 642 sequences from data/LE18_22/LE18_22.fna
# NOTICE: Finished reading 642 sequences from data/LE18_22/LE18_22.fna
# NOTICE: Finished reading 642 sequences from data/LE18_22/LE18_22.fna
# NOTICE: Finished reading 642 sequences from data/LE18_22/LE18_22.fna
# NOTICE: Finished reading 642 sequences from data/LE18_22/LE18_22.fna
# NOTICE: Finished reading 642 sequences from data/LE18_22/LE18_22.fna
# NOTICE: Finished reading 642 sequences from data/LE18_22/LE18_22.fna
# NOTICE: Finished reading 642 sequences from data/LE18_22/LE18_22.fna
# NOTICE: Finished reading 642 sequences from data/LE18_22/LE18_22.fna
# NOTICE: Finished reading 642 sequences from data/LE18_22/LE18_22.fna
# NOTICE: Finished reading 642 sequences from data/LE18_22/LE18_22.fna
# NOTICE: Finished reading 642 sequences from data/LE18_22/LE18_22.fna
# NOTICE: Finished reading 642 sequences from data/LE18_22/LE18_22.fna
# NOTICE: Finished reading 642 sequences from data/LE18_22/LE18_22.fna
# NOTICE: Finished reading 642 sequences from data/LE18_22/LE18_22.fna
# NOTICE: Finished reading 642 sequences from data/LE18_22/LE18_22.fna
# NOTICE: Finished reading 642 sequences from data/LE18_22/LE18_22.fna
# NOTICE: Finished reading 642 sequences from data/LE18_22/LE18_22.fna
# NOTICE: Finished reading 642 sequences from data/LE18_22/LE18_22.fna
# NOTICE: Finished reading 642 sequences from data/LE18_22/LE18_22.fna
# NOTICE: Finished reading 642 sequences from data/LE18_22/LE18_22.fna
# NOTICE: Finished reading 642 sequences from data/LE18_22/LE18_22.fna
# NOTICE: Finished reading 642 sequences from data/LE18_22/LE18_22.fna
# NOTICE: Finished reading 642 sequences from data/LE18_22/LE18_22.fna
# NOTICE: Finished reading 642 sequences from data/LE18_22/LE18_22.fna
# NOTICE: Finished reading 642 sequences from data/LE18_22/LE18_22.fna
# NOTICE: Finished reading 642 sequences from data/LE18_22/LE18_22.fna
# NOTICE: Finished reading 642 sequences from data/LE18_22/LE18_22.fna
# NOTICE: Finished reading 642 sequences from data/LE18_22/LE18_22.fna
# NOTICE: Finished reading 642 sequences from data/LE18_22/LE18_22.fna
# NOTICE: Finished reading 642 sequences from data/LE18_22/LE18_22.fna
# NOTICE: Finished reading 642 sequences from data/LE18_22/LE18_22.fna
# NOTICE: Finished reading 642 sequences from data/LE18_22/LE18_22.fna
# NOTICE: Finished reading 642 sequences from data/LE18_22/LE18_22.fna
# NOTICE: Finished reading 642 sequences from data/LE18_22/LE18_22.fna
# NOTICE: Finished reading 642 sequences from data/LE18_22/LE18_22.fna
# NOTICE: Finished reading 642 sequences from data/LE18_22/LE18_22.fna
# NOTICE: Finished reading 642 sequences from data/LE18_22/LE18_22.fna
# NOTICE: Finished reading 642 sequences from data/LE18_22/LE18_22.fna
# NOTICE: Finished reading 642 sequences from data/LE18_22/LE18_22.fna
# NOTICE: Finished reading 642 sequences from data/LE18_22/LE18_22.fna
# NOTICE: Finished reading 642 sequences from data/LE18_22/LE18_22.fna
# NOTICE: Finished reading 642 sequences from data/LE18_22/LE18_22.fna
# NOTICE: Finished reading 642 sequences from data/LE18_22/LE18_22.fna
# NOTICE: Finished reading 642 sequences from data/LE18_22/LE18_22.fna
# NOTICE: Finished reading 642 sequences from data/LE18_22/LE18_22.fna
# NOTICE: Finished reading 642 sequences from data/LE18_22/LE18_22.fna
# NOTICE: Finished reading 642 sequences from data/LE18_22/LE18_22.fna
# NOTICE: Finished reading 642 sequences from data/LE18_22/LE18_22.fna
# NOTICE: Finished reading 642 sequences from data/LE18_22/LE18_22.fna
# NOTICE: Finished reading 642 sequences from data/LE18_22/LE18_22.fna
# NOTICE: Finished reading 642 sequences from data/LE18_22/LE18_22.fna
# NOTICE: Finished reading 642 sequences from data/LE18_22/LE18_22.fna
# NOTICE: Finished reading 642 sequences from data/LE18_22/LE18_22.fna
# NOTICE: Finished reading 642 sequences from data/LE18_22/LE18_22.fna
# NOTICE: Finished reading 642 sequences from data/LE18_22/LE18_22.fna
# NOTICE: Finished reading 642 sequences from data/LE18_22/LE18_22.fna
# NOTICE: Finished reading 642 sequences from data/LE18_22/LE18_22.fna
# NOTICE: Finished reading 642 sequences from data/LE18_22/LE18_22.fna
# NOTICE: Finished reading 642 sequences from data/LE18_22/LE18_22.fna
# NOTICE: Finished reading 642 sequences from data/LE18_22/LE18_22.fna
# NOTICE: Finished reading 642 sequences from data/LE18_22/LE18_22.fna
# NOTICE: Finished reading 642 sequences from data/LE18_22/LE18_22.fna
# NOTICE: Finished reading 642 sequences from data/LE18_22/LE18_22.fna
# NOTICE: Finished reading 642 sequences from data/LE18_22/LE18_22.fna
# NOTICE: Finished reading 642 sequences from data/LE18_22/LE18_22.fna
# NOTICE: Finished reading 642 sequences from data/LE18_22/LE18_22.fna
# NOTICE: Finished reading 642 sequences from data/LE18_22/LE18_22.fna
# NOTICE: Finished reading 642 sequences from data/LE18_22/LE18_22.fna
# NOTICE: Finished reading 642 sequences from data/LE18_22/LE18_22.fna
# NOTICE: Finished reading 642 sequences from data/LE18_22/LE18_22.fna
# NOTICE: Finished reading 642 sequences from data/LE18_22/LE18_22.fna
# NOTICE: Finished reading 642 sequences from data/LE18_22/LE18_22.fna
# NOTICE: Finished reading 642 sequences from data/LE18_22/LE18_22.fna
# NOTICE: Finished reading 642 sequences from data/LE18_22/LE18_22.fna
# NOTICE: Finished reading 642 sequences from data/LE18_22/LE18_22.fna
# NOTICE: Finished reading 642 sequences from data/LE18_22/LE18_22.fna
# NOTICE: Finished reading 642 sequences from data/LE18_22/LE18_22.fna
# NOTICE: Finished reading 642 sequences from data/LE18_22/LE18_22.fna
# NOTICE: Finished reading 642 sequences from data/LE18_22/LE18_22.fna
# NOTICE: Finished reading 642 sequences from data/LE18_22/LE18_22.fna
# NOTICE: Finished reading 642 sequences from data/LE18_22/LE18_22.fna
# NOTICE: Finished reading 642 sequences from data/LE18_22/LE18_22.fna
# NOTICE: Finished reading 642 sequences from data/LE18_22/LE18_22.fna
# NOTICE: Finished reading 642 sequences from data/LE18_22/LE18_22.fna
# NOTICE: Finished reading 642 sequences from data/LE18_22/LE18_22.fna
# NOTICE: Finished reading 642 sequences from data/LE18_22/LE18_22.fna
# NOTICE: Finished reading 642 sequences from data/LE18_22/LE18_22.fna
# NOTICE: Finished reading 642 sequences from data/LE18_22/LE18_22.fna
# NOTICE: Finished reading 642 sequences from data/LE18_22/LE18_22.fna
# NOTICE: Finished reading 642 sequences from data/LE18_22/LE18_22.fna
# NOTICE: Finished reading 642 sequences from data/LE18_22/LE18_22.fna
# NOTICE: Finished reading 642 sequences from data/LE18_22/LE18_22.fna
# NOTICE: Finished reading 642 sequences from data/LE18_22/LE18_22.fna
# NOTICE: Finished reading 642 sequences from data/LE18_22/LE18_22.fna
# NOTICE: Finished reading 642 sequences from data/LE18_22/LE18_22.fna
# NOTICE: Finished reading 642 sequences from data/LE18_22/LE18_22.fna
# NOTICE: Finished reading 642 sequences from data/LE18_22/LE18_22.fna
# NOTICE: Finished reading 642 sequences from data/LE18_22/LE18_22.fna
# NOTICE: Finished reading 642 sequences from data/LE18_22/LE18_22.fna
# NOTICE: Finished reading 642 sequences from data/LE18_22/LE18_22.fna
# NOTICE: Finished reading 642 sequences from data/LE18_22/LE18_22.fna
# NOTICE: Finished reading 642 sequences from data/LE18_22/LE18_22.fna
# NOTICE: Finished reading 642 sequences from data/LE18_22/LE18_22.fna
# NOTICE: Finished reading 642 sequences from data/LE18_22/LE18_22.fna
# NOTICE: Finished reading 642 sequences from data/LE18_22/LE18_22.fna
# NOTICE: Finished reading 642 sequences from data/LE18_22/LE18_22.fna
# NOTICE: Finished reading 642 sequences from data/LE18_22/LE18_22.fna
# NOTICE: Finished reading 642 sequences from data/LE18_22/LE18_22.fna
# NOTICE: Finished reading 642 sequences from data/LE18_22/LE18_22.fna
# NOTICE: Finished reading 642 sequences from data/LE18_22/LE18_22.fna
# NOTICE: Finished reading 642 sequences from data/LE18_22/LE18_22.fna
# NOTICE: Finished reading 642 sequences from data/LE18_22/LE18_22.fna
# NOTICE: Finished reading 642 sequences from data/LE18_22/LE18_22.fna
# NOTICE: Finished reading 642 sequences from data/LE18_22/LE18_22.fna
# NOTICE: Finished reading 642 sequences from data/LE18_22/LE18_22.fna
# NOTICE: Finished reading 642 sequences from data/LE18_22/LE18_22.fna
# NOTICE: Finished reading 642 sequences from data/LE18_22/LE18_22.fna
# NOTICE: Finished reading 642 sequences from data/LE18_22/LE18_22.fna
# NOTICE: Finished reading 642 sequences from data/LE18_22/LE18_22.fna
# NOTICE: Finished reading 642 sequences from data/LE18_22/LE18_22.fna
# NOTICE: Finished reading 642 sequences from data/LE18_22/LE18_22.fna
# NOTICE: Finished reading 642 sequences from data/LE18_22/LE18_22.fna
# NOTICE: Finished reading 642 sequences from data/LE18_22/LE18_22.fna
# NOTICE: Finished reading 642 sequences from data/LE18_22/LE18_22.fna
# NOTICE: Finished reading 642 sequences from data/LE18_22/LE18_22.fna
# NOTICE: Finished reading 642 sequences from data/LE18_22/LE18_22.fna
# NOTICE: Finished reading 642 sequences from data/LE18_22/LE18_22.fna
# NOTICE: Finished reading 642 sequences from data/LE18_22/LE18_22.fna
# NOTICE: Finished reading 642 sequences from data/LE18_22/LE18_22.fna
# NOTICE: Finished reading 642 sequences from data/LE18_22/LE18_22.fna
# NOTICE: Finished reading 642 sequences from data/LE18_22/LE18_22.fna
# NOTICE: Finished reading 642 sequences from data/LE18_22/LE18_22.fna
# NOTICE: Finished reading 642 sequences from data/LE18_22/LE18_22.fna
# NOTICE: Finished reading 642 sequences from data/LE18_22/LE18_22.fna
# NOTICE: Finished reading 642 sequences from data/LE18_22/LE18_22.fna
# NOTICE: Finished reading 642 sequences from data/LE18_22/LE18_22.fna
# NOTICE: Finished reading 642 sequences from data/LE18_22/LE18_22.fna
# NOTICE: Finished reading 642 sequences from data/LE18_22/LE18_22.fna
# NOTICE: Finished reading 642 sequences from data/LE18_22/LE18_22.fna
# NOTICE: Finished reading 642 sequences from data/LE18_22/LE18_22.fna
# NOTICE: Finished reading 642 sequences from data/LE18_22/LE18_22.fna
# NOTICE: Finished reading 642 sequences from data/LE18_22/LE18_22.fna
# NOTICE: Finished reading 642 sequences from data/LE18_22/LE18_22.fna
# NOTICE: Finished reading 642 sequences from data/LE18_22/LE18_22.fna
# NOTICE: Finished reading 642 sequences from data/LE18_22/LE18_22.fna
# NOTICE: Finished reading 642 sequences from data/LE18_22/LE18_22.fna
# NOTICE: Finished reading 642 sequences from data/LE18_22/LE18_22.fna
# NOTICE: Finished reading 642 sequences from data/LE18_22/LE18_22.fna
# NOTICE: Finished reading 642 sequences from data/LE18_22/LE18_22.fna
# NOTICE: Finished reading 642 sequences from data/LE18_22/LE18_22.fna
# NOTICE: Finished reading 642 sequences from data/LE18_22/LE18_22.fna
# NOTICE: Finished reading 642 sequences from data/LE18_22/LE18_22.fna
# NOTICE: Finished reading 642 sequences from data/LE18_22/LE18_22.fna
# NOTICE: Finished reading 642 sequences from data/LE18_22/LE18_22.fna
# NOTICE: Finished reading 642 sequences from data/LE18_22/LE18_22.fna
# NOTICE: Finished reading 642 sequences from data/LE18_22/LE18_22.fna
# NOTICE: Finished reading 642 sequences from data/LE18_22/LE18_22.fna
# NOTICE: Finished reading 642 sequences from data/LE18_22/LE18_22.fna
# NOTICE: Finished reading 642 sequences from data/LE18_22/LE18_22.fna
# NOTICE: Finished reading 642 sequences from data/LE18_22/LE18_22.fna
# NOTICE: Finished reading 642 sequences from data/LE18_22/LE18_22.fna
# NOTICE: Finished reading 642 sequences from data/LE18_22/LE18_22.fna
# NOTICE: Finished reading 642 sequences from data/LE18_22/LE18_22.fna
# NOTICE: Finished reading 642 sequences from data/LE18_22/LE18_22.fna
# NOTICE: Finished reading 642 sequences from data/LE18_22/LE18_22.fna
# NOTICE: Finished reading 642 sequences from data/LE18_22/LE18_22.fna
# NOTICE: Finished reading 642 sequences from data/LE18_22/LE18_22.fna
# NOTICE: Finished reading 642 sequences from data/LE18_22/LE18_22.fna
# NOTICE: Finished reading 642 sequences from data/LE18_22/LE18_22.fna
# NOTICE: Finished reading 642 sequences from data/LE18_22/LE18_22.fna
# NOTICE: Finished reading 642 sequences from data/LE18_22/LE18_22.fna
# NOTICE: Finished reading 642 sequences from data/LE18_22/LE18_22.fna
# NOTICE: Finished reading 642 sequences from data/LE18_22/LE18_22.fna
# NOTICE: Finished reading 642 sequences from data/LE18_22/LE18_22.fna
# NOTICE: Finished reading 642 sequences from data/LE18_22/LE18_22.fna
# NOTICE: Finished reading 642 sequences from data/LE18_22/LE18_22.fna
# NOTICE: Finished reading 642 sequences from data/LE18_22/LE18_22.fna
# NOTICE: Finished reading 642 sequences from data/LE18_22/LE18_22.fna
# NOTICE: Finished reading 642 sequences from data/LE18_22/LE18_22.fna
# NOTICE: Finished reading 642 sequences from data/LE18_22/LE18_22.fna
# NOTICE: Finished reading 642 sequences from data/LE18_22/LE18_22.fna
# NOTICE: Finished reading 642 sequences from data/LE18_22/LE18_22.fna
# NOTICE: Finished reading 642 sequences from data/LE18_22/LE18_22.fna
# NOTICE: Finished reading 642 sequences from data/LE18_22/LE18_22.fna
# NOTICE: Finished reading 642 sequences from data/LE18_22/LE18_22.fna
# NOTICE: Finished reading 642 sequences from data/LE18_22/LE18_22.fna
# NOTICE: Finished reading 642 sequences from data/LE18_22/LE18_22.fna
# NOTICE: Finished reading 642 sequences from data/LE18_22/LE18_22.fna
# NOTICE: Finished reading 642 sequences from data/LE18_22/LE18_22.fna
# NOTICE: Finished reading 642 sequences from data/LE18_22/LE18_22.fna
# NOTICE: Finished reading 642 sequences from data/LE18_22/LE18_22.fna
# NOTICE: Finished reading 642 sequences from data/LE18_22/LE18_22.fna
# NOTICE: Finished reading 642 sequences from data/LE18_22/LE18_22.fna
# NOTICE: Finished reading 642 sequences from data/LE18_22/LE18_22.fna
# NOTICE: Finished reading 642 sequences from data/LE18_22/LE18_22.fna
# NOTICE: Finished reading 642 sequences from data/LE18_22/LE18_22.fna
# NOTICE: Finished reading 642 sequences from data/LE18_22/LE18_22.fna
# NOTICE: Finished reading 642 sequences from data/LE18_22/LE18_22.fna
# NOTICE: Finished reading 642 sequences from data/LE18_22/LE18_22.fna
# NOTICE: Finished reading 642 sequences from data/LE18_22/LE18_22.fna
# NOTICE: Finished reading 642 sequences from data/LE18_22/LE18_22.fna
# NOTICE: Finished reading 642 sequences from data/LE18_22/LE18_22.fna
# NOTICE: Finished reading 642 sequences from data/LE18_22/LE18_22.fna
# NOTICE: Finished reading 642 sequences from data/LE18_22/LE18_22.fna
# NOTICE: Finished reading 642 sequences from data/LE18_22/LE18_22.fna
# NOTICE: Finished reading 642 sequences from data/LE18_22/LE18_22.fna
# NOTICE: Finished reading 642 sequences from data/LE18_22/LE18_22.fna
# NOTICE: Finished reading 642 sequences from data/LE18_22/LE18_22.fna
# NOTICE: Finished reading 642 sequences from data/LE18_22/LE18_22.fna
# NOTICE: Finished reading 642 sequences from data/LE18_22/LE18_22.fna
# NOTICE: Finished reading 642 sequences from data/LE18_22/LE18_22.fna
# NOTICE: Finished reading 642 sequences from data/LE18_22/LE18_22.fna
# NOTICE: Finished reading 642 sequences from data/LE18_22/LE18_22.fna
# NOTICE: Finished reading 642 sequences from data/LE18_22/LE18_22.fna
# NOTICE: Finished reading 642 sequences from data/LE18_22/LE18_22.fna
# NOTICE: Finished reading 642 sequences from data/LE18_22/LE18_22.fna
# NOTICE: Finished reading 642 sequences from data/LE18_22/LE18_22.fna
# NOTICE: Finished reading 642 sequences from data/LE18_22/LE18_22.fna
# NOTICE: Finished reading 642 sequences from data/LE18_22/LE18_22.fna
# NOTICE: Finished reading 642 sequences from data/LE18_22/LE18_22.fna
# NOTICE: Finished reading 642 sequences from data/LE18_22/LE18_22.fna
# NOTICE: Finished reading 642 sequences from data/LE18_22/LE18_22.fna
# NOTICE: Finished reading 642 sequences from data/LE18_22/LE18_22.fna
# NOTICE: Finished reading 642 sequences from data/LE18_22/LE18_22.fna
# NOTICE: Finished reading 642 sequences from data/LE18_22/LE18_22.fna
# NOTICE: Finished reading 642 sequences from data/LE18_22/LE18_22.fna
# NOTICE: Finished reading 642 sequences from data/LE18_22/LE18_22.fna
# NOTICE: Finished writting FASTA for 5095 genomic regions to data/LE18_22/LE18_22_refGeneMrna.fa
# 2025-04-13 20:18:13,447 - INFO - Starting parallel annotation of avinput files.
# Database has been built and saved to data/LE18_22/.
#
# Annotating avinput files...
# NOTICE: Output files are written to data/annovar_files/graz_LE.ND_85.avinput.variant_function, data/annovar_files/graz_LE.ND_85.avinput.exonic_variant_function
# NOTICE: Reading gene annotation from data/LE18_22/LE18_22_refGene.txt ... NOTICE: Output files are written to data/annovar_files/graz_LE.ND_79.avinput.variant_function, data/annovar_files/graz_LE.ND_79.avinput.exonic_variant_function
# NOTICE: Reading gene annotation from data/LE18_22/LE18_22_refGene.txt ... NOTICE: Output files are written to data/annovar_files/graz_LE.ND_78.avinput.variant_function, data/annovar_files/graz_LE.ND_78.avinput.exonic_variant_function
# NOTICE: Reading gene annotation from data/LE18_22/LE18_22_refGene.txt ... NOTICE: Output files are written to data/annovar_files/graz_LE.ND_101.avinput.variant_function, data/annovar_files/graz_LE.ND_101.avinput.exonic_variant_function
# NOTICE: Reading gene annotation from data/LE18_22/LE18_22_refGene.txt ... NOTICE: Output files are written to data/annovar_files/graz_LE.ND_100.avinput.variant_function, data/annovar_files/graz_LE.ND_100.avinput.exonic_variant_function
# NOTICE: Reading gene annotation from data/LE18_22/LE18_22_refGene.txt ... NOTICE: Output files are written to data/annovar_files/graz_LE.ND_95.avinput.variant_function, data/annovar_files/graz_LE.ND_95.avinput.exonic_variant_function
# NOTICE: Reading gene annotation from data/LE18_22/LE18_22_refGene.txt ... NOTICE: Output files are written to data/annovar_files/graz_LE.ND_94.avinput.variant_function, data/annovar_files/graz_LE.ND_94.avinput.exonic_variant_function
# NOTICE: Reading gene annotation from data/LE18_22/LE18_22_refGene.txt ... NOTICE: Output files are written to data/annovar_files/graz_LE.ND_84.avinput.variant_function, data/annovar_files/graz_LE.ND_84.avinput.exonic_variant_function
# NOTICE: Reading gene annotation from data/LE18_22/LE18_22_refGene.txt ... Done with 5095 transcripts (including 54 without coding sequence annotation) for 5095 unique genes
# Done with 5095 transcripts (including 54 without coding sequence annotation) for 5095 unique genes
# NOTICE: Processing next batch with 49 unique variants in 49 input lines
# NOTICE: Reading FASTA sequences from data/LE18_22/LE18_22_refGeneMrna.fa ... Done with 5095 transcripts (including 54 without coding sequence annotation) for 5095 unique genes
# Done with 5095 transcripts (including 54 without coding sequence annotation) for 5095 unique genes
# Done with 7 sequences
# Done with 5095 transcripts (including 54 without coding sequence annotation) for 5095 unique genes
# Done with 5095 transcripts (including 54 without coding sequence annotation) for 5095 unique genes
# 2025-04-13 20:18:14,538 - INFO - Successfully annotated data/annovar_files/graz_LE.ND_79.avinput
# Done with 5095 transcripts (including 54 without coding sequence annotation) for 5095 unique genes
# NOTICE: Processing next batch with 4199 unique variants in 4199 input lines
# Done with 5095 transcripts (including 54 without coding sequence annotation) for 5095 unique genes
# NOTICE: Processing next batch with 5045 unique variants in 5045 input lines
# NOTICE: Processing next batch with 3879 unique variants in 3879 input lines
# NOTICE: Processing next batch with 3939 unique variants in 3939 input lines
# NOTICE: Processing next batch with 3410 unique variants in 3410 input lines
# NOTICE: Processing next batch with 4084 unique variants in 4084 input lines
# NOTICE: Processing next batch with 3552 unique variants in 3552 input lines
# NOTICE: Reading FASTA sequences from data/LE18_22/LE18_22_refGeneMrna.fa ... NOTICE: Output files are written to data/annovar_files/graz_LE.ND_87.avinput.variant_function, data/annovar_files/graz_LE.ND_87.avinput.exonic_variant_function
# NOTICE: Reading gene annotation from data/LE18_22/LE18_22_refGene.txt ... NOTICE: Reading FASTA sequences from data/LE18_22/LE18_22_refGeneMrna.fa ... NOTICE: Reading FASTA sequences from data/LE18_22/LE18_22_refGeneMrna.fa ... Done with 312 sequences
# NOTICE: Reading FASTA sequences from data/LE18_22/LE18_22_refGeneMrna.fa ... NOTICE: Reading FASTA sequences from data/LE18_22/LE18_22_refGeneMrna.fa ... Done with 319 sequences
# NOTICE: Reading FASTA sequences from data/LE18_22/LE18_22_refGeneMrna.fa ... Done with 270 sequences
# Done with 317 sequences
# Done with 302 sequences
# NOTICE: Reading FASTA sequences from data/LE18_22/LE18_22_refGeneMrna.fa ... Done with 290 sequences
# Done with 285 sequences
# Done with 5095 transcripts (including 54 without coding sequence annotation) for 5095 unique genes
# 2025-04-13 20:18:14,767 - INFO - Successfully annotated data/annovar_files/graz_LE.ND_94.avinput
# 2025-04-13 20:18:14,784 - INFO - Successfully annotated data/annovar_files/graz_LE.ND_100.avinput
# 2025-04-13 20:18:14,794 - INFO - Successfully annotated data/annovar_files/graz_LE.ND_84.avinput
# 2025-04-13 20:18:14,804 - INFO - Successfully annotated data/annovar_files/graz_LE.ND_78.avinput
# 2025-04-13 20:18:14,807 - INFO - Successfully annotated data/annovar_files/graz_LE.ND_101.avinput
# NOTICE: Processing next batch with 6020 unique variants in 6020 input lines
# 2025-04-13 20:18:14,833 - INFO - Successfully annotated data/annovar_files/graz_LE.ND_95.avinput
# 2025-04-13 20:18:14,837 - INFO - Successfully annotated data/annovar_files/graz_LE.ND_85.avinput
# NOTICE: Output files are written to data/annovar_files/graz_LE.ND_97.avinput.variant_function, data/annovar_files/graz_LE.ND_97.avinput.exonic_variant_function
# NOTICE: Reading gene annotation from data/LE18_22/LE18_22_refGene.txt ... NOTICE: Output files are written to data/annovar_files/graz_LE.ND_102.avinput.variant_function, data/annovar_files/graz_LE.ND_102.avinput.exonic_variant_function
# NOTICE: Reading gene annotation from data/LE18_22/LE18_22_refGene.txt ... NOTICE: Output files are written to data/annovar_files/graz_LE.ND_86.avinput.variant_function, data/annovar_files/graz_LE.ND_86.avinput.exonic_variant_function
# NOTICE: Reading gene annotation from data/LE18_22/LE18_22_refGene.txt ... NOTICE: Output files are written to data/annovar_files/graz_LE.ND_93.avinput.variant_function, data/annovar_files/graz_LE.ND_93.avinput.exonic_variant_function
# NOTICE: Reading gene annotation from data/LE18_22/LE18_22_refGene.txt ... NOTICE: Output files are written to data/annovar_files/graz_LE.ND_83.avinput.variant_function, data/annovar_files/graz_LE.ND_83.avinput.exonic_variant_function
# NOTICE: Reading gene annotation from data/LE18_22/LE18_22_refGene.txt ... NOTICE: Output files are written to data/annovar_files/graz_LE.ND_80.avinput.variant_function, data/annovar_files/graz_LE.ND_80.avinput.exonic_variant_function
# NOTICE: Reading gene annotation from data/LE18_22/LE18_22_refGene.txt ... Done with 5095 transcripts (including 54 without coding sequence annotation) for 5095 unique genes
# NOTICE: Output files are written to data/annovar_files/graz_LE.ND_82.avinput.variant_function, data/annovar_files/graz_LE.ND_82.avinput.exonic_variant_function
# NOTICE: Reading gene annotation from data/LE18_22/LE18_22_refGene.txt ... Done with 5095 transcripts (including 54 without coding sequence annotation) for 5095 unique genes
# Done with 5095 transcripts (including 54 without coding sequence annotation) for 5095 unique genes
# NOTICE: Processing next batch with 3952 unique variants in 3952 input lines
# Done with 5095 transcripts (including 54 without coding sequence annotation) for 5095 unique genes
# NOTICE: Reading FASTA sequences from data/LE18_22/LE18_22_refGeneMrna.fa ... Done with 5095 transcripts (including 54 without coding sequence annotation) for 5095 unique genes
# NOTICE: Processing next batch with 4507 unique variants in 4507 input lines
# NOTICE: Processing next batch with 3763 unique variants in 3763 input lines
# Done with 5095 transcripts (including 54 without coding sequence annotation) for 5095 unique genes
# Done with 320 sequences
# NOTICE: Processing next batch with 4017 unique variants in 4017 input lines
# NOTICE: Processing next batch with 2921 unique variants in 2921 input lines
# Done with 5095 transcripts (including 54 without coding sequence annotation) for 5095 unique genes
# NOTICE: Processing next batch with 2598 unique variants in 2598 input lines
# NOTICE: Processing next batch with 4704 unique variants in 4704 input lines
# NOTICE: Reading FASTA sequences from data/LE18_22/LE18_22_refGeneMrna.fa ... NOTICE: Reading FASTA sequences from data/LE18_22/LE18_22_refGeneMrna.fa ... NOTICE: Reading FASTA sequences from data/LE18_22/LE18_22_refGeneMrna.fa ... NOTICE: Reading FASTA sequences from data/LE18_22/LE18_22_refGeneMrna.fa ... 2025-04-13 20:18:15,165 - INFO - Successfully annotated data/annovar_files/graz_LE.ND_87.avinput
# Done with 308 sequences
# NOTICE: Reading FASTA sequences from data/LE18_22/LE18_22_refGeneMrna.fa ... Done with 251 sequences
# Done with 280 sequences
# Done with 265 sequences
# Done with 304 sequences
# NOTICE: Reading FASTA sequences from data/LE18_22/LE18_22_refGeneMrna.fa ... Done with 281 sequences
# 2025-04-13 20:18:15,224 - INFO - Successfully annotated data/annovar_files/graz_LE.ND_83.avinput
# 2025-04-13 20:18:15,232 - INFO - Successfully annotated data/annovar_files/graz_LE.ND_82.avinput
# NOTICE: Reading FASTA sequences from data/LE18_22/LE18_22_refGeneMrna.fa ... 2025-04-13 20:18:15,242 - INFO - Successfully annotated data/annovar_files/graz_LE.ND_93.avinput
# 2025-04-13 20:18:15,247 - INFO - Successfully annotated data/annovar_files/graz_LE.ND_97.avinput
# Done with 284 sequences
# 2025-04-13 20:18:15,271 - INFO - Successfully annotated data/annovar_files/graz_LE.ND_102.avinput
# NOTICE: Output files are written to data/annovar_files/graz_LE.ND_90.avinput.variant_function, data/annovar_files/graz_LE.ND_90.avinput.exonic_variant_function
# NOTICE: Reading gene annotation from data/LE18_22/LE18_22_refGene.txt ... 2025-04-13 20:18:15,296 - INFO - Successfully annotated data/annovar_files/graz_LE.ND_86.avinput
# NOTICE: Output files are written to data/annovar_files/graz_LE.ND_99.avinput.variant_function, data/annovar_files/graz_LE.ND_99.avinput.exonic_variant_function
# NOTICE: Reading gene annotation from data/LE18_22/LE18_22_refGene.txt ... 2025-04-13 20:18:15,342 - INFO - Successfully annotated data/annovar_files/graz_LE.ND_80.avinput
# NOTICE: Output files are written to data/annovar_files/graz_LE.ND_89.avinput.variant_function, data/annovar_files/graz_LE.ND_89.avinput.exonic_variant_function
# NOTICE: Reading gene annotation from data/LE18_22/LE18_22_refGene.txt ... NOTICE: Output files are written to data/annovar_files/graz_LE.ND_98.avinput.variant_function, data/annovar_files/graz_LE.ND_98.avinput.exonic_variant_function
# NOTICE: Reading gene annotation from data/LE18_22/LE18_22_refGene.txt ... Done with 5095 transcripts (including 54 without coding sequence annotation) for 5095 unique genes
# NOTICE: Output files are written to data/annovar_files/graz_LE.ND_91.avinput.variant_function, data/annovar_files/graz_LE.ND_91.avinput.exonic_variant_function
# NOTICE: Reading gene annotation from data/LE18_22/LE18_22_refGene.txt ... NOTICE: Output files are written to data/annovar_files/graz_LE.ND_81.avinput.variant_function, data/annovar_files/graz_LE.ND_81.avinput.exonic_variant_function
# NOTICE: Reading gene annotation from data/LE18_22/LE18_22_refGene.txt ... NOTICE: Processing next batch with 4189 unique variants in 4189 input lines
# Done with 5095 transcripts (including 54 without coding sequence annotation) for 5095 unique genes
# Done with 5095 transcripts (including 54 without coding sequence annotation) for 5095 unique genes
# Done with 5095 transcripts (including 54 without coding sequence annotation) for 5095 unique genes
# NOTICE: Processing next batch with 4506 unique variants in 4506 input lines
# Done with 5095 transcripts (including 54 without coding sequence annotation) for 5095 unique genes
# NOTICE: Processing next batch with 4199 unique variants in 4199 input lines
# NOTICE: Processing next batch with 5593 unique variants in 5593 input lines
# Done with 5095 transcripts (including 54 without coding sequence annotation) for 5095 unique genes
# NOTICE: Processing next batch with 5224 unique variants in 5224 input lines
# NOTICE: Processing next batch with 5889 unique variants in 5889 input lines
# NOTICE: Reading FASTA sequences from data/LE18_22/LE18_22_refGeneMrna.fa ... Done with 311 sequences
# NOTICE: Reading FASTA sequences from data/LE18_22/LE18_22_refGeneMrna.fa ... NOTICE: Reading FASTA sequences from data/LE18_22/LE18_22_refGeneMrna.fa ... Done with 307 sequences
# Done with 319 sequences
# 2025-04-13 20:18:15,581 - INFO - Successfully annotated data/annovar_files/graz_LE.ND_90.avinput
# NOTICE: Reading FASTA sequences from data/LE18_22/LE18_22_refGeneMrna.fa ... NOTICE: Reading FASTA sequences from data/LE18_22/LE18_22_refGeneMrna.fa ... Done with 307 sequences
# Done with 296 sequences
# 2025-04-13 20:18:15,632 - INFO - Successfully annotated data/annovar_files/graz_LE.ND_99.avinput
# 2025-04-13 20:18:15,640 - INFO - Successfully annotated data/annovar_files/graz_LE.ND_98.avinput
# NOTICE: Reading FASTA sequences from data/LE18_22/LE18_22_refGeneMrna.fa ... Done with 299 sequences
# 2025-04-13 20:18:15,688 - INFO - Successfully annotated data/annovar_files/graz_LE.ND_89.avinput
# 2025-04-13 20:18:15,694 - INFO - Successfully annotated data/annovar_files/graz_LE.ND_91.avinput
# 2025-04-13 20:18:15,740 - INFO - Successfully annotated data/annovar_files/graz_LE.ND_81.avinput
# 2025-04-13 20:18:15,866 - INFO - Completed parallel annotation of avinput files.
# Annotated 22 avinput files in 2.42 seconds.
# Annotated avinput files are saved in data/annovar_files/.

# %% [markdown]
# #### **Build Gene Mutation Table:**
#
# For each sample:
# 1. Build gene maps from the gff3 file.
# 2. Compile mutation info gene-by-gene.
# 3. Determine mutation types.
#     - binary: mutation or wildtype
#     - multiple: nonsense, nonstop, missense, silent or wildtype
# 4. Output mutation types.
#
# **Import functions and annotation data**

# %%
from muggwas import compile_gene_mutations, write_gene_mutation_summary

# Directory containing the ANNOVAR output files
annovar_output_dir = 'data/annovar_files'
# Read gff3 to build gene maps
gff_file = 'data/LE18_22/LE18_22.gff3'
# Write the mutation types to a tab delimited file
output_file = 'data/gene_mutation_summary.txt'

# %% [markdown]
# **Compile variants and output gene mutation table**

# %%
## Compile the gene mutations for each sample
# if you want to output binary mutation types (mutated or not), set model = 'binary'
gene_mutation_summary = compile_gene_mutations(annovar_output_dir, gff_file, model = 'multiple')
## Write the gene mutation summary
write_gene_mutation_summary(gene_mutation_summary, output_file)
# Out:
# Time elapsed for compiling gene mutations: 2.13 seconds
# Total number of samples processed: 22
# Gene mutation summary has been written to data/gene_mutation_summary.txt.

# %% [markdown]
# #### **Estimate Population Structure Effect:**
#
# In gene-trait association analyses, false positives could arise from shared genetic lineage, especially in clonal organisms. There are two methods to estimate the effect of population structure:
# - Phylogenetic-based: Infer population structure based on phylogenetic distances. Since MugGWAS will use a linear mixed model, the distance will be estimated from the shared branch length between the MRCA and the root.
# - Kinship: Variants on core gene sequences represent the result of vertical evolution. To make inferences for identical by descent, the script will calculate the kinship matrix from the genotype matrix of the presence and absence of variants. --> (not supported yet as of 2025.04.03)
#
# Inputs:
# - Phylogeny-based: Output from IQ-tree `core_gene_tree.nwk`. A high-quality phylogeny based on single-copy core genes from a pangenome.
# - Kinship: A VCF file documenting variants on core genes `core_gene_snp.vcf.gz`.
#
# Output:
# - `phylogeny_distances.tsv`: a file to account for population structure effect in pyseer.
#
# **Phylogeny-based method**

# %%
from muggwas import phylogeny2distmatrix

# Read the phylogenetic tree
phylogeny = 'data/LE_tree.nwk'
output_file = 'data/phylogeny_distances.tsv'

# Convert the phylogenetic tree to a distance matrix
phylogeny2distmatrix(phylogeny, output_file)
